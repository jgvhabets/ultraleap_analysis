# %% [markdown]
# Import public packages and functions

# %%
import os
import importlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
from itertools import compress
import re
import seaborn as sns

import openpyxl
from datetime import datetime
from scipy.spatial import distance
from scipy.ndimage import uniform_filter1d
import math
from scipy.signal import find_peaks, peak_prominences
import statistics as stat
import json

# %%
def get_repo_path_in_notebook():
    """
    Finds path of repo from Notebook.
    Start running this once to correctly find
    other modules/functions
    """
    path = os.getcwd()
    repo_name = 'ultraleap_analysis'

    while path[-len(repo_name):] != 'ultraleap_analysis':

        path = os.path.dirname(path)

    return path

# %%
repo_path = get_repo_path_in_notebook()
code_path = os.path.join(repo_path, 'code')
os.chdir(code_path)

# %% [markdown]
# Import own functions

# %%
import import_data.import_and_convert_data as import_dat
import import_data.find_paths as find_paths
import import_data.preprocessing_meta_info as meta_info
import sig_processing.segment_tasks as tasks
import movement_calc.helpfunctions as hp
import sig_processing.calc_features as feat_ext

# %% [markdown]
# ### Feature Extraction

# %% [markdown]
# Load dist-time .csv files and calculate features

# %%
folder = 'patientdata'
subs = find_paths.find_available_subs(folder)
ls_task = ['ft','oc']
ls_cond = ['m0s0', 'm1s0', 'm1s1', 'm0s1', 'm1', 'm0']
ls_cam = ['vr', 'dt', 'st']
ls_block = ['b1', 'b2', 'b3']
ls_side = ['right', 'left']

# %%
importlib.reload(import_dat)
importlib.reload(tasks)
importlib.reload(find_paths)
importlib.reload(feat_ext)

for sub in subs:
    for task in ls_task:
        for side in ls_side:
            for cond in ls_cond:
                for cam in ls_cam:
                    for block in ls_block:
                        try:                                            
                            # Load blocks from patients' blocks dir
                            dist = pd.read_csv(
                                os.path.join(
                                repo_path, 'data', sub, task, cond, 'distances', 
                                f'{block}_{sub}_{cond}_{cam}_{task}_{side}.csv'), 
                                index_col=0
                                )

                            get_feat = feat_ext.calculate_feat(dist, block, sub, cond, cam, task, side, 
                                                                to_plot = True, to_save_plot = True, to_save = True)

                        except FileNotFoundError:
                            print('No files available for combination: '
                                f'{sub, task, cond}')
# Out:
# No files available for combination: ('ul001', 'ft', 'm0s0')
# No files available for combination: ('ul001', 'ft', 'm0s0')
# No files available for combination: ('ul001', 'ft', 'm0s0')
# No files available for combination: ('ul001', 'ft', 'm0s0')
# No files available for combination: ('ul001', 'ft', 'm0s0')
# No files available for combination: ('ul001', 'ft', 'm0s0')
# No files available for combination: ('ul001', 'ft', 'm0s0')
# No files available for combination: ('ul001', 'ft', 'm0s0')
# No files available for combination: ('ul001', 'ft', 'm0s0')
# No files available for combination: ('ul001', 'ft', 'm1s0')
# No files available for combination: ('ul001', 'ft', 'm1s0')
# No files available for combination: ('ul001', 'ft', 'm1s0')
# No files available for combination: ('ul001', 'ft', 'm1s0')
# No files available for combination: ('ul001', 'ft', 'm1s0')
# No files available for combination: ('ul001', 'ft', 'm1s0')
# No files available for combination: ('ul001', 'ft', 'm1s0')
# No files available for combination: ('ul001', 'ft', 'm1s0')
# No files available for combination: ('ul001', 'ft', 'm1s0')
# No files available for combination: ('ul001', 'ft', 'm1s1')
# No files available for combination: ('ul001', 'ft', 'm1s1')
# No files available for combination: ('ul001', 'ft', 'm1s1')
# No files available for combination: ('ul001', 'ft', 'm1s1')
# No files available for combination: ('ul001', 'ft', 'm1s1')
# No files available for combination: ('ul001', 'ft', 'm1s1')
# No files available for combination: ('ul001', 'ft', 'm1s1')
# No files available for combination: ('ul001', 'ft', 'm1s1')
# No files available for combination: ('ul001', 'ft', 'm1s1')
# No files available for combination: ('ul001', 'ft', 'm0s1')
# No files available for combination: ('ul001', 'ft', 'm0s1')
# No files available for combination: ('ul001', 'ft', 'm0s1')
# No files available for combination: ('ul001', 'ft', 'm0s1')
# No files available for combination: ('ul001', 'ft', 'm0s1')
# No files available for combination: ('ul001', 'ft', 'm0s1')
# No files available for combination: ('ul001', 'ft', 'm0s1')
# No files available for combination: ('ul001', 'ft', 'm0s1')
# No files available for combination: ('ul001', 'ft', 'm0s1')
# No files available for combination: ('ul001', 'ft', 'm1')
# No files available for combination: ('ul001', 'ft', 'm1')
# No files available for combination: ('ul001', 'ft', 'm1')
# No files available for combination: ('ul001', 'ft', 'm1')
# No files available for combination: ('ul001', 'ft', 'm0')
# No files available for combination: ('ul001', 'ft', 'm0')
# No files available for combination: ('ul001', 'ft', 'm0')
# No files available for combination: ('ul001', 'ft', 'm0')
# No files available for combination: ('ul001', 'ft', 'm0')
# No files available for combination: ('ul001', 'ft', 'm0')
# No files available for combination: ('ul001', 'ft', 'm0')
# No files available for combination: ('ul001', 'ft', 'm0')
# No files available for combination: ('ul001', 'ft', 'm0')
# No files available for combination: ('ul001', 'ft', 'm0s0')
# No files available for combination: ('ul001', 'ft', 'm0s0')
# No files available for combination: ('ul001', 'ft', 'm0s0')
# No files available for combination: ('ul001', 'ft', 'm0s0')
# No files available for combination: ('ul001', 'ft', 'm0s0')
# No files available for combination: ('ul001', 'ft', 'm0s0')
# No files available for combination: ('ul001', 'ft', 'm0s0')
# No files available for combination: ('ul001', 'ft', 'm0s0')
# No files available for combination: ('ul001', 'ft', 'm0s0')
# No files available for combination: ('ul001', 'ft', 'm1s0')
# No files available for combination: ('ul001', 'ft', 'm1s0')
# No files available for combination: ('ul001', 'ft', 'm1s0')
# No files available for combination: ('ul001', 'ft', 'm1s0')
# No files available for combination: ('ul001', 'ft', 'm1s0')
# No files available for combination: ('ul001', 'ft', 'm1s0')
# No files available for combination: ('ul001', 'ft', 'm1s0')
# No files available for combination: ('ul001', 'ft', 'm1s0')
# No files available for combination: ('ul001', 'ft', 'm1s0')
# No files available for combination: ('ul001', 'ft', 'm1s1')
# No files available for combination: ('ul001', 'ft', 'm1s1')
# No files available for combination: ('ul001', 'ft', 'm1s1')
# No files available for combination: ('ul001', 'ft', 'm1s1')
# No files available for combination: ('ul001', 'ft', 'm1s1')
# No files available for combination: ('ul001', 'ft', 'm1s1')
# No files available for combination: ('ul001', 'ft', 'm1s1')
# No files available for combination: ('ul001', 'ft', 'm1s1')
# No files available for combination: ('ul001', 'ft', 'm1s1')
# No files available for combination: ('ul001', 'ft', 'm0s1')
# No files available for combination: ('ul001', 'ft', 'm0s1')
# No files available for combination: ('ul001', 'ft', 'm0s1')
# No files available for combination: ('ul001', 'ft', 'm0s1')
# No files available for combination: ('ul001', 'ft', 'm0s1')
# No files available for combination: ('ul001', 'ft', 'm0s1')
# No files available for combination: ('ul001', 'ft', 'm0s1')
# No files available for combination: ('ul001', 'ft', 'm0s1')
# No files available for combination: ('ul001', 'ft', 'm0s1')
# No files available for combination: ('ul001', 'ft', 'm1')
# No files available for combination: ('ul001', 'ft', 'm1')
# No files available for combination: ('ul001', 'ft', 'm1')
# No files available for combination: ('ul001', 'ft', 'm1')
# No files available for combination: ('ul001', 'ft', 'm0')
# No files available for combination: ('ul001', 'ft', 'm0')
# No files available for combination: ('ul001', 'ft', 'm0')
# No files available for combination: ('ul001', 'ft', 'm0')
# No files available for combination: ('ul001', 'ft', 'm0')
# No files available for combination: ('ul001', 'ft', 'm0')
# No files available for combination: ('ul001', 'ft', 'm0')
# No files available for combination: ('ul001', 'ft', 'm0')
# No files available for combination: ('ul001', 'ft', 'm0')
# No files available for combination: ('ul001', 'oc', 'm0s0')
# No files available for combination: ('ul001', 'oc', 'm0s0')
# No files available for combination: ('ul001', 'oc', 'm0s0')
# No files available for combination: ('ul001', 'oc', 'm0s0')
# No files available for combination: ('ul001', 'oc', 'm0s0')
# No files available for combination: ('ul001', 'oc', 'm0s0')
# No files available for combination: ('ul001', 'oc', 'm0s0')
# No files available for combination: ('ul001', 'oc', 'm0s0')
# No files available for combination: ('ul001', 'oc', 'm0s0')
# No files available for combination: ('ul001', 'oc', 'm1s0')
# No files available for combination: ('ul001', 'oc', 'm1s0')
# No files available for combination: ('ul001', 'oc', 'm1s0')
# No files available for combination: ('ul001', 'oc', 'm1s0')
# No files available for combination: ('ul001', 'oc', 'm1s0')
# No files available for combination: ('ul001', 'oc', 'm1s0')
# No files available for combination: ('ul001', 'oc', 'm1s0')
# No files available for combination: ('ul001', 'oc', 'm1s0')
# No files available for combination: ('ul001', 'oc', 'm1s0')
# No files available for combination: ('ul001', 'oc', 'm1s1')
# No files available for combination: ('ul001', 'oc', 'm1s1')
# No files available for combination: ('ul001', 'oc', 'm1s1')
# No files available for combination: ('ul001', 'oc', 'm1s1')
# No files available for combination: ('ul001', 'oc', 'm1s1')
# No files available for combination: ('ul001', 'oc', 'm1s1')
# No files available for combination: ('ul001', 'oc', 'm1s1')
# No files available for combination: ('ul001', 'oc', 'm1s1')
# No files available for combination: ('ul001', 'oc', 'm1s1')
# No files available for combination: ('ul001', 'oc', 'm0s1')
# No files available for combination: ('ul001', 'oc', 'm0s1')
# No files available for combination: ('ul001', 'oc', 'm0s1')
# No files available for combination: ('ul001', 'oc', 'm0s1')
# No files available for combination: ('ul001', 'oc', 'm0s1')
# No files available for combination: ('ul001', 'oc', 'm0s1')
# No files available for combination: ('ul001', 'oc', 'm0s1')
# No files available for combination: ('ul001', 'oc', 'm0s1')
# No files available for combination: ('ul001', 'oc', 'm0s1')
# No files available for combination: ('ul001', 'oc', 'm1')
# No files available for combination: ('ul001', 'oc', 'm1')
# No files available for combination: ('ul001', 'oc', 'm1')
# No files available for combination: ('ul001', 'oc', 'm1')
# No files available for combination: ('ul001', 'oc', 'm0')
# No files available for combination: ('ul001', 'oc', 'm0')
# No files available for combination: ('ul001', 'oc', 'm0')
# No files available for combination: ('ul001', 'oc', 'm0')
# No files available for combination: ('ul001', 'oc', 'm0')
# No files available for combination: ('ul001', 'oc', 'm0')
# No files available for combination: ('ul001', 'oc', 'm0')
# No files available for combination: ('ul001', 'oc', 'm0')
# No files available for combination: ('ul001', 'oc', 'm0')
# No files available for combination: ('ul001', 'oc', 'm0s0')
# No files available for combination: ('ul001', 'oc', 'm0s0')
# No files available for combination: ('ul001', 'oc', 'm0s0')
# No files available for combination: ('ul001', 'oc', 'm0s0')
# No files available for combination: ('ul001', 'oc', 'm0s0')
# No files available for combination: ('ul001', 'oc', 'm0s0')
# No files available for combination: ('ul001', 'oc', 'm0s0')
# No files available for combination: ('ul001', 'oc', 'm0s0')
# No files available for combination: ('ul001', 'oc', 'm0s0')
# No files available for combination: ('ul001', 'oc', 'm1s0')
# No files available for combination: ('ul001', 'oc', 'm1s0')
# No files available for combination: ('ul001', 'oc', 'm1s0')
# No files available for combination: ('ul001', 'oc', 'm1s0')
# No files available for combination: ('ul001', 'oc', 'm1s0')
# No files available for combination: ('ul001', 'oc', 'm1s0')
# No files available for combination: ('ul001', 'oc', 'm1s0')
# No files available for combination: ('ul001', 'oc', 'm1s0')
# No files available for combination: ('ul001', 'oc', 'm1s0')
# No files available for combination: ('ul001', 'oc', 'm1s1')
# No files available for combination: ('ul001', 'oc', 'm1s1')
# No files available for combination: ('ul001', 'oc', 'm1s1')
# No files available for combination: ('ul001', 'oc', 'm1s1')
# No files available for combination: ('ul001', 'oc', 'm1s1')
# No files available for combination: ('ul001', 'oc', 'm1s1')
# No files available for combination: ('ul001', 'oc', 'm1s1')
# No files available for combination: ('ul001', 'oc', 'm1s1')
# No files available for combination: ('ul001', 'oc', 'm1s1')
# No files available for combination: ('ul001', 'oc', 'm0s1')
# No files available for combination: ('ul001', 'oc', 'm0s1')
# No files available for combination: ('ul001', 'oc', 'm0s1')
# No files available for combination: ('ul001', 'oc', 'm0s1')
# No files available for combination: ('ul001', 'oc', 'm0s1')
# No files available for combination: ('ul001', 'oc', 'm0s1')
# No files available for combination: ('ul001', 'oc', 'm0s1')
# No files available for combination: ('ul001', 'oc', 'm0s1')
# No files available for combination: ('ul001', 'oc', 'm0s1')
# No files available for combination: ('ul001', 'oc', 'm1')
# No files available for combination: ('ul001', 'oc', 'm1')
# No files available for combination: ('ul001', 'oc', 'm1')
# No files available for combination: ('ul001', 'oc', 'm1')
# No files available for combination: ('ul001', 'oc', 'm0')
# No files available for combination: ('ul001', 'oc', 'm0')
# No files available for combination: ('ul001', 'oc', 'm0')
# No files available for combination: ('ul001', 'oc', 'm0')
# No files available for combination: ('ul001', 'oc', 'm0')
# No files available for combination: ('ul001', 'oc', 'm0')
# No files available for combination: ('ul001', 'oc', 'm0')
# No files available for combination: ('ul001', 'oc', 'm0')
# No files available for combination: ('ul001', 'oc', 'm0')
# No files available for combination: ('ul002', 'ft', 'm0s0')
# No files available for combination: ('ul002', 'ft', 'm0s0')
# No files available for combination: ('ul002', 'ft', 'm0s0')
# No files available for combination: ('ul002', 'ft', 'm0s0')
# No files available for combination: ('ul002', 'ft', 'm0s0')
# No files available for combination: ('ul002', 'ft', 'm0s0')
# No files available for combination: ('ul002', 'ft', 'm0s0')
# No files available for combination: ('ul002', 'ft', 'm0s0')
# No files available for combination: ('ul002', 'ft', 'm0s0')
# No files available for combination: ('ul002', 'ft', 'm1s0')
# No files available for combination: ('ul002', 'ft', 'm1s0')
# No files available for combination: ('ul002', 'ft', 'm1s0')
# No files available for combination: ('ul002', 'ft', 'm1s0')
# No files available for combination: ('ul002', 'ft', 'm1s0')
# No files available for combination: ('ul002', 'ft', 'm1s0')
# No files available for combination: ('ul002', 'ft', 'm1s0')
# No files available for combination: ('ul002', 'ft', 'm1s0')
# No files available for combination: ('ul002', 'ft', 'm1s0')
# No files available for combination: ('ul002', 'ft', 'm1s1')
# No files available for combination: ('ul002', 'ft', 'm1s1')
# No files available for combination: ('ul002', 'ft', 'm1s1')
# No files available for combination: ('ul002', 'ft', 'm1s1')
# No files available for combination: ('ul002', 'ft', 'm1s1')
# No files available for combination: ('ul002', 'ft', 'm1s1')
# No files available for combination: ('ul002', 'ft', 'm1s1')
# No files available for combination: ('ul002', 'ft', 'm1s1')
# No files available for combination: ('ul002', 'ft', 'm1s1')
# No files available for combination: ('ul002', 'ft', 'm0s1')
# No files available for combination: ('ul002', 'ft', 'm0s1')
# No files available for combination: ('ul002', 'ft', 'm0s1')
# No files available for combination: ('ul002', 'ft', 'm0s1')
# No files available for combination: ('ul002', 'ft', 'm0s1')
# No files available for combination: ('ul002', 'ft', 'm0s1')
# No files available for combination: ('ul002', 'ft', 'm0s1')
# No files available for combination: ('ul002', 'ft', 'm0s1')
# No files available for combination: ('ul002', 'ft', 'm0s1')
# No files available for combination: ('ul002', 'ft', 'm1')
# No files available for combination: ('ul002', 'ft', 'm1')
# No files available for combination: ('ul002', 'ft', 'm1')
# No files available for combination: ('ul002', 'ft', 'm1')
# No files available for combination: ('ul002', 'ft', 'm1')
# No files available for combination: ('ul002', 'ft', 'm0')
# No files available for combination: ('ul002', 'ft', 'm0')
# No files available for combination: ('ul002', 'ft', 'm0')
# No files available for combination: ('ul002', 'ft', 'm0')
# No files available for combination: ('ul002', 'ft', 'm0')
# No files available for combination: ('ul002', 'ft', 'm0')
# No files available for combination: ('ul002', 'ft', 'm0')
# No files available for combination: ('ul002', 'ft', 'm0')
# No files available for combination: ('ul002', 'ft', 'm0')
# No files available for combination: ('ul002', 'ft', 'm0s0')
# No files available for combination: ('ul002', 'ft', 'm0s0')
# No files available for combination: ('ul002', 'ft', 'm0s0')
# No files available for combination: ('ul002', 'ft', 'm0s0')
# No files available for combination: ('ul002', 'ft', 'm0s0')
# No files available for combination: ('ul002', 'ft', 'm0s0')
# No files available for combination: ('ul002', 'ft', 'm0s0')
# No files available for combination: ('ul002', 'ft', 'm0s0')
# No files available for combination: ('ul002', 'ft', 'm0s0')
# No files available for combination: ('ul002', 'ft', 'm1s0')
# No files available for combination: ('ul002', 'ft', 'm1s0')
# No files available for combination: ('ul002', 'ft', 'm1s0')
# No files available for combination: ('ul002', 'ft', 'm1s0')
# No files available for combination: ('ul002', 'ft', 'm1s0')
# No files available for combination: ('ul002', 'ft', 'm1s0')
# No files available for combination: ('ul002', 'ft', 'm1s0')
# No files available for combination: ('ul002', 'ft', 'm1s0')
# No files available for combination: ('ul002', 'ft', 'm1s0')
# No files available for combination: ('ul002', 'ft', 'm1s1')
# No files available for combination: ('ul002', 'ft', 'm1s1')
# No files available for combination: ('ul002', 'ft', 'm1s1')
# No files available for combination: ('ul002', 'ft', 'm1s1')
# No files available for combination: ('ul002', 'ft', 'm1s1')
# No files available for combination: ('ul002', 'ft', 'm1s1')
# No files available for combination: ('ul002', 'ft', 'm1s1')
# No files available for combination: ('ul002', 'ft', 'm1s1')
# No files available for combination: ('ul002', 'ft', 'm1s1')
# No files available for combination: ('ul002', 'ft', 'm0s1')
# No files available for combination: ('ul002', 'ft', 'm0s1')
# No files available for combination: ('ul002', 'ft', 'm0s1')
# No files available for combination: ('ul002', 'ft', 'm0s1')
# No files available for combination: ('ul002', 'ft', 'm0s1')
# No files available for combination: ('ul002', 'ft', 'm0s1')
# No files available for combination: ('ul002', 'ft', 'm0s1')
# No files available for combination: ('ul002', 'ft', 'm0s1')
# No files available for combination: ('ul002', 'ft', 'm0s1')
# No files available for combination: ('ul002', 'ft', 'm1')
# No files available for combination: ('ul002', 'ft', 'm1')
# No files available for combination: ('ul002', 'ft', 'm1')
# No files available for combination: ('ul002', 'ft', 'm1')
# No files available for combination: ('ul002', 'ft', 'm1')
# No files available for combination: ('ul002', 'ft', 'm0')
# No files available for combination: ('ul002', 'ft', 'm0')
# No files available for combination: ('ul002', 'ft', 'm0')
# No files available for combination: ('ul002', 'ft', 'm0')
# No files available for combination: ('ul002', 'ft', 'm0')
# No files available for combination: ('ul002', 'ft', 'm0')
# No files available for combination: ('ul002', 'ft', 'm0')
# No files available for combination: ('ul002', 'ft', 'm0')
# No files available for combination: ('ul002', 'ft', 'm0')
# No files available for combination: ('ul002', 'oc', 'm0s0')
# No files available for combination: ('ul002', 'oc', 'm0s0')
# No files available for combination: ('ul002', 'oc', 'm0s0')
# No files available for combination: ('ul002', 'oc', 'm0s0')
# No files available for combination: ('ul002', 'oc', 'm0s0')
# No files available for combination: ('ul002', 'oc', 'm0s0')
# No files available for combination: ('ul002', 'oc', 'm0s0')
# No files available for combination: ('ul002', 'oc', 'm0s0')
# No files available for combination: ('ul002', 'oc', 'm0s0')
# No files available for combination: ('ul002', 'oc', 'm1s0')
# No files available for combination: ('ul002', 'oc', 'm1s0')
# No files available for combination: ('ul002', 'oc', 'm1s0')
# No files available for combination: ('ul002', 'oc', 'm1s0')
# No files available for combination: ('ul002', 'oc', 'm1s0')
# No files available for combination: ('ul002', 'oc', 'm1s0')
# No files available for combination: ('ul002', 'oc', 'm1s0')
# No files available for combination: ('ul002', 'oc', 'm1s0')
# No files available for combination: ('ul002', 'oc', 'm1s0')
# No files available for combination: ('ul002', 'oc', 'm1s1')
# No files available for combination: ('ul002', 'oc', 'm1s1')
# No files available for combination: ('ul002', 'oc', 'm1s1')
# No files available for combination: ('ul002', 'oc', 'm1s1')
# No files available for combination: ('ul002', 'oc', 'm1s1')
# No files available for combination: ('ul002', 'oc', 'm1s1')
# No files available for combination: ('ul002', 'oc', 'm1s1')
# No files available for combination: ('ul002', 'oc', 'm1s1')
# No files available for combination: ('ul002', 'oc', 'm1s1')
# No files available for combination: ('ul002', 'oc', 'm0s1')
# No files available for combination: ('ul002', 'oc', 'm0s1')
# No files available for combination: ('ul002', 'oc', 'm0s1')
# No files available for combination: ('ul002', 'oc', 'm0s1')
# No files available for combination: ('ul002', 'oc', 'm0s1')
# No files available for combination: ('ul002', 'oc', 'm0s1')
# No files available for combination: ('ul002', 'oc', 'm0s1')
# No files available for combination: ('ul002', 'oc', 'm0s1')
# No files available for combination: ('ul002', 'oc', 'm0s1')
# No files available for combination: ('ul002', 'oc', 'm1')
# No files available for combination: ('ul002', 'oc', 'm1')
# No files available for combination: ('ul002', 'oc', 'm1')
# No files available for combination: ('ul002', 'oc', 'm1')
# No files available for combination: ('ul002', 'oc', 'm1')
# No files available for combination: ('ul002', 'oc', 'm0')
# No files available for combination: ('ul002', 'oc', 'm0')
# No files available for combination: ('ul002', 'oc', 'm0')
# No files available for combination: ('ul002', 'oc', 'm0')
# No files available for combination: ('ul002', 'oc', 'm0')
# No files available for combination: ('ul002', 'oc', 'm0')
# No files available for combination: ('ul002', 'oc', 'm0')
# No files available for combination: ('ul002', 'oc', 'm0')
# No files available for combination: ('ul002', 'oc', 'm0')
# No files available for combination: ('ul002', 'oc', 'm0s0')
# No files available for combination: ('ul002', 'oc', 'm0s0')
# No files available for combination: ('ul002', 'oc', 'm0s0')
# No files available for combination: ('ul002', 'oc', 'm0s0')
# No files available for combination: ('ul002', 'oc', 'm0s0')
# No files available for combination: ('ul002', 'oc', 'm0s0')
# No files available for combination: ('ul002', 'oc', 'm0s0')
# No files available for combination: ('ul002', 'oc', 'm0s0')
# No files available for combination: ('ul002', 'oc', 'm0s0')
# No files available for combination: ('ul002', 'oc', 'm1s0')
# No files available for combination: ('ul002', 'oc', 'm1s0')
# No files available for combination: ('ul002', 'oc', 'm1s0')
# No files available for combination: ('ul002', 'oc', 'm1s0')
# No files available for combination: ('ul002', 'oc', 'm1s0')
# No files available for combination: ('ul002', 'oc', 'm1s0')
# No files available for combination: ('ul002', 'oc', 'm1s0')
# No files available for combination: ('ul002', 'oc', 'm1s0')
# No files available for combination: ('ul002', 'oc', 'm1s0')
# No files available for combination: ('ul002', 'oc', 'm1s1')
# No files available for combination: ('ul002', 'oc', 'm1s1')
# No files available for combination: ('ul002', 'oc', 'm1s1')
# No files available for combination: ('ul002', 'oc', 'm1s1')
# No files available for combination: ('ul002', 'oc', 'm1s1')
# No files available for combination: ('ul002', 'oc', 'm1s1')
# No files available for combination: ('ul002', 'oc', 'm1s1')
# No files available for combination: ('ul002', 'oc', 'm1s1')
# No files available for combination: ('ul002', 'oc', 'm1s1')
# No files available for combination: ('ul002', 'oc', 'm0s1')
# No files available for combination: ('ul002', 'oc', 'm0s1')
# No files available for combination: ('ul002', 'oc', 'm0s1')
# No files available for combination: ('ul002', 'oc', 'm0s1')
# No files available for combination: ('ul002', 'oc', 'm0s1')
# No files available for combination: ('ul002', 'oc', 'm0s1')
# No files available for combination: ('ul002', 'oc', 'm0s1')
# No files available for combination: ('ul002', 'oc', 'm0s1')
# No files available for combination: ('ul002', 'oc', 'm0s1')
# No files available for combination: ('ul002', 'oc', 'm1')
# No files available for combination: ('ul002', 'oc', 'm1')
# No files available for combination: ('ul002', 'oc', 'm1')
# No files available for combination: ('ul002', 'oc', 'm1')
# No files available for combination: ('ul002', 'oc', 'm1')
# No files available for combination: ('ul002', 'oc', 'm0')
# No files available for combination: ('ul002', 'oc', 'm0')
# No files available for combination: ('ul002', 'oc', 'm0')
# No files available for combination: ('ul002', 'oc', 'm0')
# No files available for combination: ('ul002', 'oc', 'm0')
# No files available for combination: ('ul002', 'oc', 'm0')
# No files available for combination: ('ul002', 'oc', 'm0')
# No files available for combination: ('ul002', 'oc', 'm0')
# No files available for combination: ('ul002', 'oc', 'm0')
# No files available for combination: ('ul003', 'ft', 'm0s0')
# No files available for combination: ('ul003', 'ft', 'm0s0')
# No files available for combination: ('ul003', 'ft', 'm0s0')
# No files available for combination: ('ul003', 'ft', 'm0s0')
# No files available for combination: ('ul003', 'ft', 'm0s0')
# No files available for combination: ('ul003', 'ft', 'm0s0')
# No files available for combination: ('ul003', 'ft', 'm0s0')
# No files available for combination: ('ul003', 'ft', 'm0s0')
# No files available for combination: ('ul003', 'ft', 'm0s0')
# No files available for combination: ('ul003', 'ft', 'm1s0')
# No files available for combination: ('ul003', 'ft', 'm1s0')
# No files available for combination: ('ul003', 'ft', 'm1s0')
# No files available for combination: ('ul003', 'ft', 'm1s0')
# No files available for combination: ('ul003', 'ft', 'm1s0')
# No files available for combination: ('ul003', 'ft', 'm1s1')
# No files available for combination: ('ul003', 'ft', 'm1s1')
# No files available for combination: ('ul003', 'ft', 'm1s1')
# No files available for combination: ('ul003', 'ft', 'm1s1')
# No files available for combination: ('ul003', 'ft', 'm1s1')
# No files available for combination: ('ul003', 'ft', 'm0s1')
# No files available for combination: ('ul003', 'ft', 'm0s1')
# No files available for combination: ('ul003', 'ft', 'm0s1')
# No files available for combination: ('ul003', 'ft', 'm0s1')
# No files available for combination: ('ul003', 'ft', 'm0s1')
# No files available for combination: ('ul003', 'ft', 'm0s1')
# No files available for combination: ('ul003', 'ft', 'm0s1')
# No files available for combination: ('ul003', 'ft', 'm0s1')
# No files available for combination: ('ul003', 'ft', 'm0s1')
# No files available for combination: ('ul003', 'ft', 'm1')
# No files available for combination: ('ul003', 'ft', 'm1')
# No files available for combination: ('ul003', 'ft', 'm1')
# No files available for combination: ('ul003', 'ft', 'm1')
# No files available for combination: ('ul003', 'ft', 'm1')
# No files available for combination: ('ul003', 'ft', 'm1')
# No files available for combination: ('ul003', 'ft', 'm1')
# No files available for combination: ('ul003', 'ft', 'm1')
# No files available for combination: ('ul003', 'ft', 'm1')
# No files available for combination: ('ul003', 'ft', 'm0')
# No files available for combination: ('ul003', 'ft', 'm0')
# No files available for combination: ('ul003', 'ft', 'm0')
# No files available for combination: ('ul003', 'ft', 'm0')
# No files available for combination: ('ul003', 'ft', 'm0')
# No files available for combination: ('ul003', 'ft', 'm0')
# No files available for combination: ('ul003', 'ft', 'm0')
# No files available for combination: ('ul003', 'ft', 'm0')
# No files available for combination: ('ul003', 'ft', 'm0')
# No files available for combination: ('ul003', 'ft', 'm0s0')
# No files available for combination: ('ul003', 'ft', 'm0s0')
# No files available for combination: ('ul003', 'ft', 'm0s0')
# No files available for combination: ('ul003', 'ft', 'm0s0')
# No files available for combination: ('ul003', 'ft', 'm0s0')
# No files available for combination: ('ul003', 'ft', 'm0s0')
# No files available for combination: ('ul003', 'ft', 'm0s0')
# No files available for combination: ('ul003', 'ft', 'm0s0')
# No files available for combination: ('ul003', 'ft', 'm0s0')
# No files available for combination: ('ul003', 'ft', 'm1s0')
# No files available for combination: ('ul003', 'ft', 'm1s0')
# No files available for combination: ('ul003', 'ft', 'm1s0')
# No files available for combination: ('ul003', 'ft', 'm1s0')
# No files available for combination: ('ul003', 'ft', 'm1s0')
# No files available for combination: ('ul003', 'ft', 'm1s0')
# No files available for combination: ('ul003', 'ft', 'm1s0')
# No files available for combination: ('ul003', 'ft', 'm1s1')
# No files available for combination: ('ul003', 'ft', 'm1s1')
# No files available for combination: ('ul003', 'ft', 'm1s1')
# No files available for combination: ('ul003', 'ft', 'm1s1')
# No files available for combination: ('ul003', 'ft', 'm1s1')
# No files available for combination: ('ul003', 'ft', 'm1s1')
# No files available for combination: ('ul003', 'ft', 'm1s1')
# No files available for combination: ('ul003', 'ft', 'm0s1')
# No files available for combination: ('ul003', 'ft', 'm0s1')
# No files available for combination: ('ul003', 'ft', 'm0s1')
# No files available for combination: ('ul003', 'ft', 'm0s1')
# No files available for combination: ('ul003', 'ft', 'm0s1')
# No files available for combination: ('ul003', 'ft', 'm0s1')
# No files available for combination: ('ul003', 'ft', 'm0s1')
# No files available for combination: ('ul003', 'ft', 'm0s1')
# No files available for combination: ('ul003', 'ft', 'm0s1')
# No files available for combination: ('ul003', 'ft', 'm1')
# No files available for combination: ('ul003', 'ft', 'm1')
# No files available for combination: ('ul003', 'ft', 'm1')
# No files available for combination: ('ul003', 'ft', 'm1')
# No files available for combination: ('ul003', 'ft', 'm1')
# No files available for combination: ('ul003', 'ft', 'm1')
# No files available for combination: ('ul003', 'ft', 'm1')
# No files available for combination: ('ul003', 'ft', 'm1')
# No files available for combination: ('ul003', 'ft', 'm1')
# No files available for combination: ('ul003', 'ft', 'm0')
# No files available for combination: ('ul003', 'ft', 'm0')
# No files available for combination: ('ul003', 'ft', 'm0')
# No files available for combination: ('ul003', 'ft', 'm0')
# No files available for combination: ('ul003', 'ft', 'm0')
# No files available for combination: ('ul003', 'ft', 'm0')
# No files available for combination: ('ul003', 'ft', 'm0')
# No files available for combination: ('ul003', 'ft', 'm0')
# No files available for combination: ('ul003', 'ft', 'm0')
# No files available for combination: ('ul003', 'oc', 'm0s0')
# No files available for combination: ('ul003', 'oc', 'm0s0')
# No files available for combination: ('ul003', 'oc', 'm0s0')
# No files available for combination: ('ul003', 'oc', 'm0s0')
# No files available for combination: ('ul003', 'oc', 'm0s0')
# No files available for combination: ('ul003', 'oc', 'm0s0')
# No files available for combination: ('ul003', 'oc', 'm0s0')
# No files available for combination: ('ul003', 'oc', 'm0s0')
# No files available for combination: ('ul003', 'oc', 'm0s0')
# No files available for combination: ('ul003', 'oc', 'm1s0')
# No files available for combination: ('ul003', 'oc', 'm1s0')
# No files available for combination: ('ul003', 'oc', 'm1s0')
# No files available for combination: ('ul003', 'oc', 'm1s0')
# No files available for combination: ('ul003', 'oc', 'm1s0')
# No files available for combination: ('ul003', 'oc', 'm1s1')
# No files available for combination: ('ul003', 'oc', 'm1s1')
# No files available for combination: ('ul003', 'oc', 'm1s1')
# No files available for combination: ('ul003', 'oc', 'm1s1')
# No files available for combination: ('ul003', 'oc', 'm1s1')
# No files available for combination: ('ul003', 'oc', 'm0s1')
# No files available for combination: ('ul003', 'oc', 'm0s1')
# No files available for combination: ('ul003', 'oc', 'm0s1')
# No files available for combination: ('ul003', 'oc', 'm0s1')
# No files available for combination: ('ul003', 'oc', 'm0s1')
# No files available for combination: ('ul003', 'oc', 'm0s1')
# No files available for combination: ('ul003', 'oc', 'm0s1')
# No files available for combination: ('ul003', 'oc', 'm0s1')
# No files available for combination: ('ul003', 'oc', 'm0s1')
# No files available for combination: ('ul003', 'oc', 'm1')
# No files available for combination: ('ul003', 'oc', 'm1')
# No files available for combination: ('ul003', 'oc', 'm1')
# No files available for combination: ('ul003', 'oc', 'm1')
# No files available for combination: ('ul003', 'oc', 'm1')
# No files available for combination: ('ul003', 'oc', 'm1')
# No files available for combination: ('ul003', 'oc', 'm1')
# No files available for combination: ('ul003', 'oc', 'm1')
# No files available for combination: ('ul003', 'oc', 'm1')
# No files available for combination: ('ul003', 'oc', 'm0')
# No files available for combination: ('ul003', 'oc', 'm0')
# No files available for combination: ('ul003', 'oc', 'm0')
# No files available for combination: ('ul003', 'oc', 'm0')
# No files available for combination: ('ul003', 'oc', 'm0')
# No files available for combination: ('ul003', 'oc', 'm0')
# No files available for combination: ('ul003', 'oc', 'm0')
# No files available for combination: ('ul003', 'oc', 'm0')
# No files available for combination: ('ul003', 'oc', 'm0')
# No files available for combination: ('ul003', 'oc', 'm0s0')
# No files available for combination: ('ul003', 'oc', 'm0s0')
# No files available for combination: ('ul003', 'oc', 'm0s0')
# No files available for combination: ('ul003', 'oc', 'm0s0')
# No files available for combination: ('ul003', 'oc', 'm0s0')
# No files available for combination: ('ul003', 'oc', 'm0s0')
# No files available for combination: ('ul003', 'oc', 'm0s0')
# No files available for combination: ('ul003', 'oc', 'm0s0')
# No files available for combination: ('ul003', 'oc', 'm0s0')
# No files available for combination: ('ul003', 'oc', 'm1s0')
# No files available for combination: ('ul003', 'oc', 'm1s0')
# No files available for combination: ('ul003', 'oc', 'm1s0')
# No files available for combination: ('ul003', 'oc', 'm1s0')
# No files available for combination: ('ul003', 'oc', 'm1s0')
# No files available for combination: ('ul003', 'oc', 'm1s0')
# No files available for combination: ('ul003', 'oc', 'm1s0')
# No files available for combination: ('ul003', 'oc', 'm1s0')
# No files available for combination: ('ul003', 'oc', 'm1s1')
# No files available for combination: ('ul003', 'oc', 'm1s1')
# No files available for combination: ('ul003', 'oc', 'm1s1')
# No files available for combination: ('ul003', 'oc', 'm1s1')
# No files available for combination: ('ul003', 'oc', 'm1s1')
# No files available for combination: ('ul003', 'oc', 'm1s1')
# No files available for combination: ('ul003', 'oc', 'm1s1')
# No files available for combination: ('ul003', 'oc', 'm1s1')
# No files available for combination: ('ul003', 'oc', 'm1s1')
# No files available for combination: ('ul003', 'oc', 'm0s1')
# No files available for combination: ('ul003', 'oc', 'm0s1')
# No files available for combination: ('ul003', 'oc', 'm0s1')
# No files available for combination: ('ul003', 'oc', 'm0s1')
# No files available for combination: ('ul003', 'oc', 'm0s1')
# No files available for combination: ('ul003', 'oc', 'm0s1')
# No files available for combination: ('ul003', 'oc', 'm0s1')
# No files available for combination: ('ul003', 'oc', 'm0s1')
# No files available for combination: ('ul003', 'oc', 'm0s1')
# No files available for combination: ('ul003', 'oc', 'm1')
# No files available for combination: ('ul003', 'oc', 'm1')
# No files available for combination: ('ul003', 'oc', 'm1')
# No files available for combination: ('ul003', 'oc', 'm1')
# No files available for combination: ('ul003', 'oc', 'm1')
# No files available for combination: ('ul003', 'oc', 'm1')
# No files available for combination: ('ul003', 'oc', 'm1')
# No files available for combination: ('ul003', 'oc', 'm1')
# No files available for combination: ('ul003', 'oc', 'm1')
# No files available for combination: ('ul003', 'oc', 'm0')
# No files available for combination: ('ul003', 'oc', 'm0')
# No files available for combination: ('ul003', 'oc', 'm0')
# No files available for combination: ('ul003', 'oc', 'm0')
# No files available for combination: ('ul003', 'oc', 'm0')
# No files available for combination: ('ul003', 'oc', 'm0')
# No files available for combination: ('ul003', 'oc', 'm0')
# No files available for combination: ('ul003', 'oc', 'm0')
# No files available for combination: ('ul003', 'oc', 'm0')
# No files available for combination: ('ul004', 'ft', 'm0s0')
# No files available for combination: ('ul004', 'ft', 'm0s0')
# No files available for combination: ('ul004', 'ft', 'm0s0')
# No files available for combination: ('ul004', 'ft', 'm0s0')
# No files available for combination: ('ul004', 'ft', 'm0s0')
# No files available for combination: ('ul004', 'ft', 'm0s0')
# No files available for combination: ('ul004', 'ft', 'm0s0')
# No files available for combination: ('ul004', 'ft', 'm0s0')
# No files available for combination: ('ul004', 'ft', 'm0s0')
# No files available for combination: ('ul004', 'ft', 'm1s0')
# No files available for combination: ('ul004', 'ft', 'm1s0')
# No files available for combination: ('ul004', 'ft', 'm1s0')
# No files available for combination: ('ul004', 'ft', 'm1s0')
# No files available for combination: ('ul004', 'ft', 'm1s0')
# No files available for combination: ('ul004', 'ft', 'm1s1')
# No files available for combination: ('ul004', 'ft', 'm1s1')
# No files available for combination: ('ul004', 'ft', 'm1s1')
# No files available for combination: ('ul004', 'ft', 'm1s1')
# No files available for combination: ('ul004', 'ft', 'm1s1')
# No files available for combination: ('ul004', 'ft', 'm0s1')
# No files available for combination: ('ul004', 'ft', 'm0s1')
# No files available for combination: ('ul004', 'ft', 'm0s1')
# No files available for combination: ('ul004', 'ft', 'm0s1')
# No files available for combination: ('ul004', 'ft', 'm0s1')
# No files available for combination: ('ul004', 'ft', 'm0s1')
# No files available for combination: ('ul004', 'ft', 'm0s1')
# No files available for combination: ('ul004', 'ft', 'm0s1')
# No files available for combination: ('ul004', 'ft', 'm0s1')
# No files available for combination: ('ul004', 'ft', 'm1')
# No files available for combination: ('ul004', 'ft', 'm1')
# No files available for combination: ('ul004', 'ft', 'm1')
# No files available for combination: ('ul004', 'ft', 'm1')
# No files available for combination: ('ul004', 'ft', 'm1')
# No files available for combination: ('ul004', 'ft', 'm1')
# No files available for combination: ('ul004', 'ft', 'm1')
# No files available for combination: ('ul004', 'ft', 'm1')
# No files available for combination: ('ul004', 'ft', 'm1')
# No files available for combination: ('ul004', 'ft', 'm0')
# No files available for combination: ('ul004', 'ft', 'm0')
# No files available for combination: ('ul004', 'ft', 'm0')
# No files available for combination: ('ul004', 'ft', 'm0')
# No files available for combination: ('ul004', 'ft', 'm0')
# No files available for combination: ('ul004', 'ft', 'm0')
# No files available for combination: ('ul004', 'ft', 'm0')
# No files available for combination: ('ul004', 'ft', 'm0')
# No files available for combination: ('ul004', 'ft', 'm0')
# No files available for combination: ('ul004', 'ft', 'm0s0')
# No files available for combination: ('ul004', 'ft', 'm0s0')
# No files available for combination: ('ul004', 'ft', 'm0s0')
# No files available for combination: ('ul004', 'ft', 'm0s0')
# No files available for combination: ('ul004', 'ft', 'm0s0')
# No files available for combination: ('ul004', 'ft', 'm0s0')
# No files available for combination: ('ul004', 'ft', 'm0s0')
# No files available for combination: ('ul004', 'ft', 'm0s0')
# No files available for combination: ('ul004', 'ft', 'm0s0')
# No files available for combination: ('ul004', 'ft', 'm1s0')
# No files available for combination: ('ul004', 'ft', 'm1s0')
# No files available for combination: ('ul004', 'ft', 'm1s0')
# No files available for combination: ('ul004', 'ft', 'm1s0')
# No files available for combination: ('ul004', 'ft', 'm1s0')
# No files available for combination: ('ul004', 'ft', 'm1s0')
# No files available for combination: ('ul004', 'ft', 'm1s1')
# No files available for combination: ('ul004', 'ft', 'm1s1')
# No files available for combination: ('ul004', 'ft', 'm1s1')
# No files available for combination: ('ul004', 'ft', 'm1s1')
# No files available for combination: ('ul004', 'ft', 'm1s1')
# No files available for combination: ('ul004', 'ft', 'm0s1')
# No files available for combination: ('ul004', 'ft', 'm0s1')
# No files available for combination: ('ul004', 'ft', 'm0s1')
# No files available for combination: ('ul004', 'ft', 'm0s1')
# No files available for combination: ('ul004', 'ft', 'm0s1')
# No files available for combination: ('ul004', 'ft', 'm0s1')
# No files available for combination: ('ul004', 'ft', 'm0s1')
# No files available for combination: ('ul004', 'ft', 'm0s1')
# No files available for combination: ('ul004', 'ft', 'm0s1')
# No files available for combination: ('ul004', 'ft', 'm1')
# No files available for combination: ('ul004', 'ft', 'm1')
# No files available for combination: ('ul004', 'ft', 'm1')
# No files available for combination: ('ul004', 'ft', 'm1')
# No files available for combination: ('ul004', 'ft', 'm1')
# No files available for combination: ('ul004', 'ft', 'm1')
# No files available for combination: ('ul004', 'ft', 'm1')
# No files available for combination: ('ul004', 'ft', 'm1')
# No files available for combination: ('ul004', 'ft', 'm1')
# No files available for combination: ('ul004', 'ft', 'm0')
# No files available for combination: ('ul004', 'ft', 'm0')
# No files available for combination: ('ul004', 'ft', 'm0')
# No files available for combination: ('ul004', 'ft', 'm0')
# No files available for combination: ('ul004', 'ft', 'm0')
# No files available for combination: ('ul004', 'ft', 'm0')
# No files available for combination: ('ul004', 'ft', 'm0')
# No files available for combination: ('ul004', 'ft', 'm0')
# No files available for combination: ('ul004', 'ft', 'm0')
# No files available for combination: ('ul004', 'oc', 'm0s0')
# No files available for combination: ('ul004', 'oc', 'm0s0')
# No files available for combination: ('ul004', 'oc', 'm0s0')
# No files available for combination: ('ul004', 'oc', 'm0s0')
# No files available for combination: ('ul004', 'oc', 'm0s0')
# No files available for combination: ('ul004', 'oc', 'm0s0')
# No files available for combination: ('ul004', 'oc', 'm0s0')
# No files available for combination: ('ul004', 'oc', 'm0s0')
# No files available for combination: ('ul004', 'oc', 'm0s0')
# No files available for combination: ('ul004', 'oc', 'm1s0')
# No files available for combination: ('ul004', 'oc', 'm1s0')
# No files available for combination: ('ul004', 'oc', 'm1s0')
# No files available for combination: ('ul004', 'oc', 'm1s0')
# No files available for combination: ('ul004', 'oc', 'm1s0')
# No files available for combination: ('ul004', 'oc', 'm1s1')
# No files available for combination: ('ul004', 'oc', 'm1s1')
# No files available for combination: ('ul004', 'oc', 'm1s1')
# No files available for combination: ('ul004', 'oc', 'm1s1')
# No files available for combination: ('ul004', 'oc', 'm1s1')
# No files available for combination: ('ul004', 'oc', 'm0s1')
# No files available for combination: ('ul004', 'oc', 'm0s1')
# No files available for combination: ('ul004', 'oc', 'm0s1')
# No files available for combination: ('ul004', 'oc', 'm0s1')
# No files available for combination: ('ul004', 'oc', 'm0s1')
# No files available for combination: ('ul004', 'oc', 'm0s1')
# No files available for combination: ('ul004', 'oc', 'm0s1')
# No files available for combination: ('ul004', 'oc', 'm0s1')
# No files available for combination: ('ul004', 'oc', 'm0s1')
# No files available for combination: ('ul004', 'oc', 'm1')
# No files available for combination: ('ul004', 'oc', 'm1')
# No files available for combination: ('ul004', 'oc', 'm1')
# No files available for combination: ('ul004', 'oc', 'm1')
# No files available for combination: ('ul004', 'oc', 'm1')
# No files available for combination: ('ul004', 'oc', 'm1')
# No files available for combination: ('ul004', 'oc', 'm1')
# No files available for combination: ('ul004', 'oc', 'm1')
# No files available for combination: ('ul004', 'oc', 'm1')
# No files available for combination: ('ul004', 'oc', 'm0')
# No files available for combination: ('ul004', 'oc', 'm0')
# No files available for combination: ('ul004', 'oc', 'm0')
# No files available for combination: ('ul004', 'oc', 'm0')
# No files available for combination: ('ul004', 'oc', 'm0')
# No files available for combination: ('ul004', 'oc', 'm0')
# No files available for combination: ('ul004', 'oc', 'm0')
# No files available for combination: ('ul004', 'oc', 'm0')
# No files available for combination: ('ul004', 'oc', 'm0')
# No files available for combination: ('ul004', 'oc', 'm0s0')
# No files available for combination: ('ul004', 'oc', 'm0s0')
# No files available for combination: ('ul004', 'oc', 'm0s0')
# No files available for combination: ('ul004', 'oc', 'm0s0')
# No files available for combination: ('ul004', 'oc', 'm0s0')
# No files available for combination: ('ul004', 'oc', 'm0s0')
# No files available for combination: ('ul004', 'oc', 'm0s0')
# No files available for combination: ('ul004', 'oc', 'm0s0')
# No files available for combination: ('ul004', 'oc', 'm0s0')
# No files available for combination: ('ul004', 'oc', 'm1s0')
# No files available for combination: ('ul004', 'oc', 'm1s0')
# No files available for combination: ('ul004', 'oc', 'm1s0')
# No files available for combination: ('ul004', 'oc', 'm1s0')
# No files available for combination: ('ul004', 'oc', 'm1s0')
# No files available for combination: ('ul004', 'oc', 'm1s1')
# No files available for combination: ('ul004', 'oc', 'm1s1')
# No files available for combination: ('ul004', 'oc', 'm1s1')
# No files available for combination: ('ul004', 'oc', 'm1s1')
# No files available for combination: ('ul004', 'oc', 'm1s1')
# No files available for combination: ('ul004', 'oc', 'm0s1')
# No files available for combination: ('ul004', 'oc', 'm0s1')
# No files available for combination: ('ul004', 'oc', 'm0s1')
# No files available for combination: ('ul004', 'oc', 'm0s1')
# No files available for combination: ('ul004', 'oc', 'm0s1')
# No files available for combination: ('ul004', 'oc', 'm0s1')
# No files available for combination: ('ul004', 'oc', 'm0s1')
# No files available for combination: ('ul004', 'oc', 'm0s1')
# No files available for combination: ('ul004', 'oc', 'm0s1')
# No files available for combination: ('ul004', 'oc', 'm1')
# No files available for combination: ('ul004', 'oc', 'm1')
# No files available for combination: ('ul004', 'oc', 'm1')
# No files available for combination: ('ul004', 'oc', 'm1')
# No files available for combination: ('ul004', 'oc', 'm1')
# No files available for combination: ('ul004', 'oc', 'm1')
# No files available for combination: ('ul004', 'oc', 'm1')
# No files available for combination: ('ul004', 'oc', 'm1')
# No files available for combination: ('ul004', 'oc', 'm1')
# No files available for combination: ('ul004', 'oc', 'm0')
# No files available for combination: ('ul004', 'oc', 'm0')
# No files available for combination: ('ul004', 'oc', 'm0')
# No files available for combination: ('ul004', 'oc', 'm0')
# No files available for combination: ('ul004', 'oc', 'm0')
# No files available for combination: ('ul004', 'oc', 'm0')
# No files available for combination: ('ul004', 'oc', 'm0')
# No files available for combination: ('ul004', 'oc', 'm0')
# No files available for combination: ('ul004', 'oc', 'm0')
# No files available for combination: ('ul005', 'ft', 'm0s0')
# No files available for combination: ('ul005', 'ft', 'm0s0')
# No files available for combination: ('ul005', 'ft', 'm0s0')
# No files available for combination: ('ul005', 'ft', 'm0s0')
# No files available for combination: ('ul005', 'ft', 'm0s0')
# No files available for combination: ('ul005', 'ft', 'm0s0')
# No files available for combination: ('ul005', 'ft', 'm0s0')
# No files available for combination: ('ul005', 'ft', 'm0s0')
# No files available for combination: ('ul005', 'ft', 'm0s0')
# No files available for combination: ('ul005', 'ft', 'm1s0')
# No files available for combination: ('ul005', 'ft', 'm1s0')
# No files available for combination: ('ul005', 'ft', 'm1s0')
# No files available for combination: ('ul005', 'ft', 'm1s0')
# No files available for combination: ('ul005', 'ft', 'm1s0')
# No files available for combination: ('ul005', 'ft', 'm1s0')
# No files available for combination: ('ul005', 'ft', 'm1s0')
# No files available for combination: ('ul005', 'ft', 'm1s0')
# No files available for combination: ('ul005', 'ft', 'm1s0')
# No files available for combination: ('ul005', 'ft', 'm1s1')
# No files available for combination: ('ul005', 'ft', 'm1s1')
# No files available for combination: ('ul005', 'ft', 'm1s1')
# No files available for combination: ('ul005', 'ft', 'm1s1')
# No files available for combination: ('ul005', 'ft', 'm1s1')
# No files available for combination: ('ul005', 'ft', 'm0s1')
# No files available for combination: ('ul005', 'ft', 'm0s1')
# No files available for combination: ('ul005', 'ft', 'm0s1')
# No files available for combination: ('ul005', 'ft', 'm0s1')
# No files available for combination: ('ul005', 'ft', 'm0s1')
# No files available for combination: ('ul005', 'ft', 'm0s1')
# No files available for combination: ('ul005', 'ft', 'm0s1')
# No files available for combination: ('ul005', 'ft', 'm0s1')
# No files available for combination: ('ul005', 'ft', 'm0s1')
# ...
# No files available for combination: ('ul019', 'oc', 'm0s1')
# No files available for combination: ('ul019', 'oc', 'm0s1')
# No files available for combination: ('ul019', 'oc', 'm1')
# No files available for combination: ('ul019', 'oc', 'm1')
# No files available for combination: ('ul019', 'oc', 'm1')
# No files available for combination: ('ul019', 'oc', 'm1')
# No files available for combination: ('ul019', 'oc', 'm1')
# No files available for combination: ('ul019', 'oc', 'm1')
# No files available for combination: ('ul019', 'oc', 'm1')
# No files available for combination: ('ul019', 'oc', 'm1')
# No files available for combination: ('ul019', 'oc', 'm1')
# No files available for combination: ('ul019', 'oc', 'm0')
# No files available for combination: ('ul019', 'oc', 'm0')
# No files available for combination: ('ul019', 'oc', 'm0')
# No files available for combination: ('ul019', 'oc', 'm0')
# No files available for combination: ('ul019', 'oc', 'm0')
# No files available for combination: ('ul019', 'oc', 'm0')
# No files available for combination: ('ul019', 'oc', 'm0')
# No files available for combination: ('ul019', 'oc', 'm0')
# No files available for combination: ('ul019', 'oc', 'm0')
# No files available for combination: ('ul019', 'oc', 'm0s0')
# No files available for combination: ('ul019', 'oc', 'm0s0')
# No files available for combination: ('ul019', 'oc', 'm0s0')
# No files available for combination: ('ul019', 'oc', 'm0s0')
# No files available for combination: ('ul019', 'oc', 'm0s0')
# No files available for combination: ('ul019', 'oc', 'm0s0')
# No files available for combination: ('ul019', 'oc', 'm0s0')
# No files available for combination: ('ul019', 'oc', 'm1s0')
# No files available for combination: ('ul019', 'oc', 'm1s0')
# No files available for combination: ('ul019', 'oc', 'm1s0')
# No files available for combination: ('ul019', 'oc', 'm1s0')
# No files available for combination: ('ul019', 'oc', 'm1s0')
# No files available for combination: ('ul019', 'oc', 'm1s0')
# No files available for combination: ('ul019', 'oc', 'm1s0')
# No files available for combination: ('ul019', 'oc', 'm1s1')
# No files available for combination: ('ul019', 'oc', 'm1s1')
# No files available for combination: ('ul019', 'oc', 'm1s1')
# No files available for combination: ('ul019', 'oc', 'm1s1')
# No files available for combination: ('ul019', 'oc', 'm1s1')
# No files available for combination: ('ul019', 'oc', 'm1s1')
# No files available for combination: ('ul019', 'oc', 'm1s1')
# No files available for combination: ('ul019', 'oc', 'm0s1')
# No files available for combination: ('ul019', 'oc', 'm0s1')
# No files available for combination: ('ul019', 'oc', 'm0s1')
# No files available for combination: ('ul019', 'oc', 'm0s1')
# No files available for combination: ('ul019', 'oc', 'm0s1')
# No files available for combination: ('ul019', 'oc', 'm0s1')
# No files available for combination: ('ul019', 'oc', 'm0s1')
# No files available for combination: ('ul019', 'oc', 'm1')
# No files available for combination: ('ul019', 'oc', 'm1')
# No files available for combination: ('ul019', 'oc', 'm1')
# No files available for combination: ('ul019', 'oc', 'm1')
# No files available for combination: ('ul019', 'oc', 'm1')
# No files available for combination: ('ul019', 'oc', 'm1')
# No files available for combination: ('ul019', 'oc', 'm1')
# No files available for combination: ('ul019', 'oc', 'm1')
# No files available for combination: ('ul019', 'oc', 'm1')
# No files available for combination: ('ul019', 'oc', 'm0')
# No files available for combination: ('ul019', 'oc', 'm0')
# No files available for combination: ('ul019', 'oc', 'm0')
# No files available for combination: ('ul019', 'oc', 'm0')
# No files available for combination: ('ul019', 'oc', 'm0')
# No files available for combination: ('ul019', 'oc', 'm0')
# No files available for combination: ('ul019', 'oc', 'm0')
# No files available for combination: ('ul019', 'oc', 'm0')
# No files available for combination: ('ul019', 'oc', 'm0')
# No files available for combination: ('ul020', 'ft', 'm0s0')
# No files available for combination: ('ul020', 'ft', 'm0s0')
# No files available for combination: ('ul020', 'ft', 'm0s0')
# No files available for combination: ('ul020', 'ft', 'm0s0')
# No files available for combination: ('ul020', 'ft', 'm0s0')
# No files available for combination: ('ul020', 'ft', 'm0s0')
# No files available for combination: ('ul020', 'ft', 'm0s0')
# No files available for combination: ('ul020', 'ft', 'm0s0')
# No files available for combination: ('ul020', 'ft', 'm0s0')
# No files available for combination: ('ul020', 'ft', 'm1s0')
# No files available for combination: ('ul020', 'ft', 'm1s0')
# No files available for combination: ('ul020', 'ft', 'm1s0')
# No files available for combination: ('ul020', 'ft', 'm1s0')
# No files available for combination: ('ul020', 'ft', 'm1s0')
# No files available for combination: ('ul020', 'ft', 'm1s0')
# No files available for combination: ('ul020', 'ft', 'm1s0')
# No files available for combination: ('ul020', 'ft', 'm1s0')
# No files available for combination: ('ul020', 'ft', 'm1s0')
# No files available for combination: ('ul020', 'ft', 'm1s1')
# No files available for combination: ('ul020', 'ft', 'm1s1')
# No files available for combination: ('ul020', 'ft', 'm1s1')
# No files available for combination: ('ul020', 'ft', 'm1s1')
# No files available for combination: ('ul020', 'ft', 'm1s1')
# No files available for combination: ('ul020', 'ft', 'm1s1')
# No files available for combination: ('ul020', 'ft', 'm1s1')
# No files available for combination: ('ul020', 'ft', 'm1s1')
# No files available for combination: ('ul020', 'ft', 'm0s1')
# No files available for combination: ('ul020', 'ft', 'm0s1')
# No files available for combination: ('ul020', 'ft', 'm0s1')
# No files available for combination: ('ul020', 'ft', 'm0s1')
# No files available for combination: ('ul020', 'ft', 'm0s1')
# No files available for combination: ('ul020', 'ft', 'm0s1')
# No files available for combination: ('ul020', 'ft', 'm0s1')
# No files available for combination: ('ul020', 'ft', 'm0s1')
# No files available for combination: ('ul020', 'ft', 'm0s1')
# No files available for combination: ('ul020', 'ft', 'm1')
# No files available for combination: ('ul020', 'ft', 'm1')
# No files available for combination: ('ul020', 'ft', 'm1')
# No files available for combination: ('ul020', 'ft', 'm1')
# No files available for combination: ('ul020', 'ft', 'm1')
# No files available for combination: ('ul020', 'ft', 'm1')
# No files available for combination: ('ul020', 'ft', 'm1')
# No files available for combination: ('ul020', 'ft', 'm1')
# No files available for combination: ('ul020', 'ft', 'm1')
# No files available for combination: ('ul020', 'ft', 'm0')
# No files available for combination: ('ul020', 'ft', 'm0')
# No files available for combination: ('ul020', 'ft', 'm0')
# No files available for combination: ('ul020', 'ft', 'm0')
# No files available for combination: ('ul020', 'ft', 'm0')
# No files available for combination: ('ul020', 'ft', 'm0')
# No files available for combination: ('ul020', 'ft', 'm0')
# No files available for combination: ('ul020', 'ft', 'm0')
# No files available for combination: ('ul020', 'ft', 'm0')
# No files available for combination: ('ul020', 'ft', 'm0s0')
# No files available for combination: ('ul020', 'ft', 'm0s0')
# No files available for combination: ('ul020', 'ft', 'm0s0')
# No files available for combination: ('ul020', 'ft', 'm0s0')
# No files available for combination: ('ul020', 'ft', 'm0s0')
# No files available for combination: ('ul020', 'ft', 'm0s0')
# No files available for combination: ('ul020', 'ft', 'm0s0')
# No files available for combination: ('ul020', 'ft', 'm0s0')
# No files available for combination: ('ul020', 'ft', 'm0s0')
# No files available for combination: ('ul020', 'ft', 'm1s0')
# No files available for combination: ('ul020', 'ft', 'm1s0')
# No files available for combination: ('ul020', 'ft', 'm1s0')
# No files available for combination: ('ul020', 'ft', 'm1s0')
# No files available for combination: ('ul020', 'ft', 'm1s0')
# No files available for combination: ('ul020', 'ft', 'm1s0')
# No files available for combination: ('ul020', 'ft', 'm1s0')
# No files available for combination: ('ul020', 'ft', 'm1s0')
# No files available for combination: ('ul020', 'ft', 'm1s0')
# No files available for combination: ('ul020', 'ft', 'm1s1')
# No files available for combination: ('ul020', 'ft', 'm1s1')
# No files available for combination: ('ul020', 'ft', 'm1s1')
# No files available for combination: ('ul020', 'ft', 'm1s1')
# No files available for combination: ('ul020', 'ft', 'm1s1')
# No files available for combination: ('ul020', 'ft', 'm1s1')
# No files available for combination: ('ul020', 'ft', 'm0s1')
# No files available for combination: ('ul020', 'ft', 'm0s1')
# No files available for combination: ('ul020', 'ft', 'm0s1')
# No files available for combination: ('ul020', 'ft', 'm0s1')
# No files available for combination: ('ul020', 'ft', 'm0s1')
# No files available for combination: ('ul020', 'ft', 'm0s1')
# No files available for combination: ('ul020', 'ft', 'm0s1')
# No files available for combination: ('ul020', 'ft', 'm0s1')
# No files available for combination: ('ul020', 'ft', 'm0s1')
# No files available for combination: ('ul020', 'ft', 'm1')
# No files available for combination: ('ul020', 'ft', 'm1')
# No files available for combination: ('ul020', 'ft', 'm1')
# No files available for combination: ('ul020', 'ft', 'm1')
# No files available for combination: ('ul020', 'ft', 'm1')
# No files available for combination: ('ul020', 'ft', 'm1')
# No files available for combination: ('ul020', 'ft', 'm1')
# No files available for combination: ('ul020', 'ft', 'm1')
# No files available for combination: ('ul020', 'ft', 'm1')
# No files available for combination: ('ul020', 'ft', 'm0')
# No files available for combination: ('ul020', 'ft', 'm0')
# No files available for combination: ('ul020', 'ft', 'm0')
# No files available for combination: ('ul020', 'ft', 'm0')
# No files available for combination: ('ul020', 'ft', 'm0')
# No files available for combination: ('ul020', 'ft', 'm0')
# No files available for combination: ('ul020', 'ft', 'm0')
# No files available for combination: ('ul020', 'ft', 'm0')
# No files available for combination: ('ul020', 'ft', 'm0')
# No files available for combination: ('ul020', 'oc', 'm0s0')
# No files available for combination: ('ul020', 'oc', 'm0s0')
# No files available for combination: ('ul020', 'oc', 'm0s0')
# No files available for combination: ('ul020', 'oc', 'm0s0')
# No files available for combination: ('ul020', 'oc', 'm0s0')
# No files available for combination: ('ul020', 'oc', 'm0s0')
# No files available for combination: ('ul020', 'oc', 'm0s0')
# No files available for combination: ('ul020', 'oc', 'm1s0')
# No files available for combination: ('ul020', 'oc', 'm1s0')
# No files available for combination: ('ul020', 'oc', 'm1s0')
# No files available for combination: ('ul020', 'oc', 'm1s0')
# No files available for combination: ('ul020', 'oc', 'm1s0')
# No files available for combination: ('ul020', 'oc', 'm1s0')
# No files available for combination: ('ul020', 'oc', 'm1s0')
# No files available for combination: ('ul020', 'oc', 'm1s0')
# No files available for combination: ('ul020', 'oc', 'm1s0')
# No files available for combination: ('ul020', 'oc', 'm1s1')
# No files available for combination: ('ul020', 'oc', 'm1s1')
# No files available for combination: ('ul020', 'oc', 'm1s1')
# No files available for combination: ('ul020', 'oc', 'm1s1')
# No files available for combination: ('ul020', 'oc', 'm1s1')
# No files available for combination: ('ul020', 'oc', 'm1s1')
# No files available for combination: ('ul020', 'oc', 'm1s1')
# No files available for combination: ('ul020', 'oc', 'm0s1')
# No files available for combination: ('ul020', 'oc', 'm0s1')
# No files available for combination: ('ul020', 'oc', 'm0s1')
# No files available for combination: ('ul020', 'oc', 'm0s1')
# No files available for combination: ('ul020', 'oc', 'm0s1')
# No files available for combination: ('ul020', 'oc', 'm0s1')
# No files available for combination: ('ul020', 'oc', 'm0s1')
# No files available for combination: ('ul020', 'oc', 'm0s1')
# No files available for combination: ('ul020', 'oc', 'm0s1')
# No files available for combination: ('ul020', 'oc', 'm1')
# No files available for combination: ('ul020', 'oc', 'm1')
# No files available for combination: ('ul020', 'oc', 'm1')
# No files available for combination: ('ul020', 'oc', 'm1')
# No files available for combination: ('ul020', 'oc', 'm1')
# No files available for combination: ('ul020', 'oc', 'm1')
# No files available for combination: ('ul020', 'oc', 'm1')
# No files available for combination: ('ul020', 'oc', 'm1')
# No files available for combination: ('ul020', 'oc', 'm1')
# No files available for combination: ('ul020', 'oc', 'm0')
# No files available for combination: ('ul020', 'oc', 'm0')
# No files available for combination: ('ul020', 'oc', 'm0')
# No files available for combination: ('ul020', 'oc', 'm0')
# No files available for combination: ('ul020', 'oc', 'm0')
# No files available for combination: ('ul020', 'oc', 'm0')
# No files available for combination: ('ul020', 'oc', 'm0')
# No files available for combination: ('ul020', 'oc', 'm0')
# No files available for combination: ('ul020', 'oc', 'm0')
# No files available for combination: ('ul020', 'oc', 'm0s0')
# No files available for combination: ('ul020', 'oc', 'm0s0')
# No files available for combination: ('ul020', 'oc', 'm0s0')
# No files available for combination: ('ul020', 'oc', 'm0s0')
# No files available for combination: ('ul020', 'oc', 'm0s0')
# No files available for combination: ('ul020', 'oc', 'm0s0')
# No files available for combination: ('ul020', 'oc', 'm0s0')
# No files available for combination: ('ul020', 'oc', 'm1s0')
# No files available for combination: ('ul020', 'oc', 'm1s0')
# No files available for combination: ('ul020', 'oc', 'm1s0')
# No files available for combination: ('ul020', 'oc', 'm1s0')
# No files available for combination: ('ul020', 'oc', 'm1s0')
# No files available for combination: ('ul020', 'oc', 'm1s0')
# No files available for combination: ('ul020', 'oc', 'm1s0')
# No files available for combination: ('ul020', 'oc', 'm1s0')
# No files available for combination: ('ul020', 'oc', 'm1s0')
# No files available for combination: ('ul020', 'oc', 'm1s1')
# No files available for combination: ('ul020', 'oc', 'm1s1')
# No files available for combination: ('ul020', 'oc', 'm1s1')
# No files available for combination: ('ul020', 'oc', 'm1s1')
# No files available for combination: ('ul020', 'oc', 'm1s1')
# No files available for combination: ('ul020', 'oc', 'm1s1')
# No files available for combination: ('ul020', 'oc', 'm1s1')
# No files available for combination: ('ul020', 'oc', 'm0s1')
# No files available for combination: ('ul020', 'oc', 'm0s1')
# No files available for combination: ('ul020', 'oc', 'm0s1')
# No files available for combination: ('ul020', 'oc', 'm0s1')
# No files available for combination: ('ul020', 'oc', 'm0s1')
# No files available for combination: ('ul020', 'oc', 'm0s1')
# No files available for combination: ('ul020', 'oc', 'm0s1')
# No files available for combination: ('ul020', 'oc', 'm0s1')
# No files available for combination: ('ul020', 'oc', 'm0s1')
# No files available for combination: ('ul020', 'oc', 'm1')
# No files available for combination: ('ul020', 'oc', 'm1')
# No files available for combination: ('ul020', 'oc', 'm1')
# No files available for combination: ('ul020', 'oc', 'm1')
# No files available for combination: ('ul020', 'oc', 'm1')
# No files available for combination: ('ul020', 'oc', 'm1')
# No files available for combination: ('ul020', 'oc', 'm1')
# No files available for combination: ('ul020', 'oc', 'm1')
# No files available for combination: ('ul020', 'oc', 'm1')
# No files available for combination: ('ul020', 'oc', 'm0')
# No files available for combination: ('ul020', 'oc', 'm0')
# No files available for combination: ('ul020', 'oc', 'm0')
# No files available for combination: ('ul020', 'oc', 'm0')
# No files available for combination: ('ul020', 'oc', 'm0')
# No files available for combination: ('ul020', 'oc', 'm0')
# No files available for combination: ('ul020', 'oc', 'm0')
# No files available for combination: ('ul020', 'oc', 'm0')
# No files available for combination: ('ul020', 'oc', 'm0')

# %% [markdown]
# Function that creates dataframe with all features per task

# %%
def get_scores(sub, cond, cam, task, side, block):

    """
    
    """

    read_scores = pd.read_excel(
        os.path.join(
        find_paths.find_onedrive_path('patientdata'),
        f'scores_JB_JH_JR.xlsx'),
        usecols='A:I'
        )

    read_scores.set_index('sub_cond_cam', inplace = True)

    if side == 'left': side='lh'
    elif side == 'right': side='rh'
    
    # read scores for all blocks of a subject in the same cond, cam per side
    ext_scores = read_scores.loc[f'{sub}_{cond}_{cam}'][f'{task}_{side}']

    if type(ext_scores) != float:
        ls_int_sc = [int(s) for s in ext_scores if s in ['0', '1', '2', '3', '4']]
        
        if block == 'b1':
            score = ls_int_sc[0]
        elif block == 'b2':
            score = ls_int_sc[1]
        elif block == 'b3':
            score = ls_int_sc[2]
        else:
            print(f'no scores for block {block} or block does not exist')
        return score

# %%
subs = find_paths.find_available_subs(folder)
task = 'oc'
list_of_feats = []
files = []
for sub in subs:
    for side in ls_side:
        for cond in ls_cond:
            for cam in ls_cam:
                for block in ls_block:
                    try:
                        file = os.path.join(repo_path,'features', sub, task, cond, 'features_block',f'{block}_{sub}_{cond}_{cam}_{task}_{side}.json')
                        if os.path.exists(file):
                            files.append(f'{block}_{sub}_{cond}_{cam}_{task}_{side}.json')
                        with open(file) as f:
                            load_json = json.load(f)
                            
                        fts = np.array([load_json[key] for key in load_json.keys()]).ravel()
                        list_of_feats.append(fts)
                        feat_names = load_json.keys()

                        all_feats = np.array(list_of_feats) # import updrs score for every block (is 'X' for prediction)
                        df_fts = pd.DataFrame(data=all_feats, columns=feat_names)
                        if 'file' not in df_fts.columns:
                            df_fts.insert(loc=0, column='file', value=files)
                        
                    except FileNotFoundError:
                        print('No files available for combination: '
                            f'{sub, task, cond}')
# Out:
# No files available for combination: ('ul001', 'oc', 'm0s0')
# No files available for combination: ('ul001', 'oc', 'm0s0')
# No files available for combination: ('ul001', 'oc', 'm0s0')
# No files available for combination: ('ul001', 'oc', 'm0s0')
# No files available for combination: ('ul001', 'oc', 'm0s0')
# No files available for combination: ('ul001', 'oc', 'm0s0')
# No files available for combination: ('ul001', 'oc', 'm0s0')
# No files available for combination: ('ul001', 'oc', 'm0s0')
# No files available for combination: ('ul001', 'oc', 'm0s0')
# No files available for combination: ('ul001', 'oc', 'm1s0')
# No files available for combination: ('ul001', 'oc', 'm1s0')
# No files available for combination: ('ul001', 'oc', 'm1s0')
# No files available for combination: ('ul001', 'oc', 'm1s0')
# No files available for combination: ('ul001', 'oc', 'm1s0')
# No files available for combination: ('ul001', 'oc', 'm1s0')
# No files available for combination: ('ul001', 'oc', 'm1s0')
# No files available for combination: ('ul001', 'oc', 'm1s0')
# No files available for combination: ('ul001', 'oc', 'm1s0')
# No files available for combination: ('ul001', 'oc', 'm1s1')
# No files available for combination: ('ul001', 'oc', 'm1s1')
# No files available for combination: ('ul001', 'oc', 'm1s1')
# No files available for combination: ('ul001', 'oc', 'm1s1')
# No files available for combination: ('ul001', 'oc', 'm1s1')
# No files available for combination: ('ul001', 'oc', 'm1s1')
# No files available for combination: ('ul001', 'oc', 'm1s1')
# No files available for combination: ('ul001', 'oc', 'm1s1')
# No files available for combination: ('ul001', 'oc', 'm1s1')
# No files available for combination: ('ul001', 'oc', 'm0s1')
# No files available for combination: ('ul001', 'oc', 'm0s1')
# No files available for combination: ('ul001', 'oc', 'm0s1')
# No files available for combination: ('ul001', 'oc', 'm0s1')
# No files available for combination: ('ul001', 'oc', 'm0s1')
# No files available for combination: ('ul001', 'oc', 'm0s1')
# No files available for combination: ('ul001', 'oc', 'm0s1')
# No files available for combination: ('ul001', 'oc', 'm0s1')
# No files available for combination: ('ul001', 'oc', 'm0s1')
# No files available for combination: ('ul001', 'oc', 'm1')
# No files available for combination: ('ul001', 'oc', 'm1')
# No files available for combination: ('ul001', 'oc', 'm1')
# No files available for combination: ('ul001', 'oc', 'm1')
# No files available for combination: ('ul001', 'oc', 'm0')
# No files available for combination: ('ul001', 'oc', 'm0')
# No files available for combination: ('ul001', 'oc', 'm0')
# No files available for combination: ('ul001', 'oc', 'm0')
# No files available for combination: ('ul001', 'oc', 'm0')
# No files available for combination: ('ul001', 'oc', 'm0')
# No files available for combination: ('ul001', 'oc', 'm0')
# No files available for combination: ('ul001', 'oc', 'm0')
# No files available for combination: ('ul001', 'oc', 'm0')
# No files available for combination: ('ul001', 'oc', 'm0s0')
# No files available for combination: ('ul001', 'oc', 'm0s0')
# No files available for combination: ('ul001', 'oc', 'm0s0')
# No files available for combination: ('ul001', 'oc', 'm0s0')
# No files available for combination: ('ul001', 'oc', 'm0s0')
# No files available for combination: ('ul001', 'oc', 'm0s0')
# No files available for combination: ('ul001', 'oc', 'm0s0')
# No files available for combination: ('ul001', 'oc', 'm0s0')
# No files available for combination: ('ul001', 'oc', 'm0s0')
# No files available for combination: ('ul001', 'oc', 'm1s0')
# No files available for combination: ('ul001', 'oc', 'm1s0')
# No files available for combination: ('ul001', 'oc', 'm1s0')
# No files available for combination: ('ul001', 'oc', 'm1s0')
# No files available for combination: ('ul001', 'oc', 'm1s0')
# No files available for combination: ('ul001', 'oc', 'm1s0')
# No files available for combination: ('ul001', 'oc', 'm1s0')
# No files available for combination: ('ul001', 'oc', 'm1s0')
# No files available for combination: ('ul001', 'oc', 'm1s0')
# No files available for combination: ('ul001', 'oc', 'm1s1')
# No files available for combination: ('ul001', 'oc', 'm1s1')
# No files available for combination: ('ul001', 'oc', 'm1s1')
# No files available for combination: ('ul001', 'oc', 'm1s1')
# No files available for combination: ('ul001', 'oc', 'm1s1')
# No files available for combination: ('ul001', 'oc', 'm1s1')
# No files available for combination: ('ul001', 'oc', 'm1s1')
# No files available for combination: ('ul001', 'oc', 'm1s1')
# No files available for combination: ('ul001', 'oc', 'm1s1')
# No files available for combination: ('ul001', 'oc', 'm0s1')
# No files available for combination: ('ul001', 'oc', 'm0s1')
# No files available for combination: ('ul001', 'oc', 'm0s1')
# No files available for combination: ('ul001', 'oc', 'm0s1')
# No files available for combination: ('ul001', 'oc', 'm0s1')
# No files available for combination: ('ul001', 'oc', 'm0s1')
# No files available for combination: ('ul001', 'oc', 'm0s1')
# No files available for combination: ('ul001', 'oc', 'm0s1')
# No files available for combination: ('ul001', 'oc', 'm0s1')
# No files available for combination: ('ul001', 'oc', 'm1')
# No files available for combination: ('ul001', 'oc', 'm1')
# No files available for combination: ('ul001', 'oc', 'm1')
# No files available for combination: ('ul001', 'oc', 'm1')
# No files available for combination: ('ul001', 'oc', 'm0')
# No files available for combination: ('ul001', 'oc', 'm0')
# No files available for combination: ('ul001', 'oc', 'm0')
# No files available for combination: ('ul001', 'oc', 'm0')
# No files available for combination: ('ul001', 'oc', 'm0')
# No files available for combination: ('ul001', 'oc', 'm0')
# No files available for combination: ('ul001', 'oc', 'm0')
# No files available for combination: ('ul001', 'oc', 'm0')
# No files available for combination: ('ul001', 'oc', 'm0')
# No files available for combination: ('ul002', 'oc', 'm0s0')
# No files available for combination: ('ul002', 'oc', 'm0s0')
# No files available for combination: ('ul002', 'oc', 'm0s0')
# No files available for combination: ('ul002', 'oc', 'm0s0')
# No files available for combination: ('ul002', 'oc', 'm0s0')
# No files available for combination: ('ul002', 'oc', 'm0s0')
# No files available for combination: ('ul002', 'oc', 'm0s0')
# No files available for combination: ('ul002', 'oc', 'm0s0')
# No files available for combination: ('ul002', 'oc', 'm0s0')
# No files available for combination: ('ul002', 'oc', 'm1s0')
# No files available for combination: ('ul002', 'oc', 'm1s0')
# No files available for combination: ('ul002', 'oc', 'm1s0')
# No files available for combination: ('ul002', 'oc', 'm1s0')
# No files available for combination: ('ul002', 'oc', 'm1s0')
# No files available for combination: ('ul002', 'oc', 'm1s0')
# No files available for combination: ('ul002', 'oc', 'm1s0')
# No files available for combination: ('ul002', 'oc', 'm1s0')
# No files available for combination: ('ul002', 'oc', 'm1s0')
# No files available for combination: ('ul002', 'oc', 'm1s1')
# No files available for combination: ('ul002', 'oc', 'm1s1')
# No files available for combination: ('ul002', 'oc', 'm1s1')
# No files available for combination: ('ul002', 'oc', 'm1s1')
# No files available for combination: ('ul002', 'oc', 'm1s1')
# No files available for combination: ('ul002', 'oc', 'm1s1')
# No files available for combination: ('ul002', 'oc', 'm1s1')
# No files available for combination: ('ul002', 'oc', 'm1s1')
# No files available for combination: ('ul002', 'oc', 'm1s1')
# No files available for combination: ('ul002', 'oc', 'm0s1')
# No files available for combination: ('ul002', 'oc', 'm0s1')
# No files available for combination: ('ul002', 'oc', 'm0s1')
# No files available for combination: ('ul002', 'oc', 'm0s1')
# No files available for combination: ('ul002', 'oc', 'm0s1')
# No files available for combination: ('ul002', 'oc', 'm0s1')
# No files available for combination: ('ul002', 'oc', 'm0s1')
# No files available for combination: ('ul002', 'oc', 'm0s1')
# No files available for combination: ('ul002', 'oc', 'm0s1')
# No files available for combination: ('ul002', 'oc', 'm1')
# No files available for combination: ('ul002', 'oc', 'm1')
# No files available for combination: ('ul002', 'oc', 'm1')
# No files available for combination: ('ul002', 'oc', 'm1')
# No files available for combination: ('ul002', 'oc', 'm1')
# No files available for combination: ('ul002', 'oc', 'm0')
# No files available for combination: ('ul002', 'oc', 'm0')
# No files available for combination: ('ul002', 'oc', 'm0')
# No files available for combination: ('ul002', 'oc', 'm0')
# No files available for combination: ('ul002', 'oc', 'm0')
# No files available for combination: ('ul002', 'oc', 'm0')
# No files available for combination: ('ul002', 'oc', 'm0')
# No files available for combination: ('ul002', 'oc', 'm0')
# No files available for combination: ('ul002', 'oc', 'm0')
# No files available for combination: ('ul002', 'oc', 'm0s0')
# No files available for combination: ('ul002', 'oc', 'm0s0')
# No files available for combination: ('ul002', 'oc', 'm0s0')
# No files available for combination: ('ul002', 'oc', 'm0s0')
# No files available for combination: ('ul002', 'oc', 'm0s0')
# No files available for combination: ('ul002', 'oc', 'm0s0')
# No files available for combination: ('ul002', 'oc', 'm0s0')
# No files available for combination: ('ul002', 'oc', 'm0s0')
# No files available for combination: ('ul002', 'oc', 'm0s0')
# No files available for combination: ('ul002', 'oc', 'm1s0')
# No files available for combination: ('ul002', 'oc', 'm1s0')
# No files available for combination: ('ul002', 'oc', 'm1s0')
# No files available for combination: ('ul002', 'oc', 'm1s0')
# No files available for combination: ('ul002', 'oc', 'm1s0')
# No files available for combination: ('ul002', 'oc', 'm1s0')
# No files available for combination: ('ul002', 'oc', 'm1s0')
# No files available for combination: ('ul002', 'oc', 'm1s0')
# No files available for combination: ('ul002', 'oc', 'm1s0')
# No files available for combination: ('ul002', 'oc', 'm1s1')
# No files available for combination: ('ul002', 'oc', 'm1s1')
# No files available for combination: ('ul002', 'oc', 'm1s1')
# No files available for combination: ('ul002', 'oc', 'm1s1')
# No files available for combination: ('ul002', 'oc', 'm1s1')
# No files available for combination: ('ul002', 'oc', 'm1s1')
# No files available for combination: ('ul002', 'oc', 'm1s1')
# No files available for combination: ('ul002', 'oc', 'm1s1')
# No files available for combination: ('ul002', 'oc', 'm1s1')
# No files available for combination: ('ul002', 'oc', 'm0s1')
# No files available for combination: ('ul002', 'oc', 'm0s1')
# No files available for combination: ('ul002', 'oc', 'm0s1')
# No files available for combination: ('ul002', 'oc', 'm0s1')
# No files available for combination: ('ul002', 'oc', 'm0s1')
# No files available for combination: ('ul002', 'oc', 'm0s1')
# No files available for combination: ('ul002', 'oc', 'm0s1')
# No files available for combination: ('ul002', 'oc', 'm0s1')
# No files available for combination: ('ul002', 'oc', 'm0s1')
# No files available for combination: ('ul002', 'oc', 'm1')
# No files available for combination: ('ul002', 'oc', 'm1')
# No files available for combination: ('ul002', 'oc', 'm1')
# No files available for combination: ('ul002', 'oc', 'm1')
# No files available for combination: ('ul002', 'oc', 'm1')
# No files available for combination: ('ul002', 'oc', 'm0')
# No files available for combination: ('ul002', 'oc', 'm0')
# No files available for combination: ('ul002', 'oc', 'm0')
# No files available for combination: ('ul002', 'oc', 'm0')
# No files available for combination: ('ul002', 'oc', 'm0')
# No files available for combination: ('ul002', 'oc', 'm0')
# No files available for combination: ('ul002', 'oc', 'm0')
# No files available for combination: ('ul002', 'oc', 'm0')
# No files available for combination: ('ul002', 'oc', 'm0')
# No files available for combination: ('ul003', 'oc', 'm0s0')
# No files available for combination: ('ul003', 'oc', 'm0s0')
# No files available for combination: ('ul003', 'oc', 'm0s0')
# No files available for combination: ('ul003', 'oc', 'm0s0')
# No files available for combination: ('ul003', 'oc', 'm0s0')
# No files available for combination: ('ul003', 'oc', 'm0s0')
# No files available for combination: ('ul003', 'oc', 'm0s0')
# No files available for combination: ('ul003', 'oc', 'm0s0')
# No files available for combination: ('ul003', 'oc', 'm0s0')
# No files available for combination: ('ul003', 'oc', 'm1s0')
# No files available for combination: ('ul003', 'oc', 'm1s0')
# No files available for combination: ('ul003', 'oc', 'm1s0')
# No files available for combination: ('ul003', 'oc', 'm1s0')
# No files available for combination: ('ul003', 'oc', 'm1s0')
# No files available for combination: ('ul003', 'oc', 'm1s1')
# No files available for combination: ('ul003', 'oc', 'm1s1')
# No files available for combination: ('ul003', 'oc', 'm1s1')
# No files available for combination: ('ul003', 'oc', 'm1s1')
# No files available for combination: ('ul003', 'oc', 'm1s1')
# No files available for combination: ('ul003', 'oc', 'm0s1')
# No files available for combination: ('ul003', 'oc', 'm0s1')
# No files available for combination: ('ul003', 'oc', 'm0s1')
# No files available for combination: ('ul003', 'oc', 'm0s1')
# No files available for combination: ('ul003', 'oc', 'm0s1')
# No files available for combination: ('ul003', 'oc', 'm0s1')
# No files available for combination: ('ul003', 'oc', 'm0s1')
# No files available for combination: ('ul003', 'oc', 'm0s1')
# No files available for combination: ('ul003', 'oc', 'm0s1')
# No files available for combination: ('ul003', 'oc', 'm1')
# No files available for combination: ('ul003', 'oc', 'm1')
# No files available for combination: ('ul003', 'oc', 'm1')
# No files available for combination: ('ul003', 'oc', 'm1')
# No files available for combination: ('ul003', 'oc', 'm1')
# No files available for combination: ('ul003', 'oc', 'm1')
# No files available for combination: ('ul003', 'oc', 'm1')
# No files available for combination: ('ul003', 'oc', 'm1')
# No files available for combination: ('ul003', 'oc', 'm1')
# No files available for combination: ('ul003', 'oc', 'm0')
# No files available for combination: ('ul003', 'oc', 'm0')
# No files available for combination: ('ul003', 'oc', 'm0')
# No files available for combination: ('ul003', 'oc', 'm0')
# No files available for combination: ('ul003', 'oc', 'm0')
# No files available for combination: ('ul003', 'oc', 'm0')
# No files available for combination: ('ul003', 'oc', 'm0')
# No files available for combination: ('ul003', 'oc', 'm0')
# No files available for combination: ('ul003', 'oc', 'm0')
# No files available for combination: ('ul003', 'oc', 'm0s0')
# No files available for combination: ('ul003', 'oc', 'm0s0')
# No files available for combination: ('ul003', 'oc', 'm0s0')
# No files available for combination: ('ul003', 'oc', 'm0s0')
# No files available for combination: ('ul003', 'oc', 'm0s0')
# No files available for combination: ('ul003', 'oc', 'm0s0')
# No files available for combination: ('ul003', 'oc', 'm0s0')
# No files available for combination: ('ul003', 'oc', 'm0s0')
# No files available for combination: ('ul003', 'oc', 'm0s0')
# No files available for combination: ('ul003', 'oc', 'm1s0')
# No files available for combination: ('ul003', 'oc', 'm1s0')
# No files available for combination: ('ul003', 'oc', 'm1s0')
# No files available for combination: ('ul003', 'oc', 'm1s0')
# No files available for combination: ('ul003', 'oc', 'm1s0')
# No files available for combination: ('ul003', 'oc', 'm1s0')
# No files available for combination: ('ul003', 'oc', 'm1s0')
# No files available for combination: ('ul003', 'oc', 'm1s0')
# No files available for combination: ('ul003', 'oc', 'm1s1')
# No files available for combination: ('ul003', 'oc', 'm1s1')
# No files available for combination: ('ul003', 'oc', 'm1s1')
# No files available for combination: ('ul003', 'oc', 'm1s1')
# No files available for combination: ('ul003', 'oc', 'm1s1')
# No files available for combination: ('ul003', 'oc', 'm1s1')
# No files available for combination: ('ul003', 'oc', 'm1s1')
# No files available for combination: ('ul003', 'oc', 'm1s1')
# No files available for combination: ('ul003', 'oc', 'm1s1')
# No files available for combination: ('ul003', 'oc', 'm0s1')
# No files available for combination: ('ul003', 'oc', 'm0s1')
# No files available for combination: ('ul003', 'oc', 'm0s1')
# No files available for combination: ('ul003', 'oc', 'm0s1')
# No files available for combination: ('ul003', 'oc', 'm0s1')
# No files available for combination: ('ul003', 'oc', 'm0s1')
# No files available for combination: ('ul003', 'oc', 'm0s1')
# No files available for combination: ('ul003', 'oc', 'm0s1')
# No files available for combination: ('ul003', 'oc', 'm0s1')
# No files available for combination: ('ul003', 'oc', 'm1')
# No files available for combination: ('ul003', 'oc', 'm1')
# No files available for combination: ('ul003', 'oc', 'm1')
# No files available for combination: ('ul003', 'oc', 'm1')
# No files available for combination: ('ul003', 'oc', 'm1')
# No files available for combination: ('ul003', 'oc', 'm1')
# No files available for combination: ('ul003', 'oc', 'm1')
# No files available for combination: ('ul003', 'oc', 'm1')
# No files available for combination: ('ul003', 'oc', 'm1')
# No files available for combination: ('ul003', 'oc', 'm0')
# No files available for combination: ('ul003', 'oc', 'm0')
# No files available for combination: ('ul003', 'oc', 'm0')
# No files available for combination: ('ul003', 'oc', 'm0')
# No files available for combination: ('ul003', 'oc', 'm0')
# No files available for combination: ('ul003', 'oc', 'm0')
# No files available for combination: ('ul003', 'oc', 'm0')
# No files available for combination: ('ul003', 'oc', 'm0')
# No files available for combination: ('ul003', 'oc', 'm0')
# No files available for combination: ('ul004', 'oc', 'm0s0')
# No files available for combination: ('ul004', 'oc', 'm0s0')
# No files available for combination: ('ul004', 'oc', 'm0s0')
# No files available for combination: ('ul004', 'oc', 'm0s0')
# No files available for combination: ('ul004', 'oc', 'm0s0')
# No files available for combination: ('ul004', 'oc', 'm0s0')
# No files available for combination: ('ul004', 'oc', 'm0s0')
# No files available for combination: ('ul004', 'oc', 'm0s0')
# No files available for combination: ('ul004', 'oc', 'm0s0')
# No files available for combination: ('ul004', 'oc', 'm1s0')
# No files available for combination: ('ul004', 'oc', 'm1s0')
# No files available for combination: ('ul004', 'oc', 'm1s0')
# No files available for combination: ('ul004', 'oc', 'm1s0')
# No files available for combination: ('ul004', 'oc', 'm1s0')
# No files available for combination: ('ul004', 'oc', 'm1s1')
# No files available for combination: ('ul004', 'oc', 'm1s1')
# No files available for combination: ('ul004', 'oc', 'm1s1')
# No files available for combination: ('ul004', 'oc', 'm1s1')
# No files available for combination: ('ul004', 'oc', 'm1s1')
# No files available for combination: ('ul004', 'oc', 'm0s1')
# No files available for combination: ('ul004', 'oc', 'm0s1')
# No files available for combination: ('ul004', 'oc', 'm0s1')
# No files available for combination: ('ul004', 'oc', 'm0s1')
# No files available for combination: ('ul004', 'oc', 'm0s1')
# No files available for combination: ('ul004', 'oc', 'm0s1')
# No files available for combination: ('ul004', 'oc', 'm0s1')
# No files available for combination: ('ul004', 'oc', 'm0s1')
# No files available for combination: ('ul004', 'oc', 'm0s1')
# No files available for combination: ('ul004', 'oc', 'm1')
# No files available for combination: ('ul004', 'oc', 'm1')
# No files available for combination: ('ul004', 'oc', 'm1')
# No files available for combination: ('ul004', 'oc', 'm1')
# No files available for combination: ('ul004', 'oc', 'm1')
# No files available for combination: ('ul004', 'oc', 'm1')
# No files available for combination: ('ul004', 'oc', 'm1')
# No files available for combination: ('ul004', 'oc', 'm1')
# No files available for combination: ('ul004', 'oc', 'm1')
# No files available for combination: ('ul004', 'oc', 'm0')
# No files available for combination: ('ul004', 'oc', 'm0')
# No files available for combination: ('ul004', 'oc', 'm0')
# No files available for combination: ('ul004', 'oc', 'm0')
# No files available for combination: ('ul004', 'oc', 'm0')
# No files available for combination: ('ul004', 'oc', 'm0')
# No files available for combination: ('ul004', 'oc', 'm0')
# No files available for combination: ('ul004', 'oc', 'm0')
# No files available for combination: ('ul004', 'oc', 'm0')
# No files available for combination: ('ul004', 'oc', 'm0s0')
# No files available for combination: ('ul004', 'oc', 'm0s0')
# No files available for combination: ('ul004', 'oc', 'm0s0')
# No files available for combination: ('ul004', 'oc', 'm0s0')
# No files available for combination: ('ul004', 'oc', 'm0s0')
# No files available for combination: ('ul004', 'oc', 'm0s0')
# No files available for combination: ('ul004', 'oc', 'm0s0')
# No files available for combination: ('ul004', 'oc', 'm0s0')
# No files available for combination: ('ul004', 'oc', 'm0s0')
# No files available for combination: ('ul004', 'oc', 'm1s0')
# No files available for combination: ('ul004', 'oc', 'm1s0')
# No files available for combination: ('ul004', 'oc', 'm1s0')
# No files available for combination: ('ul004', 'oc', 'm1s0')
# No files available for combination: ('ul004', 'oc', 'm1s0')
# No files available for combination: ('ul004', 'oc', 'm1s1')
# No files available for combination: ('ul004', 'oc', 'm1s1')
# No files available for combination: ('ul004', 'oc', 'm1s1')
# No files available for combination: ('ul004', 'oc', 'm1s1')
# No files available for combination: ('ul004', 'oc', 'm1s1')
# No files available for combination: ('ul004', 'oc', 'm0s1')
# No files available for combination: ('ul004', 'oc', 'm0s1')
# No files available for combination: ('ul004', 'oc', 'm0s1')
# No files available for combination: ('ul004', 'oc', 'm0s1')
# No files available for combination: ('ul004', 'oc', 'm0s1')
# No files available for combination: ('ul004', 'oc', 'm0s1')
# No files available for combination: ('ul004', 'oc', 'm0s1')
# No files available for combination: ('ul004', 'oc', 'm0s1')
# No files available for combination: ('ul004', 'oc', 'm0s1')
# No files available for combination: ('ul004', 'oc', 'm1')
# No files available for combination: ('ul004', 'oc', 'm1')
# No files available for combination: ('ul004', 'oc', 'm1')
# No files available for combination: ('ul004', 'oc', 'm1')
# No files available for combination: ('ul004', 'oc', 'm1')
# No files available for combination: ('ul004', 'oc', 'm1')
# No files available for combination: ('ul004', 'oc', 'm1')
# No files available for combination: ('ul004', 'oc', 'm1')
# No files available for combination: ('ul004', 'oc', 'm1')
# No files available for combination: ('ul004', 'oc', 'm0')
# No files available for combination: ('ul004', 'oc', 'm0')
# No files available for combination: ('ul004', 'oc', 'm0')
# No files available for combination: ('ul004', 'oc', 'm0')
# No files available for combination: ('ul004', 'oc', 'm0')
# No files available for combination: ('ul004', 'oc', 'm0')
# No files available for combination: ('ul004', 'oc', 'm0')
# No files available for combination: ('ul004', 'oc', 'm0')
# No files available for combination: ('ul004', 'oc', 'm0')
# No files available for combination: ('ul005', 'oc', 'm0s0')
# No files available for combination: ('ul005', 'oc', 'm0s0')
# No files available for combination: ('ul005', 'oc', 'm0s0')
# No files available for combination: ('ul005', 'oc', 'm0s0')
# No files available for combination: ('ul005', 'oc', 'm0s0')
# No files available for combination: ('ul005', 'oc', 'm0s0')
# No files available for combination: ('ul005', 'oc', 'm0s0')
# No files available for combination: ('ul005', 'oc', 'm0s0')
# No files available for combination: ('ul005', 'oc', 'm0s0')
# No files available for combination: ('ul005', 'oc', 'm1s0')
# No files available for combination: ('ul005', 'oc', 'm1s0')
# No files available for combination: ('ul005', 'oc', 'm1s0')
# No files available for combination: ('ul005', 'oc', 'm1s0')
# No files available for combination: ('ul005', 'oc', 'm1s0')
# No files available for combination: ('ul005', 'oc', 'm1s0')
# No files available for combination: ('ul005', 'oc', 'm1s0')
# No files available for combination: ('ul005', 'oc', 'm1s0')
# No files available for combination: ('ul005', 'oc', 'm1s0')
# No files available for combination: ('ul005', 'oc', 'm1s1')
# No files available for combination: ('ul005', 'oc', 'm1s1')
# No files available for combination: ('ul005', 'oc', 'm1s1')
# No files available for combination: ('ul005', 'oc', 'm1s1')
# No files available for combination: ('ul005', 'oc', 'm1s1')
# No files available for combination: ('ul005', 'oc', 'm0s1')
# No files available for combination: ('ul005', 'oc', 'm0s1')
# No files available for combination: ('ul005', 'oc', 'm0s1')
# No files available for combination: ('ul005', 'oc', 'm0s1')
# No files available for combination: ('ul005', 'oc', 'm0s1')
# No files available for combination: ('ul005', 'oc', 'm0s1')
# No files available for combination: ('ul005', 'oc', 'm0s1')
# No files available for combination: ('ul005', 'oc', 'm0s1')
# No files available for combination: ('ul005', 'oc', 'm0s1')
# No files available for combination: ('ul005', 'oc', 'm1')
# No files available for combination: ('ul005', 'oc', 'm1')
# No files available for combination: ('ul005', 'oc', 'm1')
# No files available for combination: ('ul005', 'oc', 'm1')
# No files available for combination: ('ul005', 'oc', 'm1')
# No files available for combination: ('ul005', 'oc', 'm1')
# No files available for combination: ('ul005', 'oc', 'm1')
# No files available for combination: ('ul005', 'oc', 'm1')
# No files available for combination: ('ul005', 'oc', 'm1')
# No files available for combination: ('ul005', 'oc', 'm0')
# No files available for combination: ('ul005', 'oc', 'm0')
# No files available for combination: ('ul005', 'oc', 'm0')
# No files available for combination: ('ul005', 'oc', 'm0')
# No files available for combination: ('ul005', 'oc', 'm0')
# No files available for combination: ('ul005', 'oc', 'm0')
# No files available for combination: ('ul005', 'oc', 'm0')
# No files available for combination: ('ul005', 'oc', 'm0')
# No files available for combination: ('ul005', 'oc', 'm0')
# No files available for combination: ('ul005', 'oc', 'm0s0')
# No files available for combination: ('ul005', 'oc', 'm0s0')
# No files available for combination: ('ul005', 'oc', 'm0s0')
# No files available for combination: ('ul005', 'oc', 'm0s0')
# No files available for combination: ('ul005', 'oc', 'm0s0')
# No files available for combination: ('ul005', 'oc', 'm0s0')
# No files available for combination: ('ul005', 'oc', 'm0s0')
# No files available for combination: ('ul005', 'oc', 'm0s0')
# No files available for combination: ('ul005', 'oc', 'm0s0')
# No files available for combination: ('ul005', 'oc', 'm1s0')
# No files available for combination: ('ul005', 'oc', 'm1s0')
# No files available for combination: ('ul005', 'oc', 'm1s0')
# No files available for combination: ('ul005', 'oc', 'm1s0')
# No files available for combination: ('ul005', 'oc', 'm1s0')
# No files available for combination: ('ul005', 'oc', 'm1s0')
# No files available for combination: ('ul005', 'oc', 'm1s0')
# No files available for combination: ('ul005', 'oc', 'm1s0')
# No files available for combination: ('ul005', 'oc', 'm1s0')
# No files available for combination: ('ul005', 'oc', 'm1s1')
# No files available for combination: ('ul005', 'oc', 'm1s1')
# No files available for combination: ('ul005', 'oc', 'm1s1')
# No files available for combination: ('ul005', 'oc', 'm1s1')
# No files available for combination: ('ul005', 'oc', 'm1s1')
# No files available for combination: ('ul005', 'oc', 'm1s1')
# No files available for combination: ('ul005', 'oc', 'm0s1')
# No files available for combination: ('ul005', 'oc', 'm0s1')
# No files available for combination: ('ul005', 'oc', 'm0s1')
# No files available for combination: ('ul005', 'oc', 'm0s1')
# No files available for combination: ('ul005', 'oc', 'm0s1')
# No files available for combination: ('ul005', 'oc', 'm0s1')
# No files available for combination: ('ul005', 'oc', 'm0s1')
# No files available for combination: ('ul005', 'oc', 'm0s1')
# No files available for combination: ('ul005', 'oc', 'm0s1')
# No files available for combination: ('ul005', 'oc', 'm1')
# No files available for combination: ('ul005', 'oc', 'm1')
# No files available for combination: ('ul005', 'oc', 'm1')
# No files available for combination: ('ul005', 'oc', 'm1')
# No files available for combination: ('ul005', 'oc', 'm1')
# No files available for combination: ('ul005', 'oc', 'm1')
# No files available for combination: ('ul005', 'oc', 'm1')
# No files available for combination: ('ul005', 'oc', 'm1')
# No files available for combination: ('ul005', 'oc', 'm1')
# No files available for combination: ('ul005', 'oc', 'm0')
# No files available for combination: ('ul005', 'oc', 'm0')
# No files available for combination: ('ul005', 'oc', 'm0')
# No files available for combination: ('ul005', 'oc', 'm0')
# No files available for combination: ('ul005', 'oc', 'm0')
# No files available for combination: ('ul005', 'oc', 'm0')
# No files available for combination: ('ul005', 'oc', 'm0')
# No files available for combination: ('ul005', 'oc', 'm0')
# No files available for combination: ('ul005', 'oc', 'm0')
# No files available for combination: ('ul006', 'oc', 'm0s0')
# No files available for combination: ('ul006', 'oc', 'm0s0')
# No files available for combination: ('ul006', 'oc', 'm0s0')
# No files available for combination: ('ul006', 'oc', 'm0s0')
# No files available for combination: ('ul006', 'oc', 'm0s0')
# No files available for combination: ('ul006', 'oc', 'm0s0')
# No files available for combination: ('ul006', 'oc', 'm0s0')
# No files available for combination: ('ul006', 'oc', 'm0s0')
# No files available for combination: ('ul006', 'oc', 'm0s0')
# No files available for combination: ('ul006', 'oc', 'm1s0')
# No files available for combination: ('ul006', 'oc', 'm1s0')
# No files available for combination: ('ul006', 'oc', 'm1s0')
# No files available for combination: ('ul006', 'oc', 'm1s0')
# No files available for combination: ('ul006', 'oc', 'm1s0')
# No files available for combination: ('ul006', 'oc', 'm1s0')
# No files available for combination: ('ul006', 'oc', 'm1s0')
# No files available for combination: ('ul006', 'oc', 'm1s0')
# No files available for combination: ('ul006', 'oc', 'm1s0')
# No files available for combination: ('ul006', 'oc', 'm1s1')
# No files available for combination: ('ul006', 'oc', 'm1s1')
# No files available for combination: ('ul006', 'oc', 'm1s1')
# No files available for combination: ('ul006', 'oc', 'm1s1')
# No files available for combination: ('ul006', 'oc', 'm1s1')
# No files available for combination: ('ul006', 'oc', 'm1s1')
# No files available for combination: ('ul006', 'oc', 'm1s1')
# No files available for combination: ('ul006', 'oc', 'm1s1')
# No files available for combination: ('ul006', 'oc', 'm1s1')
# No files available for combination: ('ul006', 'oc', 'm0s1')
# No files available for combination: ('ul006', 'oc', 'm0s1')
# No files available for combination: ('ul006', 'oc', 'm0s1')
# No files available for combination: ('ul006', 'oc', 'm0s1')
# No files available for combination: ('ul006', 'oc', 'm0s1')
# No files available for combination: ('ul006', 'oc', 'm0s1')
# No files available for combination: ('ul006', 'oc', 'm0s1')
# No files available for combination: ('ul006', 'oc', 'm0s1')
# No files available for combination: ('ul006', 'oc', 'm0s1')
# No files available for combination: ('ul006', 'oc', 'm1')
# No files available for combination: ('ul006', 'oc', 'm1')
# No files available for combination: ('ul006', 'oc', 'm1')
# No files available for combination: ('ul006', 'oc', 'm1')
# No files available for combination: ('ul006', 'oc', 'm1')
# No files available for combination: ('ul006', 'oc', 'm1')
# No files available for combination: ('ul006', 'oc', 'm1')
# No files available for combination: ('ul006', 'oc', 'm1')
# No files available for combination: ('ul006', 'oc', 'm1')
# No files available for combination: ('ul006', 'oc', 'm0')
# No files available for combination: ('ul006', 'oc', 'm0')
# No files available for combination: ('ul006', 'oc', 'm0')
# No files available for combination: ('ul006', 'oc', 'm0')
# No files available for combination: ('ul006', 'oc', 'm0')
# No files available for combination: ('ul006', 'oc', 'm0')
# No files available for combination: ('ul006', 'oc', 'm0')
# No files available for combination: ('ul006', 'oc', 'm0')
# No files available for combination: ('ul006', 'oc', 'm0')
# No files available for combination: ('ul006', 'oc', 'm0s0')
# No files available for combination: ('ul006', 'oc', 'm0s0')
# No files available for combination: ('ul006', 'oc', 'm0s0')
# No files available for combination: ('ul006', 'oc', 'm0s0')
# No files available for combination: ('ul006', 'oc', 'm0s0')
# No files available for combination: ('ul006', 'oc', 'm0s0')
# No files available for combination: ('ul006', 'oc', 'm0s0')
# No files available for combination: ('ul006', 'oc', 'm0s0')
# No files available for combination: ('ul006', 'oc', 'm0s0')
# No files available for combination: ('ul006', 'oc', 'm1s0')
# No files available for combination: ('ul006', 'oc', 'm1s0')
# No files available for combination: ('ul006', 'oc', 'm1s0')
# No files available for combination: ('ul006', 'oc', 'm1s0')
# No files available for combination: ('ul006', 'oc', 'm1s0')
# No files available for combination: ('ul006', 'oc', 'm1s0')
# No files available for combination: ('ul006', 'oc', 'm1s0')
# No files available for combination: ('ul006', 'oc', 'm1s0')
# No files available for combination: ('ul006', 'oc', 'm1s0')
# No files available for combination: ('ul006', 'oc', 'm1s1')
# No files available for combination: ('ul006', 'oc', 'm1s1')
# No files available for combination: ('ul006', 'oc', 'm1s1')
# No files available for combination: ('ul006', 'oc', 'm1s1')
# No files available for combination: ('ul006', 'oc', 'm1s1')
# No files available for combination: ('ul006', 'oc', 'm1s1')
# No files available for combination: ('ul006', 'oc', 'm1s1')
# No files available for combination: ('ul006', 'oc', 'm1s1')
# No files available for combination: ('ul006', 'oc', 'm1s1')
# No files available for combination: ('ul006', 'oc', 'm0s1')
# No files available for combination: ('ul006', 'oc', 'm0s1')
# No files available for combination: ('ul006', 'oc', 'm0s1')
# No files available for combination: ('ul006', 'oc', 'm0s1')
# No files available for combination: ('ul006', 'oc', 'm0s1')
# No files available for combination: ('ul006', 'oc', 'm0s1')
# No files available for combination: ('ul006', 'oc', 'm0s1')
# No files available for combination: ('ul006', 'oc', 'm0s1')
# No files available for combination: ('ul006', 'oc', 'm0s1')
# No files available for combination: ('ul006', 'oc', 'm1')
# No files available for combination: ('ul006', 'oc', 'm1')
# No files available for combination: ('ul006', 'oc', 'm1')
# No files available for combination: ('ul006', 'oc', 'm1')
# No files available for combination: ('ul006', 'oc', 'm1')
# No files available for combination: ('ul006', 'oc', 'm1')
# No files available for combination: ('ul006', 'oc', 'm1')
# No files available for combination: ('ul006', 'oc', 'm1')
# No files available for combination: ('ul006', 'oc', 'm1')
# No files available for combination: ('ul006', 'oc', 'm0')
# No files available for combination: ('ul006', 'oc', 'm0')
# No files available for combination: ('ul006', 'oc', 'm0')
# No files available for combination: ('ul006', 'oc', 'm0')
# No files available for combination: ('ul006', 'oc', 'm0')
# No files available for combination: ('ul006', 'oc', 'm0')
# No files available for combination: ('ul006', 'oc', 'm0')
# No files available for combination: ('ul006', 'oc', 'm0')
# No files available for combination: ('ul006', 'oc', 'm0')
# No files available for combination: ('ul007', 'oc', 'm0s0')
# No files available for combination: ('ul007', 'oc', 'm0s0')
# No files available for combination: ('ul007', 'oc', 'm0s0')
# No files available for combination: ('ul007', 'oc', 'm0s0')
# No files available for combination: ('ul007', 'oc', 'm0s0')
# No files available for combination: ('ul007', 'oc', 'm0s0')
# No files available for combination: ('ul007', 'oc', 'm0s0')
# No files available for combination: ('ul007', 'oc', 'm1s0')
# No files available for combination: ('ul007', 'oc', 'm1s0')
# No files available for combination: ('ul007', 'oc', 'm1s0')
# No files available for combination: ('ul007', 'oc', 'm1s0')
# No files available for combination: ('ul007', 'oc', 'm1s0')
# No files available for combination: ('ul007', 'oc', 'm1s0')
# No files available for combination: ('ul007', 'oc', 'm1s0')
# No files available for combination: ('ul007', 'oc', 'm1s1')
# No files available for combination: ('ul007', 'oc', 'm1s1')
# No files available for combination: ('ul007', 'oc', 'm1s1')
# No files available for combination: ('ul007', 'oc', 'm1s1')
# No files available for combination: ('ul007', 'oc', 'm1s1')
# No files available for combination: ('ul007', 'oc', 'm1s1')
# No files available for combination: ('ul007', 'oc', 'm1s1')
# No files available for combination: ('ul007', 'oc', 'm0s1')
# No files available for combination: ('ul007', 'oc', 'm0s1')
# No files available for combination: ('ul007', 'oc', 'm0s1')
# No files available for combination: ('ul007', 'oc', 'm0s1')
# No files available for combination: ('ul007', 'oc', 'm0s1')
# No files available for combination: ('ul007', 'oc', 'm0s1')
# No files available for combination: ('ul007', 'oc', 'm0s1')
# No files available for combination: ('ul007', 'oc', 'm1')
# No files available for combination: ('ul007', 'oc', 'm1')
# No files available for combination: ('ul007', 'oc', 'm1')
# No files available for combination: ('ul007', 'oc', 'm1')
# No files available for combination: ('ul007', 'oc', 'm1')
# No files available for combination: ('ul007', 'oc', 'm1')
# No files available for combination: ('ul007', 'oc', 'm1')
# No files available for combination: ('ul007', 'oc', 'm1')
# No files available for combination: ('ul007', 'oc', 'm1')
# No files available for combination: ('ul007', 'oc', 'm0')
# No files available for combination: ('ul007', 'oc', 'm0')
# No files available for combination: ('ul007', 'oc', 'm0')
# No files available for combination: ('ul007', 'oc', 'm0')
# No files available for combination: ('ul007', 'oc', 'm0')
# No files available for combination: ('ul007', 'oc', 'm0')
# No files available for combination: ('ul007', 'oc', 'm0')
# No files available for combination: ('ul007', 'oc', 'm0')
# No files available for combination: ('ul007', 'oc', 'm0')
# No files available for combination: ('ul007', 'oc', 'm0s0')
# No files available for combination: ('ul007', 'oc', 'm0s0')
# No files available for combination: ('ul007', 'oc', 'm0s0')
# No files available for combination: ('ul007', 'oc', 'm0s0')
# No files available for combination: ('ul007', 'oc', 'm0s0')
# No files available for combination: ('ul007', 'oc', 'm0s0')
# No files available for combination: ('ul007', 'oc', 'm0s0')
# No files available for combination: ('ul007', 'oc', 'm1s0')
# No files available for combination: ('ul007', 'oc', 'm1s0')
# No files available for combination: ('ul007', 'oc', 'm1s0')
# No files available for combination: ('ul007', 'oc', 'm1s0')
# No files available for combination: ('ul007', 'oc', 'm1s0')
# No files available for combination: ('ul007', 'oc', 'm1s0')
# No files available for combination: ('ul007', 'oc', 'm1s0')
# No files available for combination: ('ul007', 'oc', 'm1s1')
# No files available for combination: ('ul007', 'oc', 'm1s1')
# No files available for combination: ('ul007', 'oc', 'm1s1')
# No files available for combination: ('ul007', 'oc', 'm1s1')
# No files available for combination: ('ul007', 'oc', 'm1s1')
# No files available for combination: ('ul007', 'oc', 'm1s1')
# No files available for combination: ('ul007', 'oc', 'm1s1')
# No files available for combination: ('ul007', 'oc', 'm0s1')
# No files available for combination: ('ul007', 'oc', 'm0s1')
# No files available for combination: ('ul007', 'oc', 'm0s1')
# No files available for combination: ('ul007', 'oc', 'm0s1')
# No files available for combination: ('ul007', 'oc', 'm0s1')
# No files available for combination: ('ul007', 'oc', 'm0s1')
# No files available for combination: ('ul007', 'oc', 'm0s1')
# No files available for combination: ('ul007', 'oc', 'm1')
# No files available for combination: ('ul007', 'oc', 'm1')
# No files available for combination: ('ul007', 'oc', 'm1')
# No files available for combination: ('ul007', 'oc', 'm1')
# No files available for combination: ('ul007', 'oc', 'm1')
# No files available for combination: ('ul007', 'oc', 'm1')
# No files available for combination: ('ul007', 'oc', 'm1')
# No files available for combination: ('ul007', 'oc', 'm1')
# No files available for combination: ('ul007', 'oc', 'm1')
# No files available for combination: ('ul007', 'oc', 'm0')
# No files available for combination: ('ul007', 'oc', 'm0')
# No files available for combination: ('ul007', 'oc', 'm0')
# No files available for combination: ('ul007', 'oc', 'm0')
# No files available for combination: ('ul007', 'oc', 'm0')
# No files available for combination: ('ul007', 'oc', 'm0')
# No files available for combination: ('ul007', 'oc', 'm0')
# No files available for combination: ('ul007', 'oc', 'm0')
# No files available for combination: ('ul007', 'oc', 'm0')
# No files available for combination: ('ul008', 'oc', 'm0s0')
# No files available for combination: ('ul008', 'oc', 'm0s0')
# No files available for combination: ('ul008', 'oc', 'm0s0')
# No files available for combination: ('ul008', 'oc', 'm0s0')
# No files available for combination: ('ul008', 'oc', 'm0s0')
# No files available for combination: ('ul008', 'oc', 'm0s0')
# No files available for combination: ('ul008', 'oc', 'm0s0')
# No files available for combination: ('ul008', 'oc', 'm1s0')
# No files available for combination: ('ul008', 'oc', 'm1s0')
# No files available for combination: ('ul008', 'oc', 'm1s0')
# No files available for combination: ('ul008', 'oc', 'm1s0')
# No files available for combination: ('ul008', 'oc', 'm1s0')
# No files available for combination: ('ul008', 'oc', 'm1s0')
# No files available for combination: ('ul008', 'oc', 'm1s0')
# No files available for combination: ('ul008', 'oc', 'm1s1')
# No files available for combination: ('ul008', 'oc', 'm1s1')
# No files available for combination: ('ul008', 'oc', 'm1s1')
# No files available for combination: ('ul008', 'oc', 'm1s1')
# No files available for combination: ('ul008', 'oc', 'm1s1')
# No files available for combination: ('ul008', 'oc', 'm1s1')
# No files available for combination: ('ul008', 'oc', 'm1s1')
# No files available for combination: ('ul008', 'oc', 'm0s1')
# No files available for combination: ('ul008', 'oc', 'm0s1')
# No files available for combination: ('ul008', 'oc', 'm0s1')
# No files available for combination: ('ul008', 'oc', 'm0s1')
# No files available for combination: ('ul008', 'oc', 'm0s1')
# No files available for combination: ('ul008', 'oc', 'm0s1')
# No files available for combination: ('ul008', 'oc', 'm0s1')
# No files available for combination: ('ul008', 'oc', 'm1')
# No files available for combination: ('ul008', 'oc', 'm1')
# No files available for combination: ('ul008', 'oc', 'm1')
# No files available for combination: ('ul008', 'oc', 'm1')
# No files available for combination: ('ul008', 'oc', 'm1')
# No files available for combination: ('ul008', 'oc', 'm1')
# No files available for combination: ('ul008', 'oc', 'm1')
# No files available for combination: ('ul008', 'oc', 'm1')
# No files available for combination: ('ul008', 'oc', 'm1')
# No files available for combination: ('ul008', 'oc', 'm0')
# No files available for combination: ('ul008', 'oc', 'm0')
# No files available for combination: ('ul008', 'oc', 'm0')
# No files available for combination: ('ul008', 'oc', 'm0')
# No files available for combination: ('ul008', 'oc', 'm0')
# No files available for combination: ('ul008', 'oc', 'm0')
# No files available for combination: ('ul008', 'oc', 'm0')
# No files available for combination: ('ul008', 'oc', 'm0')
# No files available for combination: ('ul008', 'oc', 'm0')
# No files available for combination: ('ul008', 'oc', 'm0s0')
# No files available for combination: ('ul008', 'oc', 'm0s0')
# No files available for combination: ('ul008', 'oc', 'm0s0')
# No files available for combination: ('ul008', 'oc', 'm0s0')
# No files available for combination: ('ul008', 'oc', 'm0s0')
# No files available for combination: ('ul008', 'oc', 'm0s0')
# No files available for combination: ('ul008', 'oc', 'm0s0')
# No files available for combination: ('ul008', 'oc', 'm1s0')
# No files available for combination: ('ul008', 'oc', 'm1s0')
# No files available for combination: ('ul008', 'oc', 'm1s0')
# No files available for combination: ('ul008', 'oc', 'm1s0')
# No files available for combination: ('ul008', 'oc', 'm1s0')
# No files available for combination: ('ul008', 'oc', 'm1s0')
# No files available for combination: ('ul008', 'oc', 'm1s0')
# No files available for combination: ('ul008', 'oc', 'm1s1')
# No files available for combination: ('ul008', 'oc', 'm1s1')
# No files available for combination: ('ul008', 'oc', 'm1s1')
# No files available for combination: ('ul008', 'oc', 'm1s1')
# No files available for combination: ('ul008', 'oc', 'm1s1')
# No files available for combination: ('ul008', 'oc', 'm1s1')
# No files available for combination: ('ul008', 'oc', 'm1s1')
# No files available for combination: ('ul008', 'oc', 'm0s1')
# No files available for combination: ('ul008', 'oc', 'm0s1')
# No files available for combination: ('ul008', 'oc', 'm0s1')
# No files available for combination: ('ul008', 'oc', 'm0s1')
# No files available for combination: ('ul008', 'oc', 'm0s1')
# No files available for combination: ('ul008', 'oc', 'm0s1')
# No files available for combination: ('ul008', 'oc', 'm0s1')
# No files available for combination: ('ul008', 'oc', 'm1')
# No files available for combination: ('ul008', 'oc', 'm1')
# No files available for combination: ('ul008', 'oc', 'm1')
# No files available for combination: ('ul008', 'oc', 'm1')
# No files available for combination: ('ul008', 'oc', 'm1')
# No files available for combination: ('ul008', 'oc', 'm1')
# No files available for combination: ('ul008', 'oc', 'm1')
# No files available for combination: ('ul008', 'oc', 'm1')
# No files available for combination: ('ul008', 'oc', 'm1')
# No files available for combination: ('ul008', 'oc', 'm0')
# No files available for combination: ('ul008', 'oc', 'm0')
# No files available for combination: ('ul008', 'oc', 'm0')
# No files available for combination: ('ul008', 'oc', 'm0')
# No files available for combination: ('ul008', 'oc', 'm0')
# No files available for combination: ('ul008', 'oc', 'm0')
# No files available for combination: ('ul008', 'oc', 'm0')
# No files available for combination: ('ul008', 'oc', 'm0')
# No files available for combination: ('ul008', 'oc', 'm0')
# No files available for combination: ('ul009', 'oc', 'm0s0')
# No files available for combination: ('ul009', 'oc', 'm0s0')
# No files available for combination: ('ul009', 'oc', 'm0s0')
# No files available for combination: ('ul009', 'oc', 'm0s0')
# No files available for combination: ('ul009', 'oc', 'm0s0')
# No files available for combination: ('ul009', 'oc', 'm0s0')
# No files available for combination: ('ul009', 'oc', 'm0s0')
# No files available for combination: ('ul009', 'oc', 'm0s0')
# No files available for combination: ('ul009', 'oc', 'm0s0')
# No files available for combination: ('ul009', 'oc', 'm1s0')
# No files available for combination: ('ul009', 'oc', 'm1s0')
# No files available for combination: ('ul009', 'oc', 'm1s0')
# No files available for combination: ('ul009', 'oc', 'm1s0')
# No files available for combination: ('ul009', 'oc', 'm1s0')
# No files available for combination: ('ul009', 'oc', 'm1s0')
# No files available for combination: ('ul009', 'oc', 'm1s0')
# No files available for combination: ('ul009', 'oc', 'm1s0')
# No files available for combination: ('ul009', 'oc', 'm1s0')
# No files available for combination: ('ul009', 'oc', 'm1s1')
# No files available for combination: ('ul009', 'oc', 'm1s1')
# No files available for combination: ('ul009', 'oc', 'm1s1')
# No files available for combination: ('ul009', 'oc', 'm1s1')
# No files available for combination: ('ul009', 'oc', 'm1s1')
# No files available for combination: ('ul009', 'oc', 'm1s1')
# No files available for combination: ('ul009', 'oc', 'm1s1')
# No files available for combination: ('ul009', 'oc', 'm1s1')
# No files available for combination: ('ul009', 'oc', 'm1s1')
# ...
# No files available for combination: ('ul018', 'oc', 'm0s1')
# No files available for combination: ('ul018', 'oc', 'm0s1')
# No files available for combination: ('ul018', 'oc', 'm0s1')
# No files available for combination: ('ul018', 'oc', 'm0s1')
# No files available for combination: ('ul018', 'oc', 'm0s1')
# No files available for combination: ('ul018', 'oc', 'm0s1')
# No files available for combination: ('ul018', 'oc', 'm1')
# No files available for combination: ('ul018', 'oc', 'm1')
# No files available for combination: ('ul018', 'oc', 'm1')
# No files available for combination: ('ul018', 'oc', 'm1')
# No files available for combination: ('ul018', 'oc', 'm1')
# No files available for combination: ('ul018', 'oc', 'm1')
# No files available for combination: ('ul018', 'oc', 'm1')
# No files available for combination: ('ul018', 'oc', 'm1')
# No files available for combination: ('ul018', 'oc', 'm1')
# No files available for combination: ('ul018', 'oc', 'm0')
# No files available for combination: ('ul018', 'oc', 'm0')
# No files available for combination: ('ul018', 'oc', 'm0')
# No files available for combination: ('ul018', 'oc', 'm0')
# No files available for combination: ('ul018', 'oc', 'm0')
# No files available for combination: ('ul018', 'oc', 'm0')
# No files available for combination: ('ul018', 'oc', 'm0')
# No files available for combination: ('ul018', 'oc', 'm0')
# No files available for combination: ('ul018', 'oc', 'm0')
# No files available for combination: ('ul018', 'oc', 'm0s0')
# No files available for combination: ('ul018', 'oc', 'm0s0')
# No files available for combination: ('ul018', 'oc', 'm0s0')
# No files available for combination: ('ul018', 'oc', 'm0s0')
# No files available for combination: ('ul018', 'oc', 'm0s0')
# No files available for combination: ('ul018', 'oc', 'm0s0')
# No files available for combination: ('ul018', 'oc', 'm0s0')
# No files available for combination: ('ul018', 'oc', 'm0s0')
# No files available for combination: ('ul018', 'oc', 'm0s0')
# No files available for combination: ('ul018', 'oc', 'm1s0')
# No files available for combination: ('ul018', 'oc', 'm1s0')
# No files available for combination: ('ul018', 'oc', 'm1s0')
# No files available for combination: ('ul018', 'oc', 'm1s0')
# No files available for combination: ('ul018', 'oc', 'm1s0')
# No files available for combination: ('ul018', 'oc', 'm1s0')
# No files available for combination: ('ul018', 'oc', 'm1s0')
# No files available for combination: ('ul018', 'oc', 'm1s0')
# No files available for combination: ('ul018', 'oc', 'm1s0')
# No files available for combination: ('ul018', 'oc', 'm1s1')
# No files available for combination: ('ul018', 'oc', 'm1s1')
# No files available for combination: ('ul018', 'oc', 'm1s1')
# No files available for combination: ('ul018', 'oc', 'm1s1')
# No files available for combination: ('ul018', 'oc', 'm1s1')
# No files available for combination: ('ul018', 'oc', 'm1s1')
# No files available for combination: ('ul018', 'oc', 'm1s1')
# No files available for combination: ('ul018', 'oc', 'm1s1')
# No files available for combination: ('ul018', 'oc', 'm1s1')
# No files available for combination: ('ul018', 'oc', 'm0s1')
# No files available for combination: ('ul018', 'oc', 'm0s1')
# No files available for combination: ('ul018', 'oc', 'm0s1')
# No files available for combination: ('ul018', 'oc', 'm0s1')
# No files available for combination: ('ul018', 'oc', 'm0s1')
# No files available for combination: ('ul018', 'oc', 'm0s1')
# No files available for combination: ('ul018', 'oc', 'm0s1')
# No files available for combination: ('ul018', 'oc', 'm0s1')
# No files available for combination: ('ul018', 'oc', 'm0s1')
# No files available for combination: ('ul018', 'oc', 'm1')
# No files available for combination: ('ul018', 'oc', 'm1')
# No files available for combination: ('ul018', 'oc', 'm1')
# No files available for combination: ('ul018', 'oc', 'm1')
# No files available for combination: ('ul018', 'oc', 'm1')
# No files available for combination: ('ul018', 'oc', 'm1')
# No files available for combination: ('ul018', 'oc', 'm1')
# No files available for combination: ('ul018', 'oc', 'm1')
# No files available for combination: ('ul018', 'oc', 'm1')
# No files available for combination: ('ul018', 'oc', 'm0')
# No files available for combination: ('ul018', 'oc', 'm0')
# No files available for combination: ('ul018', 'oc', 'm0')
# No files available for combination: ('ul018', 'oc', 'm0')
# No files available for combination: ('ul018', 'oc', 'm0')
# No files available for combination: ('ul018', 'oc', 'm0')
# No files available for combination: ('ul018', 'oc', 'm0')
# No files available for combination: ('ul018', 'oc', 'm0')
# No files available for combination: ('ul018', 'oc', 'm0')
# No files available for combination: ('ul019', 'oc', 'm0s0')
# No files available for combination: ('ul019', 'oc', 'm0s0')
# No files available for combination: ('ul019', 'oc', 'm0s0')
# No files available for combination: ('ul019', 'oc', 'm0s0')
# No files available for combination: ('ul019', 'oc', 'm0s0')
# No files available for combination: ('ul019', 'oc', 'm0s0')
# No files available for combination: ('ul019', 'oc', 'm0s0')
# No files available for combination: ('ul019', 'oc', 'm1s0')
# No files available for combination: ('ul019', 'oc', 'm1s0')
# No files available for combination: ('ul019', 'oc', 'm1s0')
# No files available for combination: ('ul019', 'oc', 'm1s0')
# No files available for combination: ('ul019', 'oc', 'm1s0')
# No files available for combination: ('ul019', 'oc', 'm1s0')
# No files available for combination: ('ul019', 'oc', 'm1s0')
# No files available for combination: ('ul019', 'oc', 'm1s1')
# No files available for combination: ('ul019', 'oc', 'm1s1')
# No files available for combination: ('ul019', 'oc', 'm1s1')
# No files available for combination: ('ul019', 'oc', 'm1s1')
# No files available for combination: ('ul019', 'oc', 'm1s1')
# No files available for combination: ('ul019', 'oc', 'm1s1')
# No files available for combination: ('ul019', 'oc', 'm1s1')
# No files available for combination: ('ul019', 'oc', 'm0s1')
# No files available for combination: ('ul019', 'oc', 'm0s1')
# No files available for combination: ('ul019', 'oc', 'm0s1')
# No files available for combination: ('ul019', 'oc', 'm0s1')
# No files available for combination: ('ul019', 'oc', 'm0s1')
# No files available for combination: ('ul019', 'oc', 'm0s1')
# No files available for combination: ('ul019', 'oc', 'm0s1')
# No files available for combination: ('ul019', 'oc', 'm1')
# No files available for combination: ('ul019', 'oc', 'm1')
# No files available for combination: ('ul019', 'oc', 'm1')
# No files available for combination: ('ul019', 'oc', 'm1')
# No files available for combination: ('ul019', 'oc', 'm1')
# No files available for combination: ('ul019', 'oc', 'm1')
# No files available for combination: ('ul019', 'oc', 'm1')
# No files available for combination: ('ul019', 'oc', 'm1')
# No files available for combination: ('ul019', 'oc', 'm1')
# No files available for combination: ('ul019', 'oc', 'm0')
# No files available for combination: ('ul019', 'oc', 'm0')
# No files available for combination: ('ul019', 'oc', 'm0')
# No files available for combination: ('ul019', 'oc', 'm0')
# No files available for combination: ('ul019', 'oc', 'm0')
# No files available for combination: ('ul019', 'oc', 'm0')
# No files available for combination: ('ul019', 'oc', 'm0')
# No files available for combination: ('ul019', 'oc', 'm0')
# No files available for combination: ('ul019', 'oc', 'm0')
# No files available for combination: ('ul019', 'oc', 'm0s0')
# No files available for combination: ('ul019', 'oc', 'm0s0')
# No files available for combination: ('ul019', 'oc', 'm0s0')
# No files available for combination: ('ul019', 'oc', 'm0s0')
# No files available for combination: ('ul019', 'oc', 'm0s0')
# No files available for combination: ('ul019', 'oc', 'm0s0')
# No files available for combination: ('ul019', 'oc', 'm0s0')
# No files available for combination: ('ul019', 'oc', 'm1s0')
# No files available for combination: ('ul019', 'oc', 'm1s0')
# No files available for combination: ('ul019', 'oc', 'm1s0')
# No files available for combination: ('ul019', 'oc', 'm1s0')
# No files available for combination: ('ul019', 'oc', 'm1s0')
# No files available for combination: ('ul019', 'oc', 'm1s0')
# No files available for combination: ('ul019', 'oc', 'm1s0')
# No files available for combination: ('ul019', 'oc', 'm1s1')
# No files available for combination: ('ul019', 'oc', 'm1s1')
# No files available for combination: ('ul019', 'oc', 'm1s1')
# No files available for combination: ('ul019', 'oc', 'm1s1')
# No files available for combination: ('ul019', 'oc', 'm1s1')
# No files available for combination: ('ul019', 'oc', 'm1s1')
# No files available for combination: ('ul019', 'oc', 'm1s1')
# No files available for combination: ('ul019', 'oc', 'm0s1')
# No files available for combination: ('ul019', 'oc', 'm0s1')
# No files available for combination: ('ul019', 'oc', 'm0s1')
# No files available for combination: ('ul019', 'oc', 'm0s1')
# No files available for combination: ('ul019', 'oc', 'm0s1')
# No files available for combination: ('ul019', 'oc', 'm0s1')
# No files available for combination: ('ul019', 'oc', 'm0s1')
# No files available for combination: ('ul019', 'oc', 'm1')
# No files available for combination: ('ul019', 'oc', 'm1')
# No files available for combination: ('ul019', 'oc', 'm1')
# No files available for combination: ('ul019', 'oc', 'm1')
# No files available for combination: ('ul019', 'oc', 'm1')
# No files available for combination: ('ul019', 'oc', 'm1')
# No files available for combination: ('ul019', 'oc', 'm1')
# No files available for combination: ('ul019', 'oc', 'm1')
# No files available for combination: ('ul019', 'oc', 'm1')
# No files available for combination: ('ul019', 'oc', 'm0')
# No files available for combination: ('ul019', 'oc', 'm0')
# No files available for combination: ('ul019', 'oc', 'm0')
# No files available for combination: ('ul019', 'oc', 'm0')
# No files available for combination: ('ul019', 'oc', 'm0')
# No files available for combination: ('ul019', 'oc', 'm0')
# No files available for combination: ('ul019', 'oc', 'm0')
# No files available for combination: ('ul019', 'oc', 'm0')
# No files available for combination: ('ul019', 'oc', 'm0')
# No files available for combination: ('ul020', 'oc', 'm0s0')
# No files available for combination: ('ul020', 'oc', 'm0s0')
# No files available for combination: ('ul020', 'oc', 'm0s0')
# No files available for combination: ('ul020', 'oc', 'm0s0')
# No files available for combination: ('ul020', 'oc', 'm0s0')
# No files available for combination: ('ul020', 'oc', 'm0s0')
# No files available for combination: ('ul020', 'oc', 'm0s0')
# No files available for combination: ('ul020', 'oc', 'm1s0')
# No files available for combination: ('ul020', 'oc', 'm1s0')
# No files available for combination: ('ul020', 'oc', 'm1s0')
# No files available for combination: ('ul020', 'oc', 'm1s0')
# No files available for combination: ('ul020', 'oc', 'm1s0')
# No files available for combination: ('ul020', 'oc', 'm1s0')
# No files available for combination: ('ul020', 'oc', 'm1s0')
# No files available for combination: ('ul020', 'oc', 'm1s0')
# No files available for combination: ('ul020', 'oc', 'm1s0')
# No files available for combination: ('ul020', 'oc', 'm1s1')
# No files available for combination: ('ul020', 'oc', 'm1s1')
# No files available for combination: ('ul020', 'oc', 'm1s1')
# No files available for combination: ('ul020', 'oc', 'm1s1')
# No files available for combination: ('ul020', 'oc', 'm1s1')
# No files available for combination: ('ul020', 'oc', 'm1s1')
# No files available for combination: ('ul020', 'oc', 'm1s1')
# No files available for combination: ('ul020', 'oc', 'm0s1')
# No files available for combination: ('ul020', 'oc', 'm0s1')
# No files available for combination: ('ul020', 'oc', 'm0s1')
# No files available for combination: ('ul020', 'oc', 'm0s1')
# No files available for combination: ('ul020', 'oc', 'm0s1')
# No files available for combination: ('ul020', 'oc', 'm0s1')
# No files available for combination: ('ul020', 'oc', 'm0s1')
# No files available for combination: ('ul020', 'oc', 'm0s1')
# No files available for combination: ('ul020', 'oc', 'm0s1')
# No files available for combination: ('ul020', 'oc', 'm1')
# No files available for combination: ('ul020', 'oc', 'm1')
# No files available for combination: ('ul020', 'oc', 'm1')
# No files available for combination: ('ul020', 'oc', 'm1')
# No files available for combination: ('ul020', 'oc', 'm1')
# No files available for combination: ('ul020', 'oc', 'm1')
# No files available for combination: ('ul020', 'oc', 'm1')
# No files available for combination: ('ul020', 'oc', 'm1')
# No files available for combination: ('ul020', 'oc', 'm1')
# No files available for combination: ('ul020', 'oc', 'm0')
# No files available for combination: ('ul020', 'oc', 'm0')
# No files available for combination: ('ul020', 'oc', 'm0')
# No files available for combination: ('ul020', 'oc', 'm0')
# No files available for combination: ('ul020', 'oc', 'm0')
# No files available for combination: ('ul020', 'oc', 'm0')
# No files available for combination: ('ul020', 'oc', 'm0')
# No files available for combination: ('ul020', 'oc', 'm0')
# No files available for combination: ('ul020', 'oc', 'm0')
# No files available for combination: ('ul020', 'oc', 'm0s0')
# No files available for combination: ('ul020', 'oc', 'm0s0')
# No files available for combination: ('ul020', 'oc', 'm0s0')
# No files available for combination: ('ul020', 'oc', 'm0s0')
# No files available for combination: ('ul020', 'oc', 'm0s0')
# No files available for combination: ('ul020', 'oc', 'm0s0')
# No files available for combination: ('ul020', 'oc', 'm0s0')
# No files available for combination: ('ul020', 'oc', 'm1s0')
# No files available for combination: ('ul020', 'oc', 'm1s0')
# No files available for combination: ('ul020', 'oc', 'm1s0')
# No files available for combination: ('ul020', 'oc', 'm1s0')
# No files available for combination: ('ul020', 'oc', 'm1s0')
# No files available for combination: ('ul020', 'oc', 'm1s0')
# No files available for combination: ('ul020', 'oc', 'm1s0')
# No files available for combination: ('ul020', 'oc', 'm1s0')
# No files available for combination: ('ul020', 'oc', 'm1s0')
# No files available for combination: ('ul020', 'oc', 'm1s1')
# No files available for combination: ('ul020', 'oc', 'm1s1')
# No files available for combination: ('ul020', 'oc', 'm1s1')
# No files available for combination: ('ul020', 'oc', 'm1s1')
# No files available for combination: ('ul020', 'oc', 'm1s1')
# No files available for combination: ('ul020', 'oc', 'm1s1')
# No files available for combination: ('ul020', 'oc', 'm1s1')
# No files available for combination: ('ul020', 'oc', 'm0s1')
# No files available for combination: ('ul020', 'oc', 'm0s1')
# No files available for combination: ('ul020', 'oc', 'm0s1')
# No files available for combination: ('ul020', 'oc', 'm0s1')
# No files available for combination: ('ul020', 'oc', 'm0s1')
# No files available for combination: ('ul020', 'oc', 'm0s1')
# No files available for combination: ('ul020', 'oc', 'm0s1')
# No files available for combination: ('ul020', 'oc', 'm0s1')
# No files available for combination: ('ul020', 'oc', 'm0s1')
# No files available for combination: ('ul020', 'oc', 'm1')
# No files available for combination: ('ul020', 'oc', 'm1')
# No files available for combination: ('ul020', 'oc', 'm1')
# No files available for combination: ('ul020', 'oc', 'm1')
# No files available for combination: ('ul020', 'oc', 'm1')
# No files available for combination: ('ul020', 'oc', 'm1')
# No files available for combination: ('ul020', 'oc', 'm1')
# No files available for combination: ('ul020', 'oc', 'm1')
# No files available for combination: ('ul020', 'oc', 'm1')
# No files available for combination: ('ul020', 'oc', 'm0')
# No files available for combination: ('ul020', 'oc', 'm0')
# No files available for combination: ('ul020', 'oc', 'm0')
# No files available for combination: ('ul020', 'oc', 'm0')
# No files available for combination: ('ul020', 'oc', 'm0')
# No files available for combination: ('ul020', 'oc', 'm0')
# No files available for combination: ('ul020', 'oc', 'm0')
# No files available for combination: ('ul020', 'oc', 'm0')
# No files available for combination: ('ul020', 'oc', 'm0')

# %%
# Save features dataframe in csv file
df_fts_path = os.path.join(repo_path,
                           'EDA',
                            task
                            ) 
if not os.path.exists(df_fts_path):
    os.makedirs(df_fts_path)
df_fts.to_csv(os.path.join(df_fts_path, 'features.csv'))

# %%
ls_file = df_fts['file'].to_list()
ls_scores = []

for file in ls_file:
    del_json = file[:-5]
    split = re.split('_', del_json)
    block = split[0]
    sub = split[1]
    cond = split[2]
    cam = split[3]
    task = split[4]
    side = split[5]

    score = get_scores(sub, cond, cam, task, side, block)
    ls_scores.append(score) # import updrs score for every block (is 'y' for prediction)

# %%
df_fts
# Out:
#                                file  num_events  mean_max_dist  sd_max_dist  \
# 0      b1_ul001_m1_vr_oc_right.json        19.0       0.109272     0.002220
# 1      b2_ul001_m1_vr_oc_right.json        27.0       0.109855     0.001633
# 2      b1_ul001_m1_dt_oc_right.json        28.0       0.102382     0.001029
# 3      b2_ul001_m1_dt_oc_right.json        25.0       0.101825     0.002750
# 4      b3_ul001_m1_dt_oc_right.json        31.0       0.097874     0.001992
# ..                              ...         ...            ...          ...
# 164  b2_ul020_m1s1_dt_oc_right.json        13.0       0.085574     0.016337
# 165   b1_ul020_m0s0_vr_oc_left.json         9.0       0.055540     0.006010
# 166   b2_ul020_m0s0_vr_oc_left.json        10.0       0.052455     0.007425
# 167   b1_ul020_m1s1_dt_oc_left.json        11.0       0.077444     0.022637
# 168   b2_ul020_m1s1_dt_oc_left.json        13.0       0.073891     0.020449
#
#      coef_var_max_dist  mean_max_vel  sd_max_vel  coef_var_max_vel  \
# 0             0.020318      0.784781    0.100015          0.127444
# 1             0.014862      1.158742    0.235498          0.203236
# 2             0.010052      1.388352    0.181955          0.131058
# 3             0.027003      1.476438    0.285087          0.193091
# 4             0.020357      1.773567    0.535029          0.301668
# ..                 ...           ...         ...               ...
# 164           0.190911      1.156129    0.497027          0.429906
# 165           0.108216      0.121577    0.038430          0.316100
# 166           0.141559      0.077085    0.044308          0.574790
# 167           0.292306      0.775401    0.386518          0.498475
# 168           0.276749      0.717305    0.364233          0.507781
#
#      mean_mean_vel  sd_mean_vel  coef_var_mean_vel  mean_deltat  sd_deltat  \
# 0         0.261829     0.020189           0.077106     0.478910   0.032191
# 1         0.338435     0.028948           0.085535     0.374461   0.039508
# 2         0.413157     0.041755           0.101062     0.347895   0.036026
# 3         0.409100     0.036075           0.088182     0.351213   0.034020
# 4         0.417906     0.038900           0.093083     0.325432   0.027286
# ..             ...          ...                ...          ...        ...
# 164       0.178521     0.060589           0.339392     0.815451   0.371665
# 165       0.032163     0.009566           0.297425     1.073724   0.054028
# 166       0.022839     0.011825           0.517751     1.025500   0.347817
# 167       0.138888     0.072487           0.521908     0.829317   0.479935
# 168       0.135886     0.072134           0.530840     0.721996   0.429344
#
#      coef_var_deltat  mean_rms    sd_rms   sum_rms
# 0           0.067218  0.072793  0.002686  1.310276
# 1           0.105508  0.072942  0.002401  1.896491
# 2           0.103555  0.063184  0.003280  1.705966
# 3           0.096863  0.061535  0.002103  1.476839
# 4           0.083847  0.060389  0.002813  1.811676
# ..               ...       ...       ...       ...
# 164         0.455778  0.055987  0.008823  0.671847
# 165         0.050319  0.046582  0.004308  0.372653
# 166         0.339168  0.045076  0.002500  0.405682
# 167         0.578712  0.047152  0.009621  0.471522
# 168         0.594663  0.046298  0.009076  0.555581
#
# [169 rows x 17 columns]

# %% [markdown]
# Merge all json files with features together

# %%
# create dictionary with all features
dict_feat = {
    'ft': ['num_events', 
    'mean_max_dist', 'sd_max_dist', 'coef_var_max_dist', 'slope_max_dist',
    'mean_max_vel', 'sd_max_vel', 'coef_var_max_vel', 'slope_max_vel', 'mean_mean_vel', 'sd_mean_vel', 'coef_var_mean_vel', 'slope_mean_vel', 
    'mean_deltat', 'sd_deltat', 'coef_var_deltat', 'slope_deltat',
    'mean_rms', 'sd_rms', 'slope_rms', 'sum_rms'],

    'oc': ['num_events', 
    'mean_max_dist', 'sd_max_dist', 'coef_var_max_dist', 'slope_max_dist',
    'mean_max_vel', 'sd_max_vel', 'coef_var_max_vel', 'slope_max_vel', 'mean_mean_vel', 'sd_mean_vel', 'coef_var_mean_vel', 'slope_mean_vel', 
    'mean_deltat', 'sd_deltat', 'coef_var_deltat', 'slope_deltat',
    'mean_rms', 'sd_rms', 'slope_rms', 'sum_rms'], 

    'ps': ['num_events', 
    'mean_max_ang', 'sd_max_ang', 'coef_var_max_ang', 'slope_max_ang',
    'mean_max_vel', 'sd_max_vel', 'coef_var_max_vel', 'slope_max_vel', 'mean_mean_vel', 'sd_mean_vel', 'coef_var_mean_vel', 'slope_mean_vel', 
    'mean_deltat', 'sd_deltat', 'coef_var_deltat', 'slope_deltat',
    'mean_rms', 'sd_rms', 'slope_rms', 'sum_rms'], 

    'pt': ['psd_max', 'max_displ', 'mean_displ', 'sd_displ', 'coef_var_displ']
    }

dict_open = open(os.path.join(find_paths.find_onedrive_path(folder),'features.json'), 'w')
json.dump(dict_feat, dict_open)
dict_open.close()
