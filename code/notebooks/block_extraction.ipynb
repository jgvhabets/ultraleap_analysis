# %% [markdown]
# Import public packages and functions

# %%
import os
import importlib
import pandas as pd
import numpy as np
import csv

# %%
def get_repo_path_in_notebook():
    """
    Finds path of repo from Notebook.
    Start running this once to correctly find
    other modules/functions
    """
    path = os.getcwd()
    repo_name = 'ultraleap_analysis'

    while path[-len(repo_name):] != 'ultraleap_analysis':

        path = os.path.dirname(path)

    return path

# %%
repo_path = get_repo_path_in_notebook()
code_path = os.path.join(repo_path, 'code')
os.chdir(code_path)

# %% [markdown]
# Import own functions

# %%
import import_data.import_and_convert_data as import_dat
import import_data.find_paths as find_paths
import sig_processing.segment_tasks as tasks
import sig_processing.calc_distances as calc_dist

# %% [markdown]
# ### 1. Saving blocks for preprocessing

# %% [markdown]
# Define variables of interest

# %%
folder = 'patientdata'
ls_cam = ['vr', 'dt', 'st']
ls_task = ['ft', 'oc', 'ps','pt']
ls_cond = ['m0s0', 'm1s0', 'm1s1', 'm0s1', 'm1', 'm0']
ls_side = ['left', 'right']

# %% [markdown]
# Save blocks

# %%
subs = find_paths.find_available_subs(folder)

# %%
# Reloading own functions
importlib.reload(import_dat)
importlib.reload(tasks)
importlib.reload(find_paths)

for sub in subs:
    for task in ls_task:
        for side in ls_side:
            for cam in ls_cam:
                for cond in ls_cond:
                    try:
                        # get defined data
                        data = import_dat.get_data(
                            folder=folder, sub=sub, cam_pos=cam,
                            task=task, condition=cond, side=side,
                        )

                        # get block dataframes
                        blocks = tasks.block_extraction(
                            data, sub=sub, task=task, side=side,
                            cond=cond, cam=cam,
                            to_save=True, to_plot = True
                        )

                    except:
                        print('\n')
# Out:
# No files available for combination: ('ul001', 'vr', 'ft', 'm0s0', 'left')
#
#
# No files available for combination: ('ul001', 'vr', 'ft', 'm1s0', 'left')
#
#
# No files available for combination: ('ul001', 'vr', 'ft', 'm1s1', 'left')
#
#
# No files available for combination: ('ul001', 'vr', 'ft', 'm0s1', 'left')
#
#
# No files available for combination: ('ul001', 'vr', 'ft', 'm0', 'left')
#
#
# No files available for combination: ('ul001', 'dt', 'ft', 'm0s0', 'left')
#
#
# No files available for combination: ('ul001', 'dt', 'ft', 'm1s0', 'left')
#
#
# No files available for combination: ('ul001', 'dt', 'ft', 'm1s1', 'left')
#
#
# No files available for combination: ('ul001', 'dt', 'ft', 'm0s1', 'left')
#
#
# No files available for combination: ('ul001', 'dt', 'ft', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul001', 'vr', 'ft', 'm0s0', 'right')
#
#
# No files available for combination: ('ul001', 'vr', 'ft', 'm1s0', 'right')
#
#
# No files available for combination: ('ul001', 'vr', 'ft', 'm1s1', 'right')
#
#
# No files available for combination: ('ul001', 'vr', 'ft', 'm0s1', 'right')
#
#
# No files available for combination: ('ul001', 'vr', 'ft', 'm0', 'right')
#
#
# No files available for combination: ('ul001', 'dt', 'ft', 'm0s0', 'right')
#
#
# No files available for combination: ('ul001', 'dt', 'ft', 'm1s0', 'right')
#
#
# No files available for combination: ('ul001', 'dt', 'ft', 'm1s1', 'right')
#
#
# No files available for combination: ('ul001', 'dt', 'ft', 'm0s1', 'right')
#
#
# No files available for combination: ('ul001', 'dt', 'ft', 'm0', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul001', 'vr', 'oc', 'm0s0', 'left')
#
#
# No files available for combination: ('ul001', 'vr', 'oc', 'm1s0', 'left')
#
#
# No files available for combination: ('ul001', 'vr', 'oc', 'm1s1', 'left')
#
#
# No files available for combination: ('ul001', 'vr', 'oc', 'm0s1', 'left')
#
#
# No files available for combination: ('ul001', 'vr', 'oc', 'm0', 'left')
#
#
# No files available for combination: ('ul001', 'dt', 'oc', 'm0s0', 'left')
#
#
# No files available for combination: ('ul001', 'dt', 'oc', 'm1s0', 'left')
#
#
# No files available for combination: ('ul001', 'dt', 'oc', 'm1s1', 'left')
#
#
# No files available for combination: ('ul001', 'dt', 'oc', 'm0s1', 'left')
#
#
# No files available for combination: ('ul001', 'dt', 'oc', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul001', 'vr', 'oc', 'm0s0', 'right')
#
#
# No files available for combination: ('ul001', 'vr', 'oc', 'm1s0', 'right')
#
#
# No files available for combination: ('ul001', 'vr', 'oc', 'm1s1', 'right')
#
#
# No files available for combination: ('ul001', 'vr', 'oc', 'm0s1', 'right')
#
#
# No files available for combination: ('ul001', 'vr', 'oc', 'm0', 'right')
#
#
# No files available for combination: ('ul001', 'dt', 'oc', 'm0s0', 'right')
#
#
# No files available for combination: ('ul001', 'dt', 'oc', 'm1s0', 'right')
#
#
# No files available for combination: ('ul001', 'dt', 'oc', 'm1s1', 'right')
#
#
# No files available for combination: ('ul001', 'dt', 'oc', 'm0s1', 'right')
#
#
# No files available for combination: ('ul001', 'dt', 'oc', 'm0', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul001', 'vr', 'ps', 'm0s0', 'left')
#
#
# No files available for combination: ('ul001', 'vr', 'ps', 'm1s0', 'left')
#
#
# No files available for combination: ('ul001', 'vr', 'ps', 'm1s1', 'left')
#
#
# No files available for combination: ('ul001', 'vr', 'ps', 'm0s1', 'left')
#
#
# No files available for combination: ('ul001', 'vr', 'ps', 'm0', 'left')
#
#
# No files available for combination: ('ul001', 'dt', 'ps', 'm0s0', 'left')
#
#
# No files available for combination: ('ul001', 'dt', 'ps', 'm1s0', 'left')
#
#
# No files available for combination: ('ul001', 'dt', 'ps', 'm1s1', 'left')
#
#
# No files available for combination: ('ul001', 'dt', 'ps', 'm0s1', 'left')
#
#
# No files available for combination: ('ul001', 'dt', 'ps', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul001', 'vr', 'ps', 'm0s0', 'right')
#
#
# No files available for combination: ('ul001', 'vr', 'ps', 'm1s0', 'right')
#
#
# No files available for combination: ('ul001', 'vr', 'ps', 'm1s1', 'right')
#
#
# No files available for combination: ('ul001', 'vr', 'ps', 'm0s1', 'right')
#
#
# No files available for combination: ('ul001', 'vr', 'ps', 'm0', 'right')
#
#
# No files available for combination: ('ul001', 'dt', 'ps', 'm0s0', 'right')
#
#
# No files available for combination: ('ul001', 'dt', 'ps', 'm1s0', 'right')
#
#
# No files available for combination: ('ul001', 'dt', 'ps', 'm1s1', 'right')
#
#
# No files available for combination: ('ul001', 'dt', 'ps', 'm0s1', 'right')
#
#
# No files available for combination: ('ul001', 'dt', 'ps', 'm0', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul001', 'vr', 'pt', 'm0s0', 'left')
#
#
# No files available for combination: ('ul001', 'vr', 'pt', 'm1s0', 'left')
#
#
# No files available for combination: ('ul001', 'vr', 'pt', 'm1s1', 'left')
#
#
# No files available for combination: ('ul001', 'vr', 'pt', 'm0s1', 'left')
#
#
# No files available for combination: ('ul001', 'vr', 'pt', 'm0', 'left')
#
#
# No files available for combination: ('ul001', 'dt', 'pt', 'm0s0', 'left')
#
#
# No files available for combination: ('ul001', 'dt', 'pt', 'm1s0', 'left')
#
#
# No files available for combination: ('ul001', 'dt', 'pt', 'm1s1', 'left')
#
#
# No files available for combination: ('ul001', 'dt', 'pt', 'm0s1', 'left')
#
#
# No files available for combination: ('ul001', 'dt', 'pt', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul001', 'vr', 'pt', 'm0s0', 'right')
#
#
# No files available for combination: ('ul001', 'vr', 'pt', 'm1s0', 'right')
#
#
# No files available for combination: ('ul001', 'vr', 'pt', 'm1s1', 'right')
#
#
# No files available for combination: ('ul001', 'vr', 'pt', 'm0s1', 'right')
#
#
# No files available for combination: ('ul001', 'vr', 'pt', 'm0', 'right')
#
#
# No files available for combination: ('ul001', 'dt', 'pt', 'm0s0', 'right')
#
#
# No files available for combination: ('ul001', 'dt', 'pt', 'm1s0', 'right')
#
#
# No files available for combination: ('ul001', 'dt', 'pt', 'm1s1', 'right')
#
#
# No files available for combination: ('ul001', 'dt', 'pt', 'm0s1', 'right')
#
#
# No files available for combination: ('ul001', 'dt', 'pt', 'm0', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul002', 'vr', 'ft', 'm0s0', 'left')
#
#
# No files available for combination: ('ul002', 'vr', 'ft', 'm1s0', 'left')
#
#
# No files available for combination: ('ul002', 'vr', 'ft', 'm1s1', 'left')
#
#
# No files available for combination: ('ul002', 'vr', 'ft', 'm0s1', 'left')
#
#
# No files available for combination: ('ul002', 'vr', 'ft', 'm0', 'left')
#
#
# No files available for combination: ('ul002', 'dt', 'ft', 'm0s0', 'left')
#
#
# No files available for combination: ('ul002', 'dt', 'ft', 'm1s0', 'left')
#
#
# No files available for combination: ('ul002', 'dt', 'ft', 'm1s1', 'left')
#
#
# No files available for combination: ('ul002', 'dt', 'ft', 'm0s1', 'left')
#
#
# No files available for combination: ('ul002', 'dt', 'ft', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul002', 'vr', 'ft', 'm0s0', 'right')
#
#
# No files available for combination: ('ul002', 'vr', 'ft', 'm1s0', 'right')
#
#
# No files available for combination: ('ul002', 'vr', 'ft', 'm1s1', 'right')
#
#
# No files available for combination: ('ul002', 'vr', 'ft', 'm0s1', 'right')
#
#
# No files available for combination: ('ul002', 'vr', 'ft', 'm0', 'right')
#
#
# No files available for combination: ('ul002', 'dt', 'ft', 'm0s0', 'right')
#
#
# No files available for combination: ('ul002', 'dt', 'ft', 'm1s0', 'right')
#
#
# No files available for combination: ('ul002', 'dt', 'ft', 'm1s1', 'right')
#
#
# No files available for combination: ('ul002', 'dt', 'ft', 'm0s1', 'right')
#
#
# No files available for combination: ('ul002', 'dt', 'ft', 'm0', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul002', 'vr', 'oc', 'm0s0', 'left')
#
#
# No files available for combination: ('ul002', 'vr', 'oc', 'm1s0', 'left')
#
#
# No files available for combination: ('ul002', 'vr', 'oc', 'm1s1', 'left')
#
#
# No files available for combination: ('ul002', 'vr', 'oc', 'm0s1', 'left')
#
#
# No files available for combination: ('ul002', 'vr', 'oc', 'm0', 'left')
#
#
# No files available for combination: ('ul002', 'dt', 'oc', 'm0s0', 'left')
#
#
# No files available for combination: ('ul002', 'dt', 'oc', 'm1s0', 'left')
#
#
# No files available for combination: ('ul002', 'dt', 'oc', 'm1s1', 'left')
#
#
# No files available for combination: ('ul002', 'dt', 'oc', 'm0s1', 'left')
#
#
# No files available for combination: ('ul002', 'dt', 'oc', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul002', 'vr', 'oc', 'm0s0', 'right')
#
#
# No files available for combination: ('ul002', 'vr', 'oc', 'm1s0', 'right')
#
#
# No files available for combination: ('ul002', 'vr', 'oc', 'm1s1', 'right')
#
#
# No files available for combination: ('ul002', 'vr', 'oc', 'm0s1', 'right')
#
#
# No files available for combination: ('ul002', 'vr', 'oc', 'm0', 'right')
#
#
# No files available for combination: ('ul002', 'dt', 'oc', 'm0s0', 'right')
#
#
# No files available for combination: ('ul002', 'dt', 'oc', 'm1s0', 'right')
#
#
# No files available for combination: ('ul002', 'dt', 'oc', 'm1s1', 'right')
#
#
# No files available for combination: ('ul002', 'dt', 'oc', 'm0s1', 'right')
#
#
# No files available for combination: ('ul002', 'dt', 'oc', 'm0', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul002', 'vr', 'ps', 'm0s0', 'left')
#
#
# No files available for combination: ('ul002', 'vr', 'ps', 'm1s0', 'left')
#
#
# No files available for combination: ('ul002', 'vr', 'ps', 'm1s1', 'left')
#
#
# No files available for combination: ('ul002', 'vr', 'ps', 'm0s1', 'left')
#
#
# No files available for combination: ('ul002', 'vr', 'ps', 'm0', 'left')
#
#
# No files available for combination: ('ul002', 'dt', 'ps', 'm0s0', 'left')
#
#
# No files available for combination: ('ul002', 'dt', 'ps', 'm1s0', 'left')
#
#
# No files available for combination: ('ul002', 'dt', 'ps', 'm1s1', 'left')
#
#
# No files available for combination: ('ul002', 'dt', 'ps', 'm0s1', 'left')
#
#
# No files available for combination: ('ul002', 'dt', 'ps', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul002', 'vr', 'ps', 'm0s0', 'right')
#
#
# No files available for combination: ('ul002', 'vr', 'ps', 'm1s0', 'right')
#
#
# No files available for combination: ('ul002', 'vr', 'ps', 'm1s1', 'right')
#
#
# No files available for combination: ('ul002', 'vr', 'ps', 'm0s1', 'right')
#
#
# No files available for combination: ('ul002', 'vr', 'ps', 'm0', 'right')
#
#
# No files available for combination: ('ul002', 'dt', 'ps', 'm0s0', 'right')
#
#
# No files available for combination: ('ul002', 'dt', 'ps', 'm1s0', 'right')
#
#
# No files available for combination: ('ul002', 'dt', 'ps', 'm1s1', 'right')
#
#
# No files available for combination: ('ul002', 'dt', 'ps', 'm0s1', 'right')
#
#
# No files available for combination: ('ul002', 'dt', 'ps', 'm0', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul002', 'vr', 'pt', 'm0s0', 'left')
#
#
# No files available for combination: ('ul002', 'vr', 'pt', 'm1s0', 'left')
#
#
# No files available for combination: ('ul002', 'vr', 'pt', 'm1s1', 'left')
#
#
# No files available for combination: ('ul002', 'vr', 'pt', 'm0s1', 'left')
#
#
# No files available for combination: ('ul002', 'vr', 'pt', 'm0', 'left')
#
#
# No files available for combination: ('ul002', 'dt', 'pt', 'm0s0', 'left')
#
#
# No files available for combination: ('ul002', 'dt', 'pt', 'm1s0', 'left')
#
#
# No files available for combination: ('ul002', 'dt', 'pt', 'm1s1', 'left')
#
#
# No files available for combination: ('ul002', 'dt', 'pt', 'm0s1', 'left')
#
#
# No files available for combination: ('ul002', 'dt', 'pt', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul002', 'vr', 'pt', 'm0s0', 'right')
#
#
# No files available for combination: ('ul002', 'vr', 'pt', 'm1s0', 'right')
#
#
# No files available for combination: ('ul002', 'vr', 'pt', 'm1s1', 'right')
#
#
# No files available for combination: ('ul002', 'vr', 'pt', 'm0s1', 'right')
#
#
# No files available for combination: ('ul002', 'vr', 'pt', 'm0', 'right')
#
#
# No files available for combination: ('ul002', 'dt', 'pt', 'm0s0', 'right')
#
#
# No files available for combination: ('ul002', 'dt', 'pt', 'm1s0', 'right')
#
#
# No files available for combination: ('ul002', 'dt', 'pt', 'm1s1', 'right')
#
#
# No files available for combination: ('ul002', 'dt', 'pt', 'm0s1', 'right')
#
#
# No files available for combination: ('ul002', 'dt', 'pt', 'm0', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul003', 'vr', 'ft', 'm0s0', 'left')
#
#
# No files available for combination: ('ul003', 'vr', 'ft', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul003', 'vr', 'ft', 'm0', 'left')
#
#
# No files available for combination: ('ul003', 'dt', 'ft', 'm0s0', 'left')
#
#
# No files available for combination: ('ul003', 'dt', 'ft', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul003', 'dt', 'ft', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul003', 'vr', 'ft', 'm0s0', 'right')
#
#
# No files available for combination: ('ul003', 'vr', 'ft', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul003', 'vr', 'ft', 'm0', 'right')
#
#
# No files available for combination: ('ul003', 'dt', 'ft', 'm0s0', 'right')
#
#
# No files available for combination: ('ul003', 'dt', 'ft', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul003', 'dt', 'ft', 'm0', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul003', 'vr', 'oc', 'm0s0', 'left')
#
#
#
#
# No files available for combination: ('ul003', 'vr', 'oc', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul003', 'vr', 'oc', 'm0', 'left')
#
#
# No files available for combination: ('ul003', 'dt', 'oc', 'm0s0', 'left')
#
#
#
#
#
#
# No files available for combination: ('ul003', 'dt', 'oc', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul003', 'dt', 'oc', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul003', 'vr', 'oc', 'm0s0', 'right')
#
#
# No files available for combination: ('ul003', 'vr', 'oc', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul003', 'vr', 'oc', 'm0', 'right')
#
#
# No files available for combination: ('ul003', 'dt', 'oc', 'm0s0', 'right')
#
#
# No files available for combination: ('ul003', 'dt', 'oc', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul003', 'dt', 'oc', 'm0', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul003', 'vr', 'ps', 'm0s0', 'left')
#
#
# No files available for combination: ('ul003', 'vr', 'ps', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul003', 'vr', 'ps', 'm0', 'left')
#
#
# No files available for combination: ('ul003', 'dt', 'ps', 'm0s0', 'left')
#
#
# No files available for combination: ('ul003', 'dt', 'ps', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul003', 'dt', 'ps', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul003', 'vr', 'ps', 'm0s0', 'right')
#
#
# No files available for combination: ('ul003', 'vr', 'ps', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul003', 'vr', 'ps', 'm0', 'right')
#
#
# No files available for combination: ('ul003', 'dt', 'ps', 'm0s0', 'right')
#
#
# No files available for combination: ('ul003', 'dt', 'ps', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul003', 'dt', 'ps', 'm0', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul003', 'vr', 'pt', 'm0s0', 'left')
#
#
# No files available for combination: ('ul003', 'vr', 'pt', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul003', 'vr', 'pt', 'm0', 'left')
#
#
# No files available for combination: ('ul003', 'dt', 'pt', 'm0s0', 'left')
#
#
# No files available for combination: ('ul003', 'dt', 'pt', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul003', 'dt', 'pt', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul003', 'vr', 'pt', 'm0s0', 'right')
#
#
# No files available for combination: ('ul003', 'vr', 'pt', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul003', 'vr', 'pt', 'm0', 'right')
#
#
# No files available for combination: ('ul003', 'dt', 'pt', 'm0s0', 'right')
#
#
# No files available for combination: ('ul003', 'dt', 'pt', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul003', 'dt', 'pt', 'm0', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul004', 'vr', 'ft', 'm0s0', 'left')
#
#
# No files available for combination: ('ul004', 'vr', 'ft', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul004', 'vr', 'ft', 'm0', 'left')
#
#
# No files available for combination: ('ul004', 'dt', 'ft', 'm0s0', 'left')
#
#
# No files available for combination: ('ul004', 'dt', 'ft', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul004', 'dt', 'ft', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul004', 'vr', 'ft', 'm0s0', 'right')
#
#
# No files available for combination: ('ul004', 'vr', 'ft', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul004', 'vr', 'ft', 'm0', 'right')
#
#
# No files available for combination: ('ul004', 'dt', 'ft', 'm0s0', 'right')
#
#
# No files available for combination: ('ul004', 'dt', 'ft', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul004', 'dt', 'ft', 'm0', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul004', 'vr', 'oc', 'm0s0', 'left')
#
#
# No files available for combination: ('ul004', 'vr', 'oc', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul004', 'vr', 'oc', 'm0', 'left')
#
#
# No files available for combination: ('ul004', 'dt', 'oc', 'm0s0', 'left')
#
#
# No files available for combination: ('ul004', 'dt', 'oc', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul004', 'dt', 'oc', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul004', 'vr', 'oc', 'm0s0', 'right')
#
#
# No files available for combination: ('ul004', 'vr', 'oc', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul004', 'vr', 'oc', 'm0', 'right')
#
#
# No files available for combination: ('ul004', 'dt', 'oc', 'm0s0', 'right')
#
#
# No files available for combination: ('ul004', 'dt', 'oc', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul004', 'dt', 'oc', 'm0', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul004', 'vr', 'ps', 'm0s0', 'left')
#
#
# No files available for combination: ('ul004', 'vr', 'ps', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul004', 'vr', 'ps', 'm0', 'left')
#
#
# No files available for combination: ('ul004', 'dt', 'ps', 'm0s0', 'left')
#
#
# No files available for combination: ('ul004', 'dt', 'ps', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul004', 'dt', 'ps', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul004', 'vr', 'ps', 'm0s0', 'right')
#
#
# No files available for combination: ('ul004', 'vr', 'ps', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul004', 'vr', 'ps', 'm0', 'right')
#
#
# No files available for combination: ('ul004', 'dt', 'ps', 'm0s0', 'right')
#
#
#
#
# No files available for combination: ('ul004', 'dt', 'ps', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul004', 'dt', 'ps', 'm0', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul004', 'vr', 'pt', 'm0s0', 'left')
#
#
# No files available for combination: ('ul004', 'vr', 'pt', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul004', 'vr', 'pt', 'm0', 'left')
#
#
# No files available for combination: ('ul004', 'dt', 'pt', 'm0s0', 'left')
#
#
# No files available for combination: ('ul004', 'dt', 'pt', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul004', 'dt', 'pt', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul004', 'vr', 'pt', 'm0s0', 'right')
#
#
# No files available for combination: ('ul004', 'vr', 'pt', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul004', 'vr', 'pt', 'm0', 'right')
#
#
# No files available for combination: ('ul004', 'dt', 'pt', 'm0s0', 'right')
#
#
# No files available for combination: ('ul004', 'dt', 'pt', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul004', 'dt', 'pt', 'm0', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul005', 'vr', 'ft', 'm0s0', 'left')
#
#
# No files available for combination: ('ul005', 'vr', 'ft', 'm1s0', 'left')
#
#
# No files available for combination: ('ul005', 'vr', 'ft', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul005', 'vr', 'ft', 'm0', 'left')
#
#
# No files available for combination: ('ul005', 'dt', 'ft', 'm0s0', 'left')
#
#
# No files available for combination: ('ul005', 'dt', 'ft', 'm1s0', 'left')
#
#
# No files available for combination: ('ul005', 'dt', 'ft', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul005', 'dt', 'ft', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul005', 'vr', 'ft', 'm0s0', 'right')
#
#
# No files available for combination: ('ul005', 'vr', 'ft', 'm1s0', 'right')
#
#
# No files available for combination: ('ul005', 'vr', 'ft', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul005', 'vr', 'ft', 'm0', 'right')
#
#
# No files available for combination: ('ul005', 'dt', 'ft', 'm0s0', 'right')
#
#
# No files available for combination: ('ul005', 'dt', 'ft', 'm1s0', 'right')
#
#
# No files available for combination: ('ul005', 'dt', 'ft', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul005', 'dt', 'ft', 'm0', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul005', 'vr', 'oc', 'm0s0', 'left')
#
#
# No files available for combination: ('ul005', 'vr', 'oc', 'm1s0', 'left')
#
#
# No files available for combination: ('ul005', 'vr', 'oc', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul005', 'vr', 'oc', 'm0', 'left')
#
#
# No files available for combination: ('ul005', 'dt', 'oc', 'm0s0', 'left')
#
#
# No files available for combination: ('ul005', 'dt', 'oc', 'm1s0', 'left')
#
#
# No files available for combination: ('ul005', 'dt', 'oc', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul005', 'dt', 'oc', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul005', 'vr', 'oc', 'm0s0', 'right')
#
#
# No files available for combination: ('ul005', 'vr', 'oc', 'm1s0', 'right')
#
#
# No files available for combination: ('ul005', 'vr', 'oc', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul005', 'vr', 'oc', 'm0', 'right')
#
#
# No files available for combination: ('ul005', 'dt', 'oc', 'm0s0', 'right')
#
#
# No files available for combination: ('ul005', 'dt', 'oc', 'm1s0', 'right')
#
#
# No files available for combination: ('ul005', 'dt', 'oc', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul005', 'dt', 'oc', 'm0', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul005', 'vr', 'ps', 'm0s0', 'left')
#
#
# No files available for combination: ('ul005', 'vr', 'ps', 'm1s0', 'left')
#
#
# No files available for combination: ('ul005', 'vr', 'ps', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul005', 'vr', 'ps', 'm0', 'left')
#
#
# No files available for combination: ('ul005', 'dt', 'ps', 'm0s0', 'left')
#
#
# No files available for combination: ('ul005', 'dt', 'ps', 'm1s0', 'left')
#
#
# No files available for combination: ('ul005', 'dt', 'ps', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul005', 'dt', 'ps', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul005', 'vr', 'ps', 'm0s0', 'right')
#
#
# No files available for combination: ('ul005', 'vr', 'ps', 'm1s0', 'right')
#
#
# No files available for combination: ('ul005', 'vr', 'ps', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul005', 'vr', 'ps', 'm0', 'right')
#
#
# No files available for combination: ('ul005', 'dt', 'ps', 'm0s0', 'right')
#
#
# No files available for combination: ('ul005', 'dt', 'ps', 'm1s0', 'right')
#
#
# No files available for combination: ('ul005', 'dt', 'ps', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul005', 'dt', 'ps', 'm0', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul005', 'vr', 'pt', 'm0s0', 'left')
#
#
# No files available for combination: ('ul005', 'vr', 'pt', 'm1s0', 'left')
#
#
# No files available for combination: ('ul005', 'vr', 'pt', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul005', 'vr', 'pt', 'm0', 'left')
#
#
# No files available for combination: ('ul005', 'dt', 'pt', 'm0s0', 'left')
#
#
# No files available for combination: ('ul005', 'dt', 'pt', 'm1s0', 'left')
#
#
# No files available for combination: ('ul005', 'dt', 'pt', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul005', 'dt', 'pt', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul005', 'vr', 'pt', 'm0s0', 'right')
#
#
# No files available for combination: ('ul005', 'vr', 'pt', 'm1s0', 'right')
#
#
#
#
# No files available for combination: ('ul005', 'vr', 'pt', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul005', 'vr', 'pt', 'm0', 'right')
#
#
# No files available for combination: ('ul005', 'dt', 'pt', 'm0s0', 'right')
#
#
# No files available for combination: ('ul005', 'dt', 'pt', 'm1s0', 'right')
#
#
# No files available for combination: ('ul005', 'dt', 'pt', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul005', 'dt', 'pt', 'm0', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul006', 'vr', 'ft', 'm0s0', 'left')
#
#
#
#
# No files available for combination: ('ul006', 'vr', 'ft', 'm1s1', 'left')
#
#
# No files available for combination: ('ul006', 'vr', 'ft', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul006', 'vr', 'ft', 'm0', 'left')
#
#
#
#
# No files available for combination: ('ul006', 'dt', 'ft', 'm1s0', 'left')
#
#
# No files available for combination: ('ul006', 'dt', 'ft', 'm1s1', 'left')
#
#
# No files available for combination: ('ul006', 'dt', 'ft', 'm0s1', 'left')
#
#
# No files available for combination: ('ul006', 'dt', 'ft', 'm1', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul006', 'vr', 'ft', 'm0s0', 'right')
#
#
#
#
# No files available for combination: ('ul006', 'vr', 'ft', 'm1s1', 'right')
#
#
# No files available for combination: ('ul006', 'vr', 'ft', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul006', 'vr', 'ft', 'm0', 'right')
#
#
#
#
# No files available for combination: ('ul006', 'dt', 'ft', 'm1s0', 'right')
#
#
# No files available for combination: ('ul006', 'dt', 'ft', 'm1s1', 'right')
#
#
# No files available for combination: ('ul006', 'dt', 'ft', 'm0s1', 'right')
#
#
# No files available for combination: ('ul006', 'dt', 'ft', 'm1', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul006', 'vr', 'oc', 'm0s0', 'left')
#
#
# No files available for combination: ('ul006', 'vr', 'oc', 'm1s0', 'left')
#
#
# No files available for combination: ('ul006', 'vr', 'oc', 'm1s1', 'left')
#
#
# No files available for combination: ('ul006', 'vr', 'oc', 'm0s1', 'left')
#
#
# No files available for combination: ('ul006', 'vr', 'oc', 'm1', 'left')
#
#
# No files available for combination: ('ul006', 'vr', 'oc', 'm0', 'left')
#
#
# No files available for combination: ('ul006', 'dt', 'oc', 'm0s0', 'left')
#
#
# No files available for combination: ('ul006', 'dt', 'oc', 'm1s0', 'left')
#
#
# No files available for combination: ('ul006', 'dt', 'oc', 'm1s1', 'left')
#
#
# No files available for combination: ('ul006', 'dt', 'oc', 'm0s1', 'left')
#
#
# No files available for combination: ('ul006', 'dt', 'oc', 'm1', 'left')
#
#
# No files available for combination: ('ul006', 'dt', 'oc', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul006', 'vr', 'oc', 'm0s0', 'right')
#
#
# No files available for combination: ('ul006', 'vr', 'oc', 'm1s0', 'right')
#
#
# No files available for combination: ('ul006', 'vr', 'oc', 'm1s1', 'right')
#
#
# No files available for combination: ('ul006', 'vr', 'oc', 'm0s1', 'right')
#
#
# No files available for combination: ('ul006', 'vr', 'oc', 'm1', 'right')
#
#
# No files available for combination: ('ul006', 'vr', 'oc', 'm0', 'right')
#
#
# No files available for combination: ('ul006', 'dt', 'oc', 'm0s0', 'right')
#
#
# No files available for combination: ('ul006', 'dt', 'oc', 'm1s0', 'right')
#
#
# No files available for combination: ('ul006', 'dt', 'oc', 'm1s1', 'right')
#
#
# No files available for combination: ('ul006', 'dt', 'oc', 'm0s1', 'right')
#
#
# No files available for combination: ('ul006', 'dt', 'oc', 'm1', 'right')
#
#
# No files available for combination: ('ul006', 'dt', 'oc', 'm0', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul006', 'vr', 'ps', 'm0s0', 'left')
#
#
# No files available for combination: ('ul006', 'vr', 'ps', 'm1s0', 'left')
#
#
# No files available for combination: ('ul006', 'vr', 'ps', 'm1s1', 'left')
#
#
# No files available for combination: ('ul006', 'vr', 'ps', 'm0s1', 'left')
#
#
# No files available for combination: ('ul006', 'vr', 'ps', 'm1', 'left')
#
#
# No files available for combination: ('ul006', 'vr', 'ps', 'm0', 'left')
#
#
# No files available for combination: ('ul006', 'dt', 'ps', 'm0s0', 'left')
#
#
# No files available for combination: ('ul006', 'dt', 'ps', 'm1s0', 'left')
#
#
# No files available for combination: ('ul006', 'dt', 'ps', 'm1s1', 'left')
#
#
# No files available for combination: ('ul006', 'dt', 'ps', 'm0s1', 'left')
#
#
# No files available for combination: ('ul006', 'dt', 'ps', 'm1', 'left')
#
#
# No files available for combination: ('ul006', 'dt', 'ps', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul006', 'vr', 'ps', 'm0s0', 'right')
#
#
# No files available for combination: ('ul006', 'vr', 'ps', 'm1s0', 'right')
#
#
# No files available for combination: ('ul006', 'vr', 'ps', 'm1s1', 'right')
#
#
# No files available for combination: ('ul006', 'vr', 'ps', 'm0s1', 'right')
#
#
# No files available for combination: ('ul006', 'vr', 'ps', 'm1', 'right')
#
#
# No files available for combination: ('ul006', 'vr', 'ps', 'm0', 'right')
#
#
# No files available for combination: ('ul006', 'dt', 'ps', 'm0s0', 'right')
#
#
# No files available for combination: ('ul006', 'dt', 'ps', 'm1s0', 'right')
#
#
# No files available for combination: ('ul006', 'dt', 'ps', 'm1s1', 'right')
#
#
# No files available for combination: ('ul006', 'dt', 'ps', 'm0s1', 'right')
#
#
# No files available for combination: ('ul006', 'dt', 'ps', 'm1', 'right')
#
#
# No files available for combination: ('ul006', 'dt', 'ps', 'm0', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul006', 'vr', 'pt', 'm0s0', 'left')
#
#
# No files available for combination: ('ul006', 'vr', 'pt', 'm1s0', 'left')
#
#
# No files available for combination: ('ul006', 'vr', 'pt', 'm1s1', 'left')
#
#
# No files available for combination: ('ul006', 'vr', 'pt', 'm0s1', 'left')
#
#
# No files available for combination: ('ul006', 'vr', 'pt', 'm1', 'left')
#
#
# No files available for combination: ('ul006', 'vr', 'pt', 'm0', 'left')
#
#
# No files available for combination: ('ul006', 'dt', 'pt', 'm0s0', 'left')
#
#
# No files available for combination: ('ul006', 'dt', 'pt', 'm1s0', 'left')
#
#
# No files available for combination: ('ul006', 'dt', 'pt', 'm1s1', 'left')
#
#
# No files available for combination: ('ul006', 'dt', 'pt', 'm0s1', 'left')
#
#
# No files available for combination: ('ul006', 'dt', 'pt', 'm1', 'left')
#
#
# No files available for combination: ('ul006', 'dt', 'pt', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul006', 'vr', 'pt', 'm0s0', 'right')
#
#
# No files available for combination: ('ul006', 'vr', 'pt', 'm1s0', 'right')
#
#
# No files available for combination: ('ul006', 'vr', 'pt', 'm1s1', 'right')
#
#
# No files available for combination: ('ul006', 'vr', 'pt', 'm0s1', 'right')
#
#
# No files available for combination: ('ul006', 'vr', 'pt', 'm1', 'right')
#
#
# No files available for combination: ('ul006', 'vr', 'pt', 'm0', 'right')
#
#
# No files available for combination: ('ul006', 'dt', 'pt', 'm0s0', 'right')
#
#
# No files available for combination: ('ul006', 'dt', 'pt', 'm1s0', 'right')
#
#
# No files available for combination: ('ul006', 'dt', 'pt', 'm1s1', 'right')
#
#
# No files available for combination: ('ul006', 'dt', 'pt', 'm0s1', 'right')
#
#
# No files available for combination: ('ul006', 'dt', 'pt', 'm1', 'right')
#
#
# No files available for combination: ('ul006', 'dt', 'pt', 'm0', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul007', 'vr', 'ft', 'm1s0', 'left')
#
#
# No files available for combination: ('ul007', 'vr', 'ft', 'm0s1', 'left')
#
#
#
#
#
#
# No files available for combination: ('ul007', 'dt', 'ft', 'm0s0', 'left')
#
#
# No files available for combination: ('ul007', 'dt', 'ft', 'm1s1', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul007', 'vr', 'ft', 'm1s0', 'right')
#
#
# No files available for combination: ('ul007', 'vr', 'ft', 'm0s1', 'right')
#
#
#
#
#
#
# No files available for combination: ('ul007', 'dt', 'ft', 'm0s0', 'right')
#
#
# No files available for combination: ('ul007', 'dt', 'ft', 'm1s1', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul007', 'vr', 'oc', 'm1s0', 'left')
#
#
# No files available for combination: ('ul007', 'vr', 'oc', 'm0s1', 'left')
#
#
#
#
#
#
# No files available for combination: ('ul007', 'dt', 'oc', 'm0s0', 'left')
#
#
# No files available for combination: ('ul007', 'dt', 'oc', 'm1s1', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul007', 'vr', 'oc', 'm1s0', 'right')
#
#
# No files available for combination: ('ul007', 'vr', 'oc', 'm0s1', 'right')
#
#
#
#
#
#
# No files available for combination: ('ul007', 'dt', 'oc', 'm0s0', 'right')
#
#
# No files available for combination: ('ul007', 'dt', 'oc', 'm1s1', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul007', 'vr', 'ps', 'm1s0', 'left')
#
#
# No files available for combination: ('ul007', 'vr', 'ps', 'm0s1', 'left')
#
#
#
#
#
#
# No files available for combination: ('ul007', 'dt', 'ps', 'm0s0', 'left')
#
#
# No files available for combination: ('ul007', 'dt', 'ps', 'm1s1', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul007', 'vr', 'ps', 'm1s0', 'right')
#
#
# No files available for combination: ('ul007', 'vr', 'ps', 'm0s1', 'right')
#
#
#
#
#
#
# No files available for combination: ('ul007', 'dt', 'ps', 'm0s0', 'right')
#
#
# No files available for combination: ('ul007', 'dt', 'ps', 'm1s1', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul007', 'vr', 'pt', 'm1s0', 'left')
#
#
# No files available for combination: ('ul007', 'vr', 'pt', 'm0s1', 'left')
#
#
#
#
#
#
# No files available for combination: ('ul007', 'dt', 'pt', 'm0s0', 'left')
#
#
# No files available for combination: ('ul007', 'dt', 'pt', 'm1s1', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul007', 'vr', 'pt', 'm1s0', 'right')
#
#
# No files available for combination: ('ul007', 'vr', 'pt', 'm0s1', 'right')
#
#
#
#
#
#
# No files available for combination: ('ul007', 'dt', 'pt', 'm0s0', 'right')
#
#
# No files available for combination: ('ul007', 'dt', 'pt', 'm1s1', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul008', 'vr', 'ft', 'm0s0', 'left')
#
#
# No files available for combination: ('ul008', 'vr', 'ft', 'm1s1', 'left')
#
#
#
#
#
#
# No files available for combination: ('ul008', 'dt', 'ft', 'm1s0', 'left')
#
#
# No files available for combination: ('ul008', 'dt', 'ft', 'm0s1', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul008', 'vr', 'ft', 'm0s0', 'right')
#
#
# No files available for combination: ('ul008', 'vr', 'ft', 'm1s1', 'right')
#
#
#
#
#
#
# No files available for combination: ('ul008', 'dt', 'ft', 'm1s0', 'right')
#
#
# No files available for combination: ('ul008', 'dt', 'ft', 'm0s1', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul008', 'vr', 'oc', 'm0s0', 'left')
#
#
# No files available for combination: ('ul008', 'vr', 'oc', 'm1s1', 'left')
#
#
#
#
#
#
# No files available for combination: ('ul008', 'dt', 'oc', 'm1s0', 'left')
#
#
# No files available for combination: ('ul008', 'dt', 'oc', 'm0s1', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul008', 'vr', 'oc', 'm0s0', 'right')
#
#
# No files available for combination: ('ul008', 'vr', 'oc', 'm1s1', 'right')
#
#
#
#
#
#
# No files available for combination: ('ul008', 'dt', 'oc', 'm1s0', 'right')
#
#
# No files available for combination: ('ul008', 'dt', 'oc', 'm0s1', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul008', 'vr', 'ps', 'm0s0', 'left')
#
#
# No files available for combination: ('ul008', 'vr', 'ps', 'm1s1', 'left')
#
#
#
#
#
#
# No files available for combination: ('ul008', 'dt', 'ps', 'm1s0', 'left')
#
#
# No files available for combination: ('ul008', 'dt', 'ps', 'm0s1', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul008', 'vr', 'ps', 'm0s0', 'right')
#
#
# No files available for combination: ('ul008', 'vr', 'ps', 'm1s1', 'right')
#
#
#
#
#
#
# No files available for combination: ('ul008', 'dt', 'ps', 'm1s0', 'right')
#
#
# No files available for combination: ('ul008', 'dt', 'ps', 'm0s1', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul008', 'vr', 'pt', 'm0s0', 'left')
#
#
# No files available for combination: ('ul008', 'vr', 'pt', 'm1s1', 'left')
#
#
#
#
#
#
# No files available for combination: ('ul008', 'dt', 'pt', 'm1s0', 'left')
#
#
# No files available for combination: ('ul008', 'dt', 'pt', 'm0s1', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul008', 'vr', 'pt', 'm0s0', 'right')
#
#
# No files available for combination: ('ul008', 'vr', 'pt', 'm1s1', 'right')
#
#
#
#
#
#
# No files available for combination: ('ul008', 'dt', 'pt', 'm1s0', 'right')
#
#
# No files available for combination: ('ul008', 'dt', 'pt', 'm0s1', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul009', 'dt', 'ft', 'm0s0', 'left')
#
#
# No files available for combination: ('ul009', 'dt', 'ft', 'm1s0', 'left')
#
#
# No files available for combination: ('ul009', 'dt', 'ft', 'm1s1', 'left')
#
#
# No files available for combination: ('ul009', 'dt', 'ft', 'm0s1', 'left')
#
#
# No files available for combination: ('ul009', 'dt', 'ft', 'm0', 'left')
#
#
# No files available for combination: ('ul009', 'st', 'ft', 'm0s0', 'left')
#
#
# No files available for combination: ('ul009', 'st', 'ft', 'm1s0', 'left')
#
#
# No files available for combination: ('ul009', 'st', 'ft', 'm1s1', 'left')
#
#
# No files available for combination: ('ul009', 'st', 'ft', 'm0s1', 'left')
#
#
# No files available for combination: ('ul009', 'st', 'ft', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul009', 'dt', 'ft', 'm0s0', 'right')
#
#
# No files available for combination: ('ul009', 'dt', 'ft', 'm1s0', 'right')
#
#
# No files available for combination: ('ul009', 'dt', 'ft', 'm1s1', 'right')
#
#
# No files available for combination: ('ul009', 'dt', 'ft', 'm0s1', 'right')
#
#
# No files available for combination: ('ul009', 'dt', 'ft', 'm0', 'right')
#
#
# No files available for combination: ('ul009', 'st', 'ft', 'm0s0', 'right')
#
#
# No files available for combination: ('ul009', 'st', 'ft', 'm1s0', 'right')
#
#
# No files available for combination: ('ul009', 'st', 'ft', 'm1s1', 'right')
#
#
# No files available for combination: ('ul009', 'st', 'ft', 'm0s1', 'right')
#
#
# No files available for combination: ('ul009', 'st', 'ft', 'm0', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul009', 'dt', 'oc', 'm0s0', 'left')
#
#
# No files available for combination: ('ul009', 'dt', 'oc', 'm1s0', 'left')
#
#
# No files available for combination: ('ul009', 'dt', 'oc', 'm1s1', 'left')
#
#
# No files available for combination: ('ul009', 'dt', 'oc', 'm0s1', 'left')
#
#
# No files available for combination: ('ul009', 'dt', 'oc', 'm0', 'left')
#
#
# No files available for combination: ('ul009', 'st', 'oc', 'm0s0', 'left')
#
#
# No files available for combination: ('ul009', 'st', 'oc', 'm1s0', 'left')
#
#
# No files available for combination: ('ul009', 'st', 'oc', 'm1s1', 'left')
#
#
# No files available for combination: ('ul009', 'st', 'oc', 'm0s1', 'left')
#
#
# No files available for combination: ('ul009', 'st', 'oc', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul009', 'dt', 'oc', 'm0s0', 'right')
#
#
# No files available for combination: ('ul009', 'dt', 'oc', 'm1s0', 'right')
#
#
# No files available for combination: ('ul009', 'dt', 'oc', 'm1s1', 'right')
#
#
# No files available for combination: ('ul009', 'dt', 'oc', 'm0s1', 'right')
#
#
# No files available for combination: ('ul009', 'dt', 'oc', 'm0', 'right')
#
#
# No files available for combination: ('ul009', 'st', 'oc', 'm0s0', 'right')
#
#
# No files available for combination: ('ul009', 'st', 'oc', 'm1s0', 'right')
#
#
# No files available for combination: ('ul009', 'st', 'oc', 'm1s1', 'right')
#
#
# No files available for combination: ('ul009', 'st', 'oc', 'm0s1', 'right')
#
#
# No files available for combination: ('ul009', 'st', 'oc', 'm0', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul009', 'dt', 'ps', 'm0s0', 'left')
#
#
# No files available for combination: ('ul009', 'dt', 'ps', 'm1s0', 'left')
#
#
# No files available for combination: ('ul009', 'dt', 'ps', 'm1s1', 'left')
#
#
# No files available for combination: ('ul009', 'dt', 'ps', 'm0s1', 'left')
#
#
# No files available for combination: ('ul009', 'dt', 'ps', 'm0', 'left')
#
#
# No files available for combination: ('ul009', 'st', 'ps', 'm0s0', 'left')
#
#
# No files available for combination: ('ul009', 'st', 'ps', 'm1s0', 'left')
#
#
# No files available for combination: ('ul009', 'st', 'ps', 'm1s1', 'left')
#
#
# No files available for combination: ('ul009', 'st', 'ps', 'm0s1', 'left')
#
#
# No files available for combination: ('ul009', 'st', 'ps', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul009', 'dt', 'ps', 'm0s0', 'right')
#
#
# No files available for combination: ('ul009', 'dt', 'ps', 'm1s0', 'right')
#
#
# No files available for combination: ('ul009', 'dt', 'ps', 'm1s1', 'right')
#
#
# No files available for combination: ('ul009', 'dt', 'ps', 'm0s1', 'right')
#
#
# No files available for combination: ('ul009', 'dt', 'ps', 'm0', 'right')
#
#
# No files available for combination: ('ul009', 'st', 'ps', 'm0s0', 'right')
#
#
# No files available for combination: ('ul009', 'st', 'ps', 'm1s0', 'right')
#
#
# No files available for combination: ('ul009', 'st', 'ps', 'm1s1', 'right')
#
#
# No files available for combination: ('ul009', 'st', 'ps', 'm0s1', 'right')
#
#
# No files available for combination: ('ul009', 'st', 'ps', 'm0', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul009', 'dt', 'pt', 'm0s0', 'left')
#
#
# No files available for combination: ('ul009', 'dt', 'pt', 'm1s0', 'left')
#
#
# No files available for combination: ('ul009', 'dt', 'pt', 'm1s1', 'left')
#
#
# No files available for combination: ('ul009', 'dt', 'pt', 'm0s1', 'left')
#
#
# No files available for combination: ('ul009', 'dt', 'pt', 'm0', 'left')
#
#
# No files available for combination: ('ul009', 'st', 'pt', 'm0s0', 'left')
#
#
# No files available for combination: ('ul009', 'st', 'pt', 'm1s0', 'left')
#
#
# No files available for combination: ('ul009', 'st', 'pt', 'm1s1', 'left')
#
#
# No files available for combination: ('ul009', 'st', 'pt', 'm0s1', 'left')
#
#
# No files available for combination: ('ul009', 'st', 'pt', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul009', 'dt', 'pt', 'm0s0', 'right')
#
#
# No files available for combination: ('ul009', 'dt', 'pt', 'm1s0', 'right')
#
#
# No files available for combination: ('ul009', 'dt', 'pt', 'm1s1', 'right')
#
#
# No files available for combination: ('ul009', 'dt', 'pt', 'm0s1', 'right')
#
#
# No files available for combination: ('ul009', 'dt', 'pt', 'm0', 'right')
#
#
# No files available for combination: ('ul009', 'st', 'pt', 'm0s0', 'right')
#
#
# No files available for combination: ('ul009', 'st', 'pt', 'm1s0', 'right')
#
#
# No files available for combination: ('ul009', 'st', 'pt', 'm1s1', 'right')
#
#
# No files available for combination: ('ul009', 'st', 'pt', 'm0s1', 'right')
#
#
# No files available for combination: ('ul009', 'st', 'pt', 'm0', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul010', 'dt', 'ft', 'm1s0', 'left')
#
#
# No files available for combination: ('ul010', 'dt', 'ft', 'm1s1', 'left')
#
#
# No files available for combination: ('ul010', 'dt', 'ft', 'm0s1', 'left')
#
#
# No files available for combination: ('ul010', 'dt', 'ft', 'm1', 'left')
#
#
#
#
# No files available for combination: ('ul010', 'st', 'ft', 'm0s0', 'left')
#
#
# No files available for combination: ('ul010', 'st', 'ft', 'm1s1', 'left')
#
#
# No files available for combination: ('ul010', 'st', 'ft', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul010', 'st', 'ft', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul010', 'dt', 'ft', 'm1s0', 'right')
#
#
# No files available for combination: ('ul010', 'dt', 'ft', 'm1s1', 'right')
#
#
# No files available for combination: ('ul010', 'dt', 'ft', 'm0s1', 'right')
#
#
# No files available for combination: ('ul010', 'dt', 'ft', 'm1', 'right')
#
#
#
#
# No files available for combination: ('ul010', 'st', 'ft', 'm0s0', 'right')
#
#
#
#
# No files available for combination: ('ul010', 'st', 'ft', 'm1s1', 'right')
#
#
# No files available for combination: ('ul010', 'st', 'ft', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul010', 'st', 'ft', 'm0', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul010', 'dt', 'oc', 'm1s0', 'left')
#
#
# No files available for combination: ('ul010', 'dt', 'oc', 'm1s1', 'left')
#
#
# No files available for combination: ('ul010', 'dt', 'oc', 'm0s1', 'left')
#
#
# No files available for combination: ('ul010', 'dt', 'oc', 'm1', 'left')
#
#
#
#
# No files available for combination: ('ul010', 'st', 'oc', 'm0s0', 'left')
#
#
# No files available for combination: ('ul010', 'st', 'oc', 'm1s1', 'left')
#
#
# No files available for combination: ('ul010', 'st', 'oc', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul010', 'st', 'oc', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul010', 'dt', 'oc', 'm1s0', 'right')
#
#
# No files available for combination: ('ul010', 'dt', 'oc', 'm1s1', 'right')
#
#
# No files available for combination: ('ul010', 'dt', 'oc', 'm0s1', 'right')
#
#
# No files available for combination: ('ul010', 'dt', 'oc', 'm1', 'right')
#
#
#
#
# No files available for combination: ('ul010', 'st', 'oc', 'm0s0', 'right')
#
#
# No files available for combination: ('ul010', 'st', 'oc', 'm1s1', 'right')
#
#
# No files available for combination: ('ul010', 'st', 'oc', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul010', 'st', 'oc', 'm0', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul010', 'dt', 'ps', 'm1s0', 'left')
#
#
# No files available for combination: ('ul010', 'dt', 'ps', 'm1s1', 'left')
#
#
# No files available for combination: ('ul010', 'dt', 'ps', 'm0s1', 'left')
#
#
# No files available for combination: ('ul010', 'dt', 'ps', 'm1', 'left')
#
#
#
#
# No files available for combination: ('ul010', 'st', 'ps', 'm0s0', 'left')
#
#
# No files available for combination: ('ul010', 'st', 'ps', 'm1s1', 'left')
#
#
# No files available for combination: ('ul010', 'st', 'ps', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul010', 'st', 'ps', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul010', 'dt', 'ps', 'm1s0', 'right')
#
#
# No files available for combination: ('ul010', 'dt', 'ps', 'm1s1', 'right')
#
#
# No files available for combination: ('ul010', 'dt', 'ps', 'm0s1', 'right')
#
#
# No files available for combination: ('ul010', 'dt', 'ps', 'm1', 'right')
#
#
#
#
# No files available for combination: ('ul010', 'st', 'ps', 'm0s0', 'right')
#
#
# No files available for combination: ('ul010', 'st', 'ps', 'm1s1', 'right')
#
#
# No files available for combination: ('ul010', 'st', 'ps', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul010', 'st', 'ps', 'm0', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul010', 'dt', 'pt', 'm1s0', 'left')
#
#
# No files available for combination: ('ul010', 'dt', 'pt', 'm1s1', 'left')
#
#
# No files available for combination: ('ul010', 'dt', 'pt', 'm0s1', 'left')
#
#
# No files available for combination: ('ul010', 'dt', 'pt', 'm1', 'left')
#
#
#
#
# No files available for combination: ('ul010', 'st', 'pt', 'm0s0', 'left')
#
#
#
#
# No files available for combination: ('ul010', 'st', 'pt', 'm1s1', 'left')
#
#
# No files available for combination: ('ul010', 'st', 'pt', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul010', 'st', 'pt', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul010', 'dt', 'pt', 'm1s0', 'right')
#
#
# No files available for combination: ('ul010', 'dt', 'pt', 'm1s1', 'right')
#
#
# No files available for combination: ('ul010', 'dt', 'pt', 'm0s1', 'right')
#
#
# No files available for combination: ('ul010', 'dt', 'pt', 'm1', 'right')
#
#
#
#
# No files available for combination: ('ul010', 'st', 'pt', 'm0s0', 'right')
#
#
# No files available for combination: ('ul010', 'st', 'pt', 'm1s1', 'right')
#
#
# ...
#
#
# No files available for combination: ('ul017', 'vr', 'ps', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul017', 'vr', 'ps', 'm0', 'right')
#
#
# No files available for combination: ('ul017', 'dt', 'ps', 'm1s0', 'right')
#
#
# No files available for combination: ('ul017', 'dt', 'ps', 'm1s1', 'right')
#
#
# No files available for combination: ('ul017', 'dt', 'ps', 'm1', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul017', 'vr', 'pt', 'm0s0', 'left')
#
#
# No files available for combination: ('ul017', 'vr', 'pt', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul017', 'vr', 'pt', 'm0', 'left')
#
#
# No files available for combination: ('ul017', 'dt', 'pt', 'm1s0', 'left')
#
#
# No files available for combination: ('ul017', 'dt', 'pt', 'm1s1', 'left')
#
#
# No files available for combination: ('ul017', 'dt', 'pt', 'm1', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul017', 'vr', 'pt', 'm0s0', 'right')
#
#
#
#
#
#
# No files available for combination: ('ul017', 'vr', 'pt', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul017', 'vr', 'pt', 'm0', 'right')
#
#
# No files available for combination: ('ul017', 'dt', 'pt', 'm1s0', 'right')
#
#
# No files available for combination: ('ul017', 'dt', 'pt', 'm1s1', 'right')
#
#
# No files available for combination: ('ul017', 'dt', 'pt', 'm1', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul018', 'dt', 'ft', 'm0s0', 'left')
#
#
# No files available for combination: ('ul018', 'dt', 'ft', 'm1s0', 'left')
#
#
# No files available for combination: ('ul018', 'dt', 'ft', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul018', 'dt', 'ft', 'm0', 'left')
#
#
# No files available for combination: ('ul018', 'st', 'ft', 'm0s0', 'left')
#
#
# No files available for combination: ('ul018', 'st', 'ft', 'm1s1', 'left')
#
#
# No files available for combination: ('ul018', 'st', 'ft', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul018', 'st', 'ft', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul018', 'dt', 'ft', 'm0s0', 'right')
#
#
# No files available for combination: ('ul018', 'dt', 'ft', 'm1s0', 'right')
#
#
# No files available for combination: ('ul018', 'dt', 'ft', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul018', 'dt', 'ft', 'm0', 'right')
#
#
# No files available for combination: ('ul018', 'st', 'ft', 'm0s0', 'right')
#
#
# No files available for combination: ('ul018', 'st', 'ft', 'm1s1', 'right')
#
#
# No files available for combination: ('ul018', 'st', 'ft', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul018', 'st', 'ft', 'm0', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul018', 'dt', 'oc', 'm0s0', 'left')
#
#
# No files available for combination: ('ul018', 'dt', 'oc', 'm1s0', 'left')
#
#
# No files available for combination: ('ul018', 'dt', 'oc', 'm1s1', 'left')
#
#
# No files available for combination: ('ul018', 'dt', 'oc', 'm0s1', 'left')
#
#
# No files available for combination: ('ul018', 'dt', 'oc', 'm1', 'left')
#
#
# No files available for combination: ('ul018', 'dt', 'oc', 'm0', 'left')
#
#
# No files available for combination: ('ul018', 'st', 'oc', 'm0s0', 'left')
#
#
#
#
# No files available for combination: ('ul018', 'st', 'oc', 'm1s1', 'left')
#
#
# No files available for combination: ('ul018', 'st', 'oc', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul018', 'st', 'oc', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul018', 'dt', 'oc', 'm0s0', 'right')
#
#
# No files available for combination: ('ul018', 'dt', 'oc', 'm1s0', 'right')
#
#
# No files available for combination: ('ul018', 'dt', 'oc', 'm1s1', 'right')
# No files available for combination: ('ul018', 'dt', 'oc', 'm0s1', 'right')
#
#
# No files available for combination: ('ul018', 'dt', 'oc', 'm1', 'right')
#
#
# No files available for combination: ('ul018', 'dt', 'oc', 'm0', 'right')
#
#
# No files available for combination: ('ul018', 'st', 'oc', 'm0s0', 'right')
#
#
#
#
# No files available for combination: ('ul018', 'st', 'oc', 'm1s1', 'right')
#
#
# No files available for combination: ('ul018', 'st', 'oc', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul018', 'st', 'oc', 'm0', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul018', 'dt', 'ps', 'm0s0', 'left')
#
#
# No files available for combination: ('ul018', 'dt', 'ps', 'm1s0', 'left')
#
#
# No files available for combination: ('ul018', 'dt', 'ps', 'm1s1', 'left')
# No files available for combination: ('ul018', 'dt', 'ps', 'm0s1', 'left')
#
#
# No files available for combination: ('ul018', 'dt', 'ps', 'm1', 'left')
#
#
# No files available for combination: ('ul018', 'dt', 'ps', 'm0', 'left')
#
#
# No files available for combination: ('ul018', 'st', 'ps', 'm0s0', 'left')
#
#
# No files available for combination: ('ul018', 'st', 'ps', 'm1s1', 'left')
#
#
# No files available for combination: ('ul018', 'st', 'ps', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul018', 'st', 'ps', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul018', 'dt', 'ps', 'm0s0', 'right')
#
#
# No files available for combination: ('ul018', 'dt', 'ps', 'm1s0', 'right')
#
#
# No files available for combination: ('ul018', 'dt', 'ps', 'm1s1', 'right')
# No files available for combination: ('ul018', 'dt', 'ps', 'm0s1', 'right')
#
#
# No files available for combination: ('ul018', 'dt', 'ps', 'm1', 'right')
#
#
# No files available for combination: ('ul018', 'dt', 'ps', 'm0', 'right')
#
#
# No files available for combination: ('ul018', 'st', 'ps', 'm0s0', 'right')
#
#
# No files available for combination: ('ul018', 'st', 'ps', 'm1s1', 'right')
#
#
# No files available for combination: ('ul018', 'st', 'ps', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul018', 'st', 'ps', 'm0', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul018', 'dt', 'pt', 'm0s0', 'left')
#
#
# No files available for combination: ('ul018', 'dt', 'pt', 'm1s0', 'left')
#
#
# No files available for combination: ('ul018', 'dt', 'pt', 'm1s1', 'left')
# No files available for combination: ('ul018', 'dt', 'pt', 'm0s1', 'left')
#
#
# No files available for combination: ('ul018', 'dt', 'pt', 'm1', 'left')
#
#
# No files available for combination: ('ul018', 'dt', 'pt', 'm0', 'left')
#
#
# No files available for combination: ('ul018', 'st', 'pt', 'm0s0', 'left')
#
#
# No files available for combination: ('ul018', 'st', 'pt', 'm1s1', 'left')
#
#
# No files available for combination: ('ul018', 'st', 'pt', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul018', 'st', 'pt', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul018', 'dt', 'pt', 'm0s0', 'right')
#
#
# No files available for combination: ('ul018', 'dt', 'pt', 'm1s0', 'right')
#
#
# No files available for combination: ('ul018', 'dt', 'pt', 'm1s1', 'right')
# No files available for combination: ('ul018', 'dt', 'pt', 'm0s1', 'right')
#
#
# No files available for combination: ('ul018', 'dt', 'pt', 'm1', 'right')
#
#
# No files available for combination: ('ul018', 'dt', 'pt', 'm0', 'right')
#
#
# No files available for combination: ('ul018', 'st', 'pt', 'm0s0', 'right')
#
#
# No files available for combination: ('ul018', 'st', 'pt', 'm1s1', 'right')
#
#
# No files available for combination: ('ul018', 'st', 'pt', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul018', 'st', 'pt', 'm0', 'right')
#
#
# No files available for combination: ('ul019', 'vr', 'ft', 'm0s0', 'left')
#
#
# No files available for combination: ('ul019', 'vr', 'ft', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul019', 'vr', 'ft', 'm0', 'left')
#
#
# No files available for combination: ('ul019', 'dt', 'ft', 'm1s0', 'left')
#
#
# No files available for combination: ('ul019', 'dt', 'ft', 'm1s1', 'left')
#
#
# No files available for combination: ('ul019', 'dt', 'ft', 'm1', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul019', 'vr', 'ft', 'm0s0', 'right')
#
#
# No files available for combination: ('ul019', 'vr', 'ft', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul019', 'vr', 'ft', 'm0', 'right')
#
#
# No files available for combination: ('ul019', 'dt', 'ft', 'm1s0', 'right')
#
#
# No files available for combination: ('ul019', 'dt', 'ft', 'm1s1', 'right')
#
#
# No files available for combination: ('ul019', 'dt', 'ft', 'm1', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul019', 'vr', 'oc', 'm0s0', 'left')
#
#
# No files available for combination: ('ul019', 'vr', 'oc', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul019', 'vr', 'oc', 'm0', 'left')
#
#
# No files available for combination: ('ul019', 'dt', 'oc', 'm1s0', 'left')
#
#
# No files available for combination: ('ul019', 'dt', 'oc', 'm1s1', 'left')
#
#
# No files available for combination: ('ul019', 'dt', 'oc', 'm1', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul019', 'vr', 'oc', 'm0s0', 'right')
#
#
# No files available for combination: ('ul019', 'vr', 'oc', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul019', 'vr', 'oc', 'm0', 'right')
#
#
# No files available for combination: ('ul019', 'dt', 'oc', 'm1s0', 'right')
#
#
# No files available for combination: ('ul019', 'dt', 'oc', 'm1s1', 'right')
#
#
# No files available for combination: ('ul019', 'dt', 'oc', 'm1', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul019', 'vr', 'ps', 'm0s0', 'left')
#
#
# No files available for combination: ('ul019', 'vr', 'ps', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul019', 'vr', 'ps', 'm0', 'left')
#
#
# No files available for combination: ('ul019', 'dt', 'ps', 'm1s0', 'left')
#
#
# No files available for combination: ('ul019', 'dt', 'ps', 'm1s1', 'left')
#
#
# No files available for combination: ('ul019', 'dt', 'ps', 'm1', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul019', 'vr', 'ps', 'm0s0', 'right')
#
#
# No files available for combination: ('ul019', 'vr', 'ps', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul019', 'vr', 'ps', 'm0', 'right')
#
#
# No files available for combination: ('ul019', 'dt', 'ps', 'm1s0', 'right')
#
#
# No files available for combination: ('ul019', 'dt', 'ps', 'm1s1', 'right')
#
#
# No files available for combination: ('ul019', 'dt', 'ps', 'm1', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul019', 'vr', 'pt', 'm0s0', 'left')
#
#
# No files available for combination: ('ul019', 'vr', 'pt', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul019', 'vr', 'pt', 'm0', 'left')
#
#
# No files available for combination: ('ul019', 'dt', 'pt', 'm1s0', 'left')
#
#
# No files available for combination: ('ul019', 'dt', 'pt', 'm1s1', 'left')
#
#
# No files available for combination: ('ul019', 'dt', 'pt', 'm1', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul019', 'vr', 'pt', 'm0s0', 'right')
#
#
# No files available for combination: ('ul019', 'vr', 'pt', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul019', 'vr', 'pt', 'm0', 'right')
#
#
# No files available for combination: ('ul019', 'dt', 'pt', 'm1s0', 'right')
#
#
# No files available for combination: ('ul019', 'dt', 'pt', 'm1s1', 'right')
#
#
# No files available for combination: ('ul019', 'dt', 'pt', 'm1', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul020', 'vr', 'ft', 'm1s0', 'left')
#
#
# No files available for combination: ('ul020', 'vr', 'ft', 'm1s1', 'left')
#
#
# No files available for combination: ('ul020', 'vr', 'ft', 'm0s1', 'left')
#
#
# No files available for combination: ('ul020', 'vr', 'ft', 'm1', 'left')
#
#
#
#
# No files available for combination: ('ul020', 'dt', 'ft', 'm0s0', 'left')
#
#
# No files available for combination: ('ul020', 'dt', 'ft', 'm1s0', 'left')
#
#
# No files available for combination: ('ul020', 'dt', 'ft', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul020', 'dt', 'ft', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul020', 'vr', 'ft', 'm1s0', 'right')
#
#
# No files available for combination: ('ul020', 'vr', 'ft', 'm1s1', 'right')
#
#
# No files available for combination: ('ul020', 'vr', 'ft', 'm0s1', 'right')
#
#
# No files available for combination: ('ul020', 'vr', 'ft', 'm1', 'right')
#
#
#
#
# No files available for combination: ('ul020', 'dt', 'ft', 'm0s0', 'right')
#
#
# No files available for combination: ('ul020', 'dt', 'ft', 'm1s0', 'right')
#
#
#
#
# No files available for combination: ('ul020', 'dt', 'ft', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul020', 'dt', 'ft', 'm0', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul020', 'vr', 'oc', 'm1s0', 'left')
#
#
# No files available for combination: ('ul020', 'vr', 'oc', 'm1s1', 'left')
#
#
# No files available for combination: ('ul020', 'vr', 'oc', 'm0s1', 'left')
#
#
# No files available for combination: ('ul020', 'vr', 'oc', 'm1', 'left')
#
#
#
#
# No files available for combination: ('ul020', 'dt', 'oc', 'm0s0', 'left')
#
#
# No files available for combination: ('ul020', 'dt', 'oc', 'm1s0', 'left')
#
#
# No files available for combination: ('ul020', 'dt', 'oc', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul020', 'dt', 'oc', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul020', 'vr', 'oc', 'm1s0', 'right')
#
#
# No files available for combination: ('ul020', 'vr', 'oc', 'm1s1', 'right')
#
#
# No files available for combination: ('ul020', 'vr', 'oc', 'm0s1', 'right')
#
#
# No files available for combination: ('ul020', 'vr', 'oc', 'm1', 'right')
#
#
#
#
# No files available for combination: ('ul020', 'dt', 'oc', 'm0s0', 'right')
#
#
# No files available for combination: ('ul020', 'dt', 'oc', 'm1s0', 'right')
#
#
# No files available for combination: ('ul020', 'dt', 'oc', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul020', 'dt', 'oc', 'm0', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul020', 'vr', 'ps', 'm1s0', 'left')
#
#
# No files available for combination: ('ul020', 'vr', 'ps', 'm1s1', 'left')
#
#
# No files available for combination: ('ul020', 'vr', 'ps', 'm0s1', 'left')
#
#
# No files available for combination: ('ul020', 'vr', 'ps', 'm1', 'left')
#
#
#
#
# No files available for combination: ('ul020', 'dt', 'ps', 'm0s0', 'left')
#
#
# No files available for combination: ('ul020', 'dt', 'ps', 'm1s0', 'left')
#
#
# No files available for combination: ('ul020', 'dt', 'ps', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul020', 'dt', 'ps', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul020', 'vr', 'ps', 'm1s0', 'right')
#
#
# No files available for combination: ('ul020', 'vr', 'ps', 'm1s1', 'right')
#
#
# No files available for combination: ('ul020', 'vr', 'ps', 'm0s1', 'right')
#
#
# No files available for combination: ('ul020', 'vr', 'ps', 'm1', 'right')
#
#
#
#
# No files available for combination: ('ul020', 'dt', 'ps', 'm0s0', 'right')
#
#
# No files available for combination: ('ul020', 'dt', 'ps', 'm1s0', 'right')
#
#
# No files available for combination: ('ul020', 'dt', 'ps', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul020', 'dt', 'ps', 'm0', 'right')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul020', 'vr', 'pt', 'm1s0', 'left')
#
#
# No files available for combination: ('ul020', 'vr', 'pt', 'm1s1', 'left')
#
#
# No files available for combination: ('ul020', 'vr', 'pt', 'm0s1', 'left')
#
#
# No files available for combination: ('ul020', 'vr', 'pt', 'm1', 'left')
#
#
#
#
# No files available for combination: ('ul020', 'dt', 'pt', 'm0s0', 'left')
#
#
# No files available for combination: ('ul020', 'dt', 'pt', 'm1s0', 'left')
#
#
# No files available for combination: ('ul020', 'dt', 'pt', 'm0s1', 'left')
#
#
#
#
# No files available for combination: ('ul020', 'dt', 'pt', 'm0', 'left')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# No files available for combination: ('ul020', 'vr', 'pt', 'm1s0', 'right')
#
#
# No files available for combination: ('ul020', 'vr', 'pt', 'm1s1', 'right')
#
#
# No files available for combination: ('ul020', 'vr', 'pt', 'm0s1', 'right')
#
#
# No files available for combination: ('ul020', 'vr', 'pt', 'm1', 'right')
#
#
#
#
# No files available for combination: ('ul020', 'dt', 'pt', 'm0s0', 'right')
#
#
# No files available for combination: ('ul020', 'dt', 'pt', 'm1s0', 'right')
#
#
# No files available for combination: ('ul020', 'dt', 'pt', 'm0s1', 'right')
#
#
#
#
# No files available for combination: ('ul020', 'dt', 'pt', 'm0', 'right')

# %% [markdown]
# ### 2. Calculating distances and saving distance .csv files

# %%
subs = find_paths.find_available_subs(folder)
ls_task = ['ft', 'oc', 'ps']
ls_cond = ['m0s0', 'm1s0', 'm1s1', 'm0s1', 'm1', 'm0']

# %%
# Reloading own functions
importlib.reload(import_dat)
importlib.reload(tasks)
importlib.reload(find_paths)
importlib.reload(calc_dist)

for sub in subs:
    for task in ls_task:
        for cond in ls_cond:
            try:
                files = os.listdir(os.path.join(repo_path, 'data', sub, task, cond, 'cleaned_blocks'))

                for file in files:
                    # Load blocks from patients' blocks dir
                    block = pd.read_csv(os.path.join(
                        repo_path, 'data', sub, task, cond, 'cleaned_blocks', file), index_col=0)

                    dist = calc_dist.calculate_distances(sub, task, cond, block, file)
                    
            except FileNotFoundError:
                print('No files available for combination: '
                    f'{sub, task, cond}')
# Out:
# No files available for combination: ('ul001', 'ft', 'm0s0')
# No files available for combination: ('ul001', 'ft', 'm1s0')
# No files available for combination: ('ul001', 'ft', 'm1s1')
# No files available for combination: ('ul001', 'ft', 'm0s1')
# No files available for combination: ('ul001', 'ft', 'm0')
# No files available for combination: ('ul001', 'oc', 'm0s0')
# No files available for combination: ('ul001', 'oc', 'm1s0')
# No files available for combination: ('ul001', 'oc', 'm1s1')
# No files available for combination: ('ul001', 'oc', 'm0s1')
# No files available for combination: ('ul001', 'oc', 'm0')
# No files available for combination: ('ul001', 'ps', 'm0s0')
# No files available for combination: ('ul001', 'ps', 'm1s0')
# No files available for combination: ('ul001', 'ps', 'm1s1')
# No files available for combination: ('ul001', 'ps', 'm0s1')
# No files available for combination: ('ul001', 'ps', 'm0')
# No files available for combination: ('ul002', 'ft', 'm0s0')
# No files available for combination: ('ul002', 'ft', 'm1s0')
# No files available for combination: ('ul002', 'ft', 'm1s1')
# No files available for combination: ('ul002', 'ft', 'm0s1')
# No files available for combination: ('ul002', 'ft', 'm0')
# No files available for combination: ('ul002', 'oc', 'm0s0')
# No files available for combination: ('ul002', 'oc', 'm1s0')
# No files available for combination: ('ul002', 'oc', 'm1s1')
# No files available for combination: ('ul002', 'oc', 'm0s1')
# No files available for combination: ('ul002', 'oc', 'm0')
# No files available for combination: ('ul002', 'ps', 'm0s0')
# No files available for combination: ('ul002', 'ps', 'm1s0')
# No files available for combination: ('ul002', 'ps', 'm1s1')
# No files available for combination: ('ul002', 'ps', 'm0s1')
# No files available for combination: ('ul002', 'ps', 'm0')
# No files available for combination: ('ul003', 'ft', 'm0s0')
# No files available for combination: ('ul003', 'ft', 'm0s1')
# No files available for combination: ('ul003', 'ft', 'm1')
# No files available for combination: ('ul003', 'ft', 'm0')
# No files available for combination: ('ul003', 'oc', 'm0s0')
# No files available for combination: ('ul003', 'oc', 'm0s1')
# No files available for combination: ('ul003', 'oc', 'm1')
# No files available for combination: ('ul003', 'oc', 'm0')
# No files available for combination: ('ul003', 'ps', 'm0s0')
# No files available for combination: ('ul003', 'ps', 'm0s1')
# No files available for combination: ('ul003', 'ps', 'm1')
# No files available for combination: ('ul003', 'ps', 'm0')
# No files available for combination: ('ul004', 'ft', 'm0s0')
# No files available for combination: ('ul004', 'ft', 'm0s1')
# No files available for combination: ('ul004', 'ft', 'm1')
# No files available for combination: ('ul004', 'ft', 'm0')
# No files available for combination: ('ul004', 'oc', 'm0s0')
# No files available for combination: ('ul004', 'oc', 'm0s1')
# No files available for combination: ('ul004', 'oc', 'm1')
# No files available for combination: ('ul004', 'oc', 'm0')
# No files available for combination: ('ul004', 'ps', 'm0s0')
# No files available for combination: ('ul004', 'ps', 'm0s1')
# No files available for combination: ('ul004', 'ps', 'm1')
# No files available for combination: ('ul004', 'ps', 'm0')
# No files available for combination: ('ul005', 'ft', 'm0s0')
# No files available for combination: ('ul005', 'ft', 'm1s0')
# No files available for combination: ('ul005', 'ft', 'm0s1')
# No files available for combination: ('ul005', 'ft', 'm1')
# No files available for combination: ('ul005', 'ft', 'm0')
# No files available for combination: ('ul005', 'oc', 'm0s0')
# No files available for combination: ('ul005', 'oc', 'm1s0')
# No files available for combination: ('ul005', 'oc', 'm0s1')
# No files available for combination: ('ul005', 'oc', 'm1')
# No files available for combination: ('ul005', 'oc', 'm0')
# No files available for combination: ('ul005', 'ps', 'm0s0')
# No files available for combination: ('ul005', 'ps', 'm1s0')
# No files available for combination: ('ul005', 'ps', 'm0s1')
# No files available for combination: ('ul005', 'ps', 'm1')
# No files available for combination: ('ul005', 'ps', 'm0')
# No files available for combination: ('ul006', 'ft', 'm0s0')
# No files available for combination: ('ul006', 'ft', 'm1s0')
# No files available for combination: ('ul006', 'ft', 'm1s1')
# No files available for combination: ('ul006', 'ft', 'm0s1')
# No files available for combination: ('ul006', 'ft', 'm1')
# No files available for combination: ('ul006', 'ft', 'm0')
# No files available for combination: ('ul006', 'oc', 'm0s0')
# No files available for combination: ('ul006', 'oc', 'm1s0')
# No files available for combination: ('ul006', 'oc', 'm1s1')
# No files available for combination: ('ul006', 'oc', 'm0s1')
# No files available for combination: ('ul006', 'oc', 'm1')
# No files available for combination: ('ul006', 'oc', 'm0')
# No files available for combination: ('ul006', 'ps', 'm0s0')
# No files available for combination: ('ul006', 'ps', 'm1s0')
# No files available for combination: ('ul006', 'ps', 'm1s1')
# No files available for combination: ('ul006', 'ps', 'm0s1')
# No files available for combination: ('ul006', 'ps', 'm1')
# No files available for combination: ('ul006', 'ps', 'm0')
# No files available for combination: ('ul007', 'ft', 'm1')
# No files available for combination: ('ul007', 'ft', 'm0')
# No files available for combination: ('ul007', 'oc', 'm1')
# No files available for combination: ('ul007', 'oc', 'm0')
# No files available for combination: ('ul007', 'ps', 'm0s1')
# No files available for combination: ('ul007', 'ps', 'm1')
# No files available for combination: ('ul007', 'ps', 'm0')
# No files available for combination: ('ul008', 'ft', 'm1')
# No files available for combination: ('ul008', 'ft', 'm0')
# No files available for combination: ('ul008', 'oc', 'm1')
# No files available for combination: ('ul008', 'oc', 'm0')
# No files available for combination: ('ul008', 'ps', 'm1')
# No files available for combination: ('ul008', 'ps', 'm0')
# No files available for combination: ('ul009', 'ft', 'm0s0')
# No files available for combination: ('ul009', 'ft', 'm1s0')
# No files available for combination: ('ul009', 'ft', 'm1s1')
# No files available for combination: ('ul009', 'ft', 'm0s1')
# No files available for combination: ('ul009', 'ft', 'm0')
# No files available for combination: ('ul009', 'oc', 'm0s0')
# No files available for combination: ('ul009', 'oc', 'm1s0')
# No files available for combination: ('ul009', 'oc', 'm1s1')
# No files available for combination: ('ul009', 'oc', 'm0s1')
# No files available for combination: ('ul009', 'oc', 'm0')
# No files available for combination: ('ul009', 'ps', 'm0s0')
# No files available for combination: ('ul009', 'ps', 'm1s0')
# No files available for combination: ('ul009', 'ps', 'm1s1')
# No files available for combination: ('ul009', 'ps', 'm0s1')
# No files available for combination: ('ul009', 'ps', 'm0')
# No files available for combination: ('ul010', 'ft', 'm1s0')
# No files available for combination: ('ul010', 'ft', 'm1s1')
# No files available for combination: ('ul010', 'ft', 'm0s1')
# No files available for combination: ('ul010', 'ft', 'm1')
# No files available for combination: ('ul010', 'ft', 'm0')
# No files available for combination: ('ul010', 'oc', 'm1s1')
# No files available for combination: ('ul010', 'oc', 'm0s1')
# No files available for combination: ('ul010', 'oc', 'm1')
# No files available for combination: ('ul010', 'oc', 'm0')
# No files available for combination: ('ul010', 'ps', 'm1s1')
# No files available for combination: ('ul010', 'ps', 'm0s1')
# No files available for combination: ('ul010', 'ps', 'm1')
# No files available for combination: ('ul010', 'ps', 'm0')
# No files available for combination: ('ul011', 'ft', 'm1s1')
# No files available for combination: ('ul011', 'ft', 'm0s1')
# No files available for combination: ('ul011', 'ft', 'm1')
# No files available for combination: ('ul011', 'ft', 'm0')
# No files available for combination: ('ul011', 'oc', 'm1s1')
# No files available for combination: ('ul011', 'oc', 'm0s1')
# No files available for combination: ('ul011', 'oc', 'm1')
# No files available for combination: ('ul011', 'oc', 'm0')
# No files available for combination: ('ul011', 'ps', 'm1s1')
# No files available for combination: ('ul011', 'ps', 'm0s1')
# No files available for combination: ('ul011', 'ps', 'm1')
# No files available for combination: ('ul011', 'ps', 'm0')
# No files available for combination: ('ul012', 'ft', 'm0s0')
# No files available for combination: ('ul012', 'ft', 'm1s0')
# No files available for combination: ('ul012', 'ft', 'm1s1')
# No files available for combination: ('ul012', 'ft', 'm0s1')
# No files available for combination: ('ul012', 'ft', 'm1')
# No files available for combination: ('ul012', 'ft', 'm0')
# No files available for combination: ('ul012', 'oc', 'm0s0')
# No files available for combination: ('ul012', 'oc', 'm1s0')
# No files available for combination: ('ul012', 'oc', 'm1s1')
# No files available for combination: ('ul012', 'oc', 'm0s1')
# No files available for combination: ('ul012', 'oc', 'm1')
# No files available for combination: ('ul012', 'oc', 'm0')
# No files available for combination: ('ul012', 'ps', 'm0s0')
# No files available for combination: ('ul012', 'ps', 'm1s0')
# No files available for combination: ('ul012', 'ps', 'm1s1')
# No files available for combination: ('ul012', 'ps', 'm0s1')
# No files available for combination: ('ul012', 'ps', 'm1')
# No files available for combination: ('ul012', 'ps', 'm0')
# No files available for combination: ('ul013', 'ft', 'm0s0')
# No files available for combination: ('ul013', 'ft', 'm1s0')
# No files available for combination: ('ul013', 'ft', 'm1s1')
# No files available for combination: ('ul013', 'ft', 'm0s1')
# No files available for combination: ('ul013', 'ft', 'm0')
# No files available for combination: ('ul013', 'oc', 'm0s0')
# No files available for combination: ('ul013', 'oc', 'm1s0')
# No files available for combination: ('ul013', 'oc', 'm1s1')
# No files available for combination: ('ul013', 'oc', 'm0s1')
# No files available for combination: ('ul013', 'oc', 'm0')
# No files available for combination: ('ul013', 'ps', 'm0s0')
# No files available for combination: ('ul013', 'ps', 'm1s0')
# No files available for combination: ('ul013', 'ps', 'm1s1')
# No files available for combination: ('ul013', 'ps', 'm0s1')
# No files available for combination: ('ul013', 'ps', 'm0')
# No files available for combination: ('ul014', 'ft', 'm0s0')
# No files available for combination: ('ul014', 'ft', 'm1s0')
# No files available for combination: ('ul014', 'ft', 'm1s1')
# No files available for combination: ('ul014', 'ft', 'm0s1')
# No files available for combination: ('ul014', 'ft', 'm0')
# No files available for combination: ('ul014', 'oc', 'm0s0')
# No files available for combination: ('ul014', 'oc', 'm1s0')
# No files available for combination: ('ul014', 'oc', 'm1s1')
# No files available for combination: ('ul014', 'oc', 'm0s1')
# No files available for combination: ('ul014', 'oc', 'm0')
# No files available for combination: ('ul014', 'ps', 'm0s0')
# No files available for combination: ('ul014', 'ps', 'm1s0')
# No files available for combination: ('ul014', 'ps', 'm1s1')
# No files available for combination: ('ul014', 'ps', 'm0s1')
# No files available for combination: ('ul014', 'ps', 'm0')
# No files available for combination: ('ul015', 'ft', 'm0s0')
# No files available for combination: ('ul015', 'ft', 'm0s1')
# No files available for combination: ('ul015', 'ft', 'm1')
# No files available for combination: ('ul015', 'ft', 'm0')
# No files available for combination: ('ul015', 'oc', 'm0s0')
# No files available for combination: ('ul015', 'oc', 'm0s1')
# No files available for combination: ('ul015', 'oc', 'm1')
# No files available for combination: ('ul015', 'oc', 'm0')
# No files available for combination: ('ul015', 'ps', 'm0s0')
# No files available for combination: ('ul015', 'ps', 'm0s1')
# No files available for combination: ('ul015', 'ps', 'm1')
# No files available for combination: ('ul015', 'ps', 'm0')
# No files available for combination: ('ul016', 'ft', 'm0s0')
# No files available for combination: ('ul016', 'ft', 'm1s0')
# No files available for combination: ('ul016', 'ft', 'm1s1')
# No files available for combination: ('ul016', 'ft', 'm0s1')
# No files available for combination: ('ul016', 'ft', 'm0')
# No files available for combination: ('ul016', 'oc', 'm0s0')
# No files available for combination: ('ul016', 'oc', 'm1s0')
# No files available for combination: ('ul016', 'oc', 'm1s1')
# No files available for combination: ('ul016', 'oc', 'm0s1')
# No files available for combination: ('ul016', 'oc', 'm0')
# No files available for combination: ('ul016', 'ps', 'm0s0')
# No files available for combination: ('ul016', 'ps', 'm1s0')
# No files available for combination: ('ul016', 'ps', 'm1s1')
# No files available for combination: ('ul016', 'ps', 'm0s1')
# No files available for combination: ('ul016', 'ps', 'm0')
# No files available for combination: ('ul017', 'ft', 'm0s0')
# No files available for combination: ('ul017', 'ft', 'm1')
# No files available for combination: ('ul017', 'ft', 'm0')
# No files available for combination: ('ul017', 'oc', 'm1')
# No files available for combination: ('ul017', 'oc', 'm0')
# No files available for combination: ('ul017', 'ps', 'm1')
# No files available for combination: ('ul017', 'ps', 'm0')
# No files available for combination: ('ul018', 'ft', 'm0s0')
# No files available for combination: ('ul018', 'ft', 'm0s1')
# No files available for combination: ('ul018', 'ft', 'm1')
# No files available for combination: ('ul018', 'ft', 'm0')
# No files available for combination: ('ul018', 'oc', 'm0s0')
# No files available for combination: ('ul018', 'oc', 'm1s1')
# No files available for combination: ('ul018', 'oc', 'm0s1')
# No files available for combination: ('ul018', 'oc', 'm1')
# No files available for combination: ('ul018', 'oc', 'm0')
# No files available for combination: ('ul018', 'ps', 'm0s0')
# No files available for combination: ('ul018', 'ps', 'm1s1')
# No files available for combination: ('ul018', 'ps', 'm0s1')
# No files available for combination: ('ul018', 'ps', 'm1')
# No files available for combination: ('ul018', 'ps', 'm0')
# No files available for combination: ('ul019', 'ft', 'm1')
# No files available for combination: ('ul019', 'ft', 'm0')
# No files available for combination: ('ul019', 'oc', 'm1')
# No files available for combination: ('ul019', 'oc', 'm0')
# No files available for combination: ('ul019', 'ps', 'm1')
# No files available for combination: ('ul019', 'ps', 'm0')
# No files available for combination: ('ul020', 'ft', 'm0s0')
# No files available for combination: ('ul020', 'ft', 'm1s0')
# No files available for combination: ('ul020', 'ft', 'm0s1')
# No files available for combination: ('ul020', 'ft', 'm1')
# No files available for combination: ('ul020', 'ft', 'm0')
# No files available for combination: ('ul020', 'oc', 'm1s0')
# No files available for combination: ('ul020', 'oc', 'm0s1')
# No files available for combination: ('ul020', 'oc', 'm1')
# No files available for combination: ('ul020', 'oc', 'm0')
# No files available for combination: ('ul020', 'ps', 'm1s0')
# No files available for combination: ('ul020', 'ps', 'm0s1')
# No files available for combination: ('ul020', 'ps', 'm1')
# No files available for combination: ('ul020', 'ps', 'm0')
